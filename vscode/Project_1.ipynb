# %%
print("Hello World")
# Out:
# Hello World

# %%
import json

# %%
import pandas as pd

# %%
import streamlit as st
st.write("Hello World")
# Out:
# 2026-07-26 20:48:24.152 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-26 20:48:24.591
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run e:\vscode\.venv\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-07-26 20:48:24.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-26 20:48:24.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import os
os.getcwd()
# Out:
# 'e:\\vscode'

# %%
import os
os.listdir()
# Out:
# ['.venv',
#  'agents_cleaned.json',
#  'app.py',
#  'buyers_cleaned.json',
#  'employee.db',
#  'listings_final_expanded.json',
#  'Project_1.ipynb',
#  'Project_1.py',
#  'property_attributes_final_expanded.json',
#  'sales_cleaned.csv']

# %%
import json

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# e:\vscode
# ['.venv', 'agents_cleaned.json', 'app.py', 'buyers_cleaned.json', 'employee.db', 'listings_final_expanded.json', 'Project_1.ipynb', 'Project_1.py', 'property_attributes_final_expanded.json', 'sales_cleaned.csv']

# %%
import json
import pandas as pd

# %%
listings_df = pd.read_json("listings_final_expanded.json")

# %%
property_df = pd.read_json("property_attributes_final_expanded.json")

# %%
import pandas as pd
df = pd.read_json("listings_final_expanded.json")
df.to_csv("listings_final_expanded.csv"),
print("CSV file created successfully.")
# Out:
# CSV file created successfully.

# %%
import pandas as pd
df = pd.read_json("property_attributes_final_expanded.json")
df.to_csv("property_attributes_final_expanded.csv", index=False)
print("CSV file created successfully.")
# Out:
# CSV file created successfully.

# %%
import pandas as pd
df = pd.read_json("agents_cleaned.json")
df.to_csv("agents_cleaned.csv", index=False)
print("csv file created successfully.")
# Out:
# csv file created successfully.

# %%
import pandas as pd
df = pd.read_json("buyers_cleaned.json")
df.to_csv("buyers_cleaned.csv", index=False)
print("csv file created successfully.")
# Out:
# csv file created successfully.

# %%
listings_df = pd.read_csv("listings_final_expanded.csv")

# %%
listings_df = pd.read_csv("listings_final_expanded.csv")
property_df = pd.read_csv("property_attributes_final_expanded.csv")
agents_df = pd.read_csv("agents_cleaned.csv")
sales_df = pd.read_csv("sales_cleaned.csv")
buyers_df = pd.read_csv("buyers_cleaned.csv")
print("All csv files loaded successfully.")
# Out:
# All csv files loaded successfully.

# %%
import json
import pandas as pd

with open("listings_final_expanded.json", "r") as file:
    data = json.load(file)    #data is now a list of dictionaries

# %%
data
# Out:
# [{'Listing_ID': 'L00001',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1655144.006669635,
#   'Sqft': 2753.009121237,
#   'Date_Listed': '2023-05-06',
#   'Agent_ID': 'A0015',
#   'Latitude': 33.9652080059,
#   'Longitude': -69.8615892795},
#  {'Listing_ID': 'L00002',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1519141.0026169808,
#   'Sqft': 4966.9881928135,
#   'Date_Listed': '2023-02-14',
#   'Agent_ID': 'A0038',
#   'Latitude': 42.5478920594,
#   'Longitude': -90.2778602519},
#  {'Listing_ID': 'L00003',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 162488.9975420714,
#   'Sqft': 1267.0039591344,
#   'Date_Listed': '2023-04-22',
#   'Agent_ID': 'A0015',
#   'Latitude': 28.7323266553,
#   'Longitude': -115.9529818783},
#  {'Listing_ID': 'L00004',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 1277015.9840670894,
#   'Sqft': 2128.0144287921,
#   'Date_Listed': '2024-01-02',
#   'Agent_ID': 'A0042',
#   'Latitude': 26.4039382837,
#   'Longitude': -74.7714904573},
#  {'Listing_ID': 'L00005',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 562297.0068077513,
#   'Sqft': 4178.9974210875,
#   'Date_Listed': '2023-10-29',
#   'Agent_ID': 'A0018',
#   'Latitude': 39.4252516293,
#   'Longitude': -83.9178782667},
#  {'Listing_ID': 'L00006',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 1564104.0078713011,
#   'Sqft': 3961.992615551,
#   'Date_Listed': '2023-06-24',
#   'Agent_ID': 'A0018',
#   'Latitude': 25.4877926032,
#   'Longitude': -68.7571139192},
#  {'Listing_ID': 'L00007',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1701163.003815294,
#   'Sqft': 3257.0150616858,
#   'Date_Listed': '2023-02-22',
#   'Agent_ID': 'A0006',
#   'Latitude': 44.9691124588,
#   'Longitude': -112.6784942679},
#  {'Listing_ID': 'L00008',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 852834.0147462517,
#   'Sqft': 3316.9937214813,
#   'Date_Listed': '2023-11-06',
#   'Agent_ID': 'A0017',
#   'Latitude': 29.3549128014,
#   'Longitude': -114.3646813823},
#  {'Listing_ID': 'L00009',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 1224550.9990439962,
#   'Sqft': 1522.0077799342,
#   'Date_Listed': '2024-05-13',
#   'Agent_ID': 'A0025',
#   'Latitude': 32.3025694404,
#   'Longitude': -94.5569819185},
#  {'Listing_ID': 'L00010',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 1839386.9924549507,
#   'Sqft': 3462.0226393851,
#   'Date_Listed': '2023-10-23',
#   'Agent_ID': 'A0013',
#   'Latitude': 35.3703968658,
#   'Longitude': -108.1193181126},
#  {'Listing_ID': 'L00011',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1486768.99430001,
#   'Sqft': 2366.0004685872,
#   'Date_Listed': '2024-01-31',
#   'Agent_ID': 'A0019',
#   'Latitude': 39.6667837428,
#   'Longitude': -116.9028968424},
#  {'Listing_ID': 'L00012',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 1917147.0045034816,
#   'Sqft': 1326.9966016133,
#   'Date_Listed': '2023-07-14',
#   'Agent_ID': 'A0018',
#   'Latitude': 32.0067048962,
#   'Longitude': -103.728939014},
#  {'Listing_ID': 'L00013',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 441109.9971346703,
#   'Sqft': 3532.0009552261,
#   'Date_Listed': '2023-07-01',
#   'Agent_ID': 'A0014',
#   'Latitude': 35.9403141234,
#   'Longitude': -79.4629622952},
#  {'Listing_ID': 'L00014',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1377440.009039592,
#   'Sqft': 1900.9981292033,
#   'Date_Listed': '2023-10-01',
#   'Agent_ID': 'A0047',
#   'Latitude': 29.7726767961,
#   'Longitude': -95.1627789955},
#  {'Listing_ID': 'L00015',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1069428.9949294312,
#   'Sqft': 3607.9958386703,
#   'Date_Listed': '2023-05-19',
#   'Agent_ID': 'A0041',
#   'Latitude': 39.2149977097,
#   'Longitude': -122.2951451057},
#  {'Listing_ID': 'L00016',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 1535739.9878467089,
#   'Sqft': 3155.9855295615,
#   'Date_Listed': '2024-03-07',
#   'Agent_ID': 'A0050',
#   'Latitude': 39.5606135828,
#   'Longitude': -115.1161514064},
#  {'Listing_ID': 'L00017',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 1823443.991926888,
#   'Sqft': 761.9910429221,
#   'Date_Listed': '2024-02-17',
#   'Agent_ID': 'A0021',
#   'Latitude': 26.5653340022,
#   'Longitude': -69.9599783535},
#  {'Listing_ID': 'L00018',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 238806.9991160855,
#   'Sqft': 2228.0055864515,
#   'Date_Listed': '2024-04-12',
#   'Agent_ID': 'A0037',
#   'Latitude': 48.1698905658,
#   'Longitude': -78.1024236235},
#  {'Listing_ID': 'L00019',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1474553.9971662802,
#   'Sqft': 4588.9969614987,
#   'Date_Listed': '2023-07-22',
#   'Agent_ID': 'A0042',
#   'Latitude': 32.3174646036,
#   'Longitude': -119.3352010399},
#  {'Listing_ID': 'L00020',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 655493.0037820246,
#   'Sqft': 1642.993953628,
#   'Date_Listed': '2023-05-07',
#   'Agent_ID': 'A0048',
#   'Latitude': 41.4292958213,
#   'Longitude': -99.4574502664},
#  {'Listing_ID': 'L00021',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1666600.9895170184,
#   'Sqft': 4008.9978969856,
#   'Date_Listed': '2024-04-04',
#   'Agent_ID': 'A0038',
#   'Latitude': 27.9290898341,
#   'Longitude': -96.2830279906},
#  {'Listing_ID': 'L00022',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 559947.9922024726,
#   'Sqft': 1632.9825852231,
#   'Date_Listed': '2023-09-18',
#   'Agent_ID': 'A0032',
#   'Latitude': 25.8170831427,
#   'Longitude': -72.269854559},
#  {'Listing_ID': 'L00023',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1905862.998264031,
#   'Sqft': 1398.000161607,
#   'Date_Listed': '2023-03-20',
#   'Agent_ID': 'A0041',
#   'Latitude': 31.2208542412,
#   'Longitude': -86.5858979497},
#  {'Listing_ID': 'L00024',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1350760.0032556157,
#   'Sqft': 1019.9872054702,
#   'Date_Listed': '2023-07-17',
#   'Agent_ID': 'A0025',
#   'Latitude': 32.4753814616,
#   'Longitude': -94.8329238418},
#  {'Listing_ID': 'L00025',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1209632.9979716954,
#   'Sqft': 2558.9872529546,
#   'Date_Listed': '2024-05-12',
#   'Agent_ID': 'A0036',
#   'Latitude': 38.119584411,
#   'Longitude': -114.2548262935},
#  {'Listing_ID': 'L00026',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1529650.007746305,
#   'Sqft': 4897.9929195399,
#   'Date_Listed': '2024-01-20',
#   'Agent_ID': 'A0018',
#   'Latitude': 48.2727660384,
#   'Longitude': -80.0229214198},
#  {'Listing_ID': 'L00027',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 715514.0105212211,
#   'Sqft': 4060.995356237,
#   'Date_Listed': '2023-03-22',
#   'Agent_ID': 'A0030',
#   'Latitude': 47.5607962653,
#   'Longitude': -73.0966404624},
#  {'Listing_ID': 'L00028',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 1149805.022774446,
#   'Sqft': 1963.0086161937,
#   'Date_Listed': '2023-09-17',
#   'Agent_ID': 'A0007',
#   'Latitude': 39.3433736022,
#   'Longitude': -71.5232101841},
#  {'Listing_ID': 'L00029',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 420526.996362138,
#   'Sqft': 3562.9998182924,
#   'Date_Listed': '2024-01-26',
#   'Agent_ID': 'A0011',
#   'Latitude': 27.1258472438,
#   'Longitude': -113.6176070274},
#  {'Listing_ID': 'L00030',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 1356076.9997694592,
#   'Sqft': 3155.0195611716,
#   'Date_Listed': '2023-09-08',
#   'Agent_ID': 'A0002',
#   'Latitude': 26.0633829383,
#   'Longitude': -106.1167797261},
#  {'Listing_ID': 'L00031',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 1942813.0070935567,
#   'Sqft': 3018.992756025,
#   'Date_Listed': '2023-05-03',
#   'Agent_ID': 'A0004',
#   'Latitude': 34.3268415649,
#   'Longitude': -109.2481520153},
#  {'Listing_ID': 'L00032',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 279627.9828940844,
#   'Sqft': 4481.0033803764,
#   'Date_Listed': '2024-02-22',
#   'Agent_ID': 'A0005',
#   'Latitude': 44.8886779321,
#   'Longitude': -104.3088841328},
#  {'Listing_ID': 'L00033',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 369255.9867133461,
#   'Sqft': 4392.9944753235,
#   'Date_Listed': '2024-04-29',
#   'Agent_ID': 'A0036',
#   'Latitude': 31.7483050495,
#   'Longitude': -93.5173568229},
#  {'Listing_ID': 'L00034',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 1206612.0044058403,
#   'Sqft': 3965.9999954926,
#   'Date_Listed': '2024-05-08',
#   'Agent_ID': 'A0014',
#   'Latitude': 28.3954666469,
#   'Longitude': -78.4792978709},
#  {'Listing_ID': 'L00035',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 1595162.0022436606,
#   'Sqft': 3053.00445987,
#   'Date_Listed': '2023-07-24',
#   'Agent_ID': 'A0043',
#   'Latitude': 26.7793816313,
#   'Longitude': -67.7637654748},
#  {'Listing_ID': 'L00036',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 1986626.9982937004,
#   'Sqft': 4739.0106064016,
#   'Date_Listed': '2023-08-20',
#   'Agent_ID': 'A0008',
#   'Latitude': 43.5497248799,
#   'Longitude': -113.4803450916},
#  {'Listing_ID': 'L00037',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 234271.9905708409,
#   'Sqft': 3268.9973305329,
#   'Date_Listed': '2023-01-11',
#   'Agent_ID': 'A0038',
#   'Latitude': 25.1271935888,
#   'Longitude': -77.695743235},
#  {'Listing_ID': 'L00038',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 1334047.9847119623,
#   'Sqft': 2303.9924302756,
#   'Date_Listed': '2023-01-04',
#   'Agent_ID': 'A0005',
#   'Latitude': 41.9517778588,
#   'Longitude': -82.7296416306},
#  {'Listing_ID': 'L00039',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 241347.9937965968,
#   'Sqft': 757.0172819014,
#   'Date_Listed': '2024-03-16',
#   'Agent_ID': 'A0022',
#   'Latitude': 43.5149827054,
#   'Longitude': -120.7095220006},
#  {'Listing_ID': 'L00040',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 684009.001745823,
#   'Sqft': 4475.9849570381,
#   'Date_Listed': '2023-04-20',
#   'Agent_ID': 'A0035',
#   'Latitude': 33.6008881471,
#   'Longitude': -118.2906497446},
#  {'Listing_ID': 'L00041',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 609601.9933523665,
#   'Sqft': 4373.9867944448,
#   'Date_Listed': '2024-02-18',
#   'Agent_ID': 'A0027',
#   'Latitude': 45.7091560157,
#   'Longitude': -88.8456795944},
#  {'Listing_ID': 'L00042',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 303278.0054376267,
#   'Sqft': 4030.9858568846,
#   'Date_Listed': '2023-07-01',
#   'Agent_ID': 'A0028',
#   'Latitude': 32.9466374501,
#   'Longitude': -121.3245138112},
#  {'Listing_ID': 'L00043',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 1911596.0243525945,
#   'Sqft': 943.006286233,
#   'Date_Listed': '2023-12-11',
#   'Agent_ID': 'A0042',
#   'Latitude': 32.4683955586,
#   'Longitude': -106.1345042263},
#  {'Listing_ID': 'L00044',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 944358.0060646946,
#   'Sqft': 3278.9872164437,
#   'Date_Listed': '2024-02-14',
#   'Agent_ID': 'A0007',
#   'Latitude': 42.5015929696,
#   'Longitude': -88.0343341326},
#  {'Listing_ID': 'L00045',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 498895.9931935394,
#   'Sqft': 4892.9774985391,
#   'Date_Listed': '2023-08-18',
#   'Agent_ID': 'A0009',
#   'Latitude': 46.2983679408,
#   'Longitude': -97.6086290268},
#  {'Listing_ID': 'L00046',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 684150.9850024586,
#   'Sqft': 4289.00371231,
#   'Date_Listed': '2023-05-08',
#   'Agent_ID': 'A0005',
#   'Latitude': 27.8670510432,
#   'Longitude': -83.628569518},
#  {'Listing_ID': 'L00047',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 206090.992576832,
#   'Sqft': 4928.0180862834,
#   'Date_Listed': '2024-03-04',
#   'Agent_ID': 'A0001',
#   'Latitude': 43.2642502129,
#   'Longitude': -92.4532509955},
#  {'Listing_ID': 'L00048',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 448778.9907588365,
#   'Sqft': 3829.0255823772,
#   'Date_Listed': '2023-09-06',
#   'Agent_ID': 'A0031',
#   'Latitude': 43.4900156661,
#   'Longitude': -96.3784651134},
#  {'Listing_ID': 'L00049',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1992558.993666205,
#   'Sqft': 980.00891026,
#   'Date_Listed': '2023-03-26',
#   'Agent_ID': 'A0025',
#   'Latitude': 37.5204776701,
#   'Longitude': -100.2117923844},
#  {'Listing_ID': 'L00050',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 656170.9985995548,
#   'Sqft': 4226.9820195161,
#   'Date_Listed': '2023-05-27',
#   'Agent_ID': 'A0028',
#   'Latitude': 25.6161133735,
#   'Longitude': -118.7403679638},
#  {'Listing_ID': 'L00051',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 424631.9953986098,
#   'Sqft': 2054.993811594,
#   'Date_Listed': '2023-06-01',
#   'Agent_ID': 'A0014',
#   'Latitude': 25.761618658,
#   'Longitude': -88.0936904528},
#  {'Listing_ID': 'L00052',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1668617.9917311152,
#   'Sqft': 3069.0072975525,
#   'Date_Listed': '2023-01-30',
#   'Agent_ID': 'A0004',
#   'Latitude': 32.5388363135,
#   'Longitude': -95.5066937821},
#  {'Listing_ID': 'L00053',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1154553.014901774,
#   'Sqft': 4850.0099341646,
#   'Date_Listed': '2023-03-22',
#   'Agent_ID': 'A0004',
#   'Latitude': 46.7904185617,
#   'Longitude': -110.5505869598},
#  {'Listing_ID': 'L00054',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 1885394.0027651929,
#   'Sqft': 2021.9877856247,
#   'Date_Listed': '2023-02-05',
#   'Agent_ID': 'A0039',
#   'Latitude': 34.8462556861,
#   'Longitude': -81.1700064354},
#  {'Listing_ID': 'L00055',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 946777.9996189112,
#   'Sqft': 1482.0179235242,
#   'Date_Listed': '2024-04-27',
#   'Agent_ID': 'A0037',
#   'Latitude': 30.4651560146,
#   'Longitude': -120.5369520762},
#  {'Listing_ID': 'L00056',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1398936.992892045,
#   'Sqft': 1170.9938551099,
#   'Date_Listed': '2023-08-03',
#   'Agent_ID': 'A0043',
#   'Latitude': 31.9565278567,
#   'Longitude': -115.6480486895},
#  {'Listing_ID': 'L00057',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 646864.9940109532,
#   'Sqft': 2173.0043767088,
#   'Date_Listed': '2023-12-09',
#   'Agent_ID': 'A0046',
#   'Latitude': 47.3112410926,
#   'Longitude': -78.1135549335},
#  {'Listing_ID': 'L00058',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 657034.0069895955,
#   'Sqft': 3742.0086963294,
#   'Date_Listed': '2023-03-09',
#   'Agent_ID': 'A0043',
#   'Latitude': 40.2086204548,
#   'Longitude': -74.4404303747},
#  {'Listing_ID': 'L00059',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 763071.0083974146,
#   'Sqft': 1094.0041316585,
#   'Date_Listed': '2023-01-05',
#   'Agent_ID': 'A0030',
#   'Latitude': 44.2827353761,
#   'Longitude': -114.1803056648},
#  {'Listing_ID': 'L00060',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 253638.0102558497,
#   'Sqft': 4904.0151293379,
#   'Date_Listed': '2023-04-20',
#   'Agent_ID': 'A0033',
#   'Latitude': 46.410717685,
#   'Longitude': -93.7183101908},
#  {'Listing_ID': 'L00061',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 831924.0092601049,
#   'Sqft': 1063.0061280225,
#   'Date_Listed': '2024-03-26',
#   'Agent_ID': 'A0016',
#   'Latitude': 44.3717180983,
#   'Longitude': -73.0168938696},
#  {'Listing_ID': 'L00062',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 430818.9959883752,
#   'Sqft': 4089.0195665673,
#   'Date_Listed': '2024-03-02',
#   'Agent_ID': 'A0035',
#   'Latitude': 32.6135712144,
#   'Longitude': -118.6064141325},
#  {'Listing_ID': 'L00063',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1500609.9979459555,
#   'Sqft': 2952.009513741,
#   'Date_Listed': '2024-04-22',
#   'Agent_ID': 'A0043',
#   'Latitude': 30.4851391176,
#   'Longitude': -100.2187723825},
#  {'Listing_ID': 'L00064',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 654625.0108844107,
#   'Sqft': 1445.000395038,
#   'Date_Listed': '2024-03-31',
#   'Agent_ID': 'A0007',
#   'Latitude': 44.6358264786,
#   'Longitude': -75.0729908729},
#  {'Listing_ID': 'L00065',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 671155.0073553645,
#   'Sqft': 2807.9897481108,
#   'Date_Listed': '2023-11-06',
#   'Agent_ID': 'A0014',
#   'Latitude': 25.1796892095,
#   'Longitude': -95.3779771634},
#  {'Listing_ID': 'L00066',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1541785.005881715,
#   'Sqft': 2661.9948108116,
#   'Date_Listed': '2023-09-16',
#   'Agent_ID': 'A0032',
#   'Latitude': 35.0154780669,
#   'Longitude': -112.1028739339},
#  {'Listing_ID': 'L00067',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 293562.991705888,
#   'Sqft': 3968.9890394132,
#   'Date_Listed': '2024-02-29',
#   'Agent_ID': 'A0018',
#   'Latitude': 27.8864520562,
#   'Longitude': -105.4113724066},
#  {'Listing_ID': 'L00068',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 799517.9931058761,
#   'Sqft': 1571.0019832297,
#   'Date_Listed': '2023-11-23',
#   'Agent_ID': 'A0017',
#   'Latitude': 47.6403206866,
#   'Longitude': -106.2632255622},
#  {'Listing_ID': 'L00069',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1256957.0031506247,
#   'Sqft': 4003.0114329256,
#   'Date_Listed': '2023-10-15',
#   'Agent_ID': 'A0001',
#   'Latitude': 37.4431846551,
#   'Longitude': -84.2371076936},
#  {'Listing_ID': 'L00070',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1952008.0085800816,
#   'Sqft': 1721.0087544017,
#   'Date_Listed': '2023-10-07',
#   'Agent_ID': 'A0003',
#   'Latitude': 33.7097956441,
#   'Longitude': -68.6340529765},
#  {'Listing_ID': 'L00071',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1001328.0130720296,
#   'Sqft': 1544.016407825,
#   'Date_Listed': '2023-01-22',
#   'Agent_ID': 'A0020',
#   'Latitude': 48.0783802554,
#   'Longitude': -110.3936928378},
#  {'Listing_ID': 'L00072',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1985180.9935530408,
#   'Sqft': 3431.0139869652,
#   'Date_Listed': '2023-04-18',
#   'Agent_ID': 'A0044',
#   'Latitude': 36.9180341978,
#   'Longitude': -107.5494182588},
#  {'Listing_ID': 'L00073',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 841716.9942317429,
#   'Sqft': 3829.0164019267,
#   'Date_Listed': '2024-05-13',
#   'Agent_ID': 'A0040',
#   'Latitude': 31.8411503329,
#   'Longitude': -122.8598128376},
#  {'Listing_ID': 'L00074',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1913209.0115324676,
#   'Sqft': 1831.0142917551,
#   'Date_Listed': '2024-05-14',
#   'Agent_ID': 'A0012',
#   'Latitude': 39.6170653256,
#   'Longitude': -95.8650866912},
#  {'Listing_ID': 'L00075',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 476145.995407261,
#   'Sqft': 3220.989488528,
#   'Date_Listed': '2024-02-05',
#   'Agent_ID': 'A0027',
#   'Latitude': 26.2321069187,
#   'Longitude': -108.838532292},
#  {'Listing_ID': 'L00076',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 433862.0290331536,
#   'Sqft': 1384.9975128761,
#   'Date_Listed': '2023-07-15',
#   'Agent_ID': 'A0003',
#   'Latitude': 46.7956695919,
#   'Longitude': -111.0779120601},
#  {'Listing_ID': 'L00077',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 518534.0134712281,
#   'Sqft': 4269.994796758,
#   'Date_Listed': '2023-06-29',
#   'Agent_ID': 'A0020',
#   'Latitude': 28.4913285609,
#   'Longitude': -96.6133456793},
#  {'Listing_ID': 'L00078',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 149626.9962423429,
#   'Sqft': 2082.0069999196,
#   'Date_Listed': '2023-07-24',
#   'Agent_ID': 'A0022',
#   'Latitude': 48.6648289016,
#   'Longitude': -110.9442572349},
#  {'Listing_ID': 'L00079',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1721783.002609785,
#   'Sqft': 2786.0017747648,
#   'Date_Listed': '2023-06-29',
#   'Agent_ID': 'A0042',
#   'Latitude': 41.1255847944,
#   'Longitude': -80.8146432293},
#  {'Listing_ID': 'L00080',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1525051.9908902347,
#   'Sqft': 4892.0016418842,
#   'Date_Listed': '2023-06-19',
#   'Agent_ID': 'A0002',
#   'Latitude': 30.7021644315,
#   'Longitude': -82.7792752253},
#  {'Listing_ID': 'L00081',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 474483.0059193216,
#   'Sqft': 2674.0091474699,
#   'Date_Listed': '2023-01-20',
#   'Agent_ID': 'A0007',
#   'Latitude': 33.831788759,
#   'Longitude': -88.3319176975},
#  {'Listing_ID': 'L00082',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 824958.0019557737,
#   'Sqft': 3068.9764770344,
#   'Date_Listed': '2023-08-12',
#   'Agent_ID': 'A0039',
#   'Latitude': 40.1998435587,
#   'Longitude': -93.9231491689},
#  {'Listing_ID': 'L00083',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 907812.9961061009,
#   'Sqft': 2056.9877339818,
#   'Date_Listed': '2023-05-11',
#   'Agent_ID': 'A0003',
#   'Latitude': 27.1660279182,
#   'Longitude': -76.5359624075},
#  {'Listing_ID': 'L00084',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1190351.005028891,
#   'Sqft': 4909.9949707974,
#   'Date_Listed': '2023-12-18',
#   'Agent_ID': 'A0047',
#   'Latitude': 32.6985991509,
#   'Longitude': -114.1887685035},
#  {'Listing_ID': 'L00085',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 1004496.0048382406,
#   'Sqft': 1072.9890662084,
#   'Date_Listed': '2024-04-30',
#   'Agent_ID': 'A0043',
#   'Latitude': 25.9851710636,
#   'Longitude': -90.7365685957},
#  {'Listing_ID': 'L00086',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 1491223.99404185,
#   'Sqft': 1520.0108733925,
#   'Date_Listed': '2024-01-04',
#   'Agent_ID': 'A0020',
#   'Latitude': 41.2509898934,
#   'Longitude': -124.0377071953},
#  {'Listing_ID': 'L00087',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1498575.001661819,
#   'Sqft': 3845.0155857059,
#   'Date_Listed': '2023-06-17',
#   'Agent_ID': 'A0026',
#   'Latitude': 37.2809613151,
#   'Longitude': -111.8731909314},
#  {'Listing_ID': 'L00088',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 502316.9957604048,
#   'Sqft': 3944.0044941681,
#   'Date_Listed': '2023-12-07',
#   'Agent_ID': 'A0025',
#   'Latitude': 40.4797516464,
#   'Longitude': -114.8868085307},
#  {'Listing_ID': 'L00089',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 951601.0134466242,
#   'Sqft': 4987.9912375584,
#   'Date_Listed': '2024-03-02',
#   'Agent_ID': 'A0001',
#   'Latitude': 41.5891334092,
#   'Longitude': -102.5621469695},
#  {'Listing_ID': 'L00090',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 540784.9904388748,
#   'Sqft': 4020.997939276,
#   'Date_Listed': '2024-02-07',
#   'Agent_ID': 'A0038',
#   'Latitude': 47.4900813399,
#   'Longitude': -117.0238451143},
#  {'Listing_ID': 'L00091',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1075149.9999516662,
#   'Sqft': 4118.9890218209,
#   'Date_Listed': '2023-08-15',
#   'Agent_ID': 'A0044',
#   'Latitude': 33.1790478186,
#   'Longitude': -118.4070442306},
#  {'Listing_ID': 'L00092',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1764583.0057763518,
#   'Sqft': 1890.0005543662,
#   'Date_Listed': '2023-12-04',
#   'Agent_ID': 'A0006',
#   'Latitude': 47.1793468077,
#   'Longitude': -74.1127530736},
#  {'Listing_ID': 'L00093',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 295847.0159191616,
#   'Sqft': 2424.015155872,
#   'Date_Listed': '2023-12-11',
#   'Agent_ID': 'A0020',
#   'Latitude': 31.1945220753,
#   'Longitude': -86.7028119854},
#  {'Listing_ID': 'L00094',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 409023.0071445631,
#   'Sqft': 699.9997482566,
#   'Date_Listed': '2023-01-24',
#   'Agent_ID': 'A0016',
#   'Latitude': 44.6172960145,
#   'Longitude': -92.8004448798},
#  {'Listing_ID': 'L00095',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1055076.0157005065,
#   'Sqft': 3895.0126157492,
#   'Date_Listed': '2024-03-29',
#   'Agent_ID': 'A0041',
#   'Latitude': 37.692175107,
#   'Longitude': -110.9823337336},
#  {'Listing_ID': 'L00096',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 1606479.992708546,
#   'Sqft': 3644.9978276229,
#   'Date_Listed': '2023-09-11',
#   'Agent_ID': 'A0026',
#   'Latitude': 27.2396739905,
#   'Longitude': -72.9662032066},
#  {'Listing_ID': 'L00097',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1475853.00722883,
#   'Sqft': 545.0033141921,
#   'Date_Listed': '2024-04-02',
#   'Agent_ID': 'A0049',
#   'Latitude': 46.5879493862,
#   'Longitude': -88.2823740171},
#  {'Listing_ID': 'L00098',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 558942.9926215892,
#   'Sqft': 1939.9985998331,
#   'Date_Listed': '2024-02-16',
#   'Agent_ID': 'A0045',
#   'Latitude': 33.1282410502,
#   'Longitude': -104.7492040567},
#  {'Listing_ID': 'L00099',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 205314.9934504401,
#   'Sqft': 2541.0056200682,
#   'Date_Listed': '2024-04-14',
#   'Agent_ID': 'A0008',
#   'Latitude': 42.4166211328,
#   'Longitude': -72.9761705308},
#  {'Listing_ID': 'L00100',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 1780691.987670497,
#   'Sqft': 4305.999765798,
#   'Date_Listed': '2023-12-08',
#   'Agent_ID': 'A0034',
#   'Latitude': 46.2801888539,
#   'Longitude': -79.7565876275},
#  {'Listing_ID': 'L00101',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1683874.001859864,
#   'Sqft': 4124.9938719396,
#   'Date_Listed': '2023-11-10',
#   'Agent_ID': 'A0047',
#   'Latitude': 40.4097109332,
#   'Longitude': -120.114584994},
#  {'Listing_ID': 'L00102',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1841829.011562143,
#   'Sqft': 4988.0010717367,
#   'Date_Listed': '2023-08-17',
#   'Agent_ID': 'A0011',
#   'Latitude': 28.889570004,
#   'Longitude': -72.8802290781},
#  {'Listing_ID': 'L00103',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 643564.0040515264,
#   'Sqft': 2525.0155911217,
#   'Date_Listed': '2024-03-06',
#   'Agent_ID': 'A0041',
#   'Latitude': 39.5631084999,
#   'Longitude': -124.4550860874},
#  {'Listing_ID': 'L00104',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 1414385.999983373,
#   'Sqft': 2459.0002140629,
#   'Date_Listed': '2023-05-21',
#   'Agent_ID': 'A0029',
#   'Latitude': 27.4311389295,
#   'Longitude': -86.5136836783},
#  {'Listing_ID': 'L00105',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 591767.9878689974,
#   'Sqft': 2724.9880048664,
#   'Date_Listed': '2023-06-21',
#   'Agent_ID': 'A0021',
#   'Latitude': 25.1147124504,
#   'Longitude': -115.6697260774},
#  {'Listing_ID': 'L00106',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 390190.9955295722,
#   'Sqft': 1735.0215210846,
#   'Date_Listed': '2023-04-29',
#   'Agent_ID': 'A0025',
#   'Latitude': 38.1585249461,
#   'Longitude': -84.8711276886},
#  {'Listing_ID': 'L00107',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 234697.0071264488,
#   'Sqft': 3898.0016920104,
#   'Date_Listed': '2023-07-28',
#   'Agent_ID': 'A0022',
#   'Latitude': 40.6555077884,
#   'Longitude': -111.9987312173},
#  {'Listing_ID': 'L00108',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 971940.990455548,
#   'Sqft': 1009.9916332196,
#   'Date_Listed': '2023-04-16',
#   'Agent_ID': 'A0027',
#   'Latitude': 42.0970367332,
#   'Longitude': -111.2329992824},
#  {'Listing_ID': 'L00109',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1896696.9978714725,
#   'Sqft': 3616.0011322252,
#   'Date_Listed': '2023-09-02',
#   'Agent_ID': 'A0001',
#   'Latitude': 32.8044107749,
#   'Longitude': -81.7192514889},
#  {'Listing_ID': 'L00110',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 1680151.0067175904,
#   'Sqft': 3693.9859848346,
#   'Date_Listed': '2024-03-12',
#   'Agent_ID': 'A0027',
#   'Latitude': 40.5892742074,
#   'Longitude': -75.7345831368},
#  {'Listing_ID': 'L00111',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 1123890.9990712989,
#   'Sqft': 2296.9946207191,
#   'Date_Listed': '2023-05-20',
#   'Agent_ID': 'A0028',
#   'Latitude': 40.7813935952,
#   'Longitude': -92.0274247021},
#  {'Listing_ID': 'L00112',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 915492.0097004994,
#   'Sqft': 3252.9921276148,
#   'Date_Listed': '2023-12-09',
#   'Agent_ID': 'A0044',
#   'Latitude': 27.2434337153,
#   'Longitude': -103.6720973956},
#  {'Listing_ID': 'L00113',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 1862668.003069206,
#   'Sqft': 4328.0123523842,
#   'Date_Listed': '2024-04-15',
#   'Agent_ID': 'A0009',
#   'Latitude': 31.3490074133,
#   'Longitude': -110.8563869227},
#  {'Listing_ID': 'L00114',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 926319.9969215828,
#   'Sqft': 721.9820406736,
#   'Date_Listed': '2023-02-12',
#   'Agent_ID': 'A0042',
#   'Latitude': 48.350449704,
#   'Longitude': -102.1848510008},
#  {'Listing_ID': 'L00115',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 1917918.993257518,
#   'Sqft': 4281.9944647223,
#   'Date_Listed': '2023-04-04',
#   'Agent_ID': 'A0004',
#   'Latitude': 46.4164134858,
#   'Longitude': -88.3804900848},
#  {'Listing_ID': 'L00116',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 786508.0063288987,
#   'Sqft': 2233.0004633734,
#   'Date_Listed': '2023-08-21',
#   'Agent_ID': 'A0021',
#   'Latitude': 44.0559403811,
#   'Longitude': -95.8440769943},
#  {'Listing_ID': 'L00117',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 683546.0066851192,
#   'Sqft': 3952.9886578067,
#   'Date_Listed': '2023-05-10',
#   'Agent_ID': 'A0006',
#   'Latitude': 38.8486012985,
#   'Longitude': -96.4380424877},
#  {'Listing_ID': 'L00118',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1670816.99636856,
#   'Sqft': 4917.9886705435,
#   'Date_Listed': '2023-01-27',
#   'Agent_ID': 'A0023',
#   'Latitude': 29.6980966801,
#   'Longitude': -83.1017018149},
#  {'Listing_ID': 'L00119',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1738363.992925086,
#   'Sqft': 828.9930430389,
#   'Date_Listed': '2024-01-22',
#   'Agent_ID': 'A0002',
#   'Latitude': 31.7338374306,
#   'Longitude': -123.601931486},
#  {'Listing_ID': 'L00120',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1859990.0050224245,
#   'Sqft': 666.0093419838,
#   'Date_Listed': '2023-11-15',
#   'Agent_ID': 'A0010',
#   'Latitude': 40.4833797167,
#   'Longitude': -114.7208011246},
#  {'Listing_ID': 'L00121',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1093128.9841211091,
#   'Sqft': 1437.0063530893,
#   'Date_Listed': '2023-10-16',
#   'Agent_ID': 'A0014',
#   'Latitude': 47.5674451497,
#   'Longitude': -69.6887733145},
#  {'Listing_ID': 'L00122',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 1708300.9978369076,
#   'Sqft': 3521.0025638572,
#   'Date_Listed': '2023-03-27',
#   'Agent_ID': 'A0039',
#   'Latitude': 46.934276441,
#   'Longitude': -103.5350632926},
#  {'Listing_ID': 'L00123',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 1731146.9882662804,
#   'Sqft': 1840.9941069555,
#   'Date_Listed': '2024-05-08',
#   'Agent_ID': 'A0020',
#   'Latitude': 25.3820501303,
#   'Longitude': -71.1773627666},
#  {'Listing_ID': 'L00124',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 754221.0163723365,
#   'Sqft': 3573.9881049624,
#   'Date_Listed': '2023-07-23',
#   'Agent_ID': 'A0046',
#   'Latitude': 35.2879924641,
#   'Longitude': -68.9396352315},
#  {'Listing_ID': 'L00125',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1341718.983048268,
#   'Sqft': 2488.9788216896,
#   'Date_Listed': '2023-02-22',
#   'Agent_ID': 'A0045',
#   'Latitude': 48.1208731693,
#   'Longitude': -75.5205641853},
#  {'Listing_ID': 'L00126',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1769808.999891914,
#   'Sqft': 836.0175349973,
#   'Date_Listed': '2023-06-27',
#   'Agent_ID': 'A0035',
#   'Latitude': 32.0504053089,
#   'Longitude': -102.6854651284},
#  {'Listing_ID': 'L00127',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 244611.9881667826,
#   'Sqft': 4643.9999194837,
#   'Date_Listed': '2023-11-28',
#   'Agent_ID': 'A0022',
#   'Latitude': 45.4213331691,
#   'Longitude': -106.6071400008},
#  {'Listing_ID': 'L00128',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 1824552.0047249724,
#   'Sqft': 4515.0145671116,
#   'Date_Listed': '2023-02-24',
#   'Agent_ID': 'A0028',
#   'Latitude': 29.073848364,
#   'Longitude': -92.7017402366},
#  {'Listing_ID': 'L00129',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 1583333.011155822,
#   'Sqft': 1753.0088785937,
#   'Date_Listed': '2023-08-11',
#   'Agent_ID': 'A0012',
#   'Latitude': 47.4847897066,
#   'Longitude': -84.6297147664},
#  {'Listing_ID': 'L00130',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1391660.9869196364,
#   'Sqft': 4908.0084521431,
#   'Date_Listed': '2024-02-01',
#   'Agent_ID': 'A0031',
#   'Latitude': 38.6809516482,
#   'Longitude': -119.371389667},
#  {'Listing_ID': 'L00131',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 1831690.017183493,
#   'Sqft': 2697.9967271988,
#   'Date_Listed': '2023-06-15',
#   'Agent_ID': 'A0016',
#   'Latitude': 39.769632392,
#   'Longitude': -67.5810078667},
#  {'Listing_ID': 'L00132',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 1948914.004414438,
#   'Sqft': 4191.9838615536,
#   'Date_Listed': '2023-05-05',
#   'Agent_ID': 'A0049',
#   'Latitude': 28.3557621799,
#   'Longitude': -94.9343042336},
#  {'Listing_ID': 'L00133',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 805474.005516904,
#   'Sqft': 735.0025001099,
#   'Date_Listed': '2023-09-11',
#   'Agent_ID': 'A0021',
#   'Latitude': 46.058348461,
#   'Longitude': -82.0390349493},
#  {'Listing_ID': 'L00134',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 544846.9960472332,
#   'Sqft': 3406.0048388256,
#   'Date_Listed': '2024-02-13',
#   'Agent_ID': 'A0017',
#   'Latitude': 41.7229083068,
#   'Longitude': -84.2513172591},
#  {'Listing_ID': 'L00135',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 1946163.994673243,
#   'Sqft': 2762.9757344839,
#   'Date_Listed': '2023-10-12',
#   'Agent_ID': 'A0001',
#   'Latitude': 33.635378476,
#   'Longitude': -107.9621436571},
#  {'Listing_ID': 'L00136',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 279543.0083691963,
#   'Sqft': 2476.9951260352,
#   'Date_Listed': '2024-01-04',
#   'Agent_ID': 'A0027',
#   'Latitude': 44.4295560706,
#   'Longitude': -78.0175733102},
#  {'Listing_ID': 'L00137',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 1548311.985173564,
#   'Sqft': 4400.0153800314,
#   'Date_Listed': '2023-11-27',
#   'Agent_ID': 'A0046',
#   'Latitude': 45.8139443156,
#   'Longitude': -72.041007889},
#  {'Listing_ID': 'L00138',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 1762900.0153484598,
#   'Sqft': 641.0056100565,
#   'Date_Listed': '2023-02-17',
#   'Agent_ID': 'A0019',
#   'Latitude': 37.2682001645,
#   'Longitude': -95.924341401},
#  {'Listing_ID': 'L00139',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1550782.006308987,
#   'Sqft': 2492.9950698093,
#   'Date_Listed': '2023-06-06',
#   'Agent_ID': 'A0043',
#   'Latitude': 44.1578034097,
#   'Longitude': -87.3123756644},
#  {'Listing_ID': 'L00140',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1092499.008112562,
#   'Sqft': 4849.0037975034,
#   'Date_Listed': '2023-06-26',
#   'Agent_ID': 'A0028',
#   'Latitude': 41.8410094948,
#   'Longitude': -78.8265096041},
#  {'Listing_ID': 'L00141',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 837799.9853241607,
#   'Sqft': 4217.0059480353,
#   'Date_Listed': '2023-05-19',
#   'Agent_ID': 'A0020',
#   'Latitude': 46.3720691882,
#   'Longitude': -105.3918276109},
#  {'Listing_ID': 'L00142',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 353032.988114459,
#   'Sqft': 2076.9961876743,
#   'Date_Listed': '2023-06-11',
#   'Agent_ID': 'A0008',
#   'Latitude': 34.0023169434,
#   'Longitude': -119.5484600323},
#  {'Listing_ID': 'L00143',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 501689.9922512635,
#   'Sqft': 2272.0074382279,
#   'Date_Listed': '2024-01-14',
#   'Agent_ID': 'A0031',
#   'Latitude': 38.9153848531,
#   'Longitude': -122.928607601},
#  {'Listing_ID': 'L00144',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 310817.9905364587,
#   'Sqft': 2089.9920858076,
#   'Date_Listed': '2023-06-01',
#   'Agent_ID': 'A0015',
#   'Latitude': 36.1621660889,
#   'Longitude': -93.5188750062},
#  {'Listing_ID': 'L00145',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 733900.989744627,
#   'Sqft': 614.9941296977,
#   'Date_Listed': '2023-12-29',
#   'Agent_ID': 'A0035',
#   'Latitude': 31.8770845403,
#   'Longitude': -90.7244378799},
#  {'Listing_ID': 'L00146',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 195452.9957649919,
#   'Sqft': 946.0088972079,
#   'Date_Listed': '2023-10-11',
#   'Agent_ID': 'A0019',
#   'Latitude': 25.7277662517,
#   'Longitude': -122.8300646307},
#  {'Listing_ID': 'L00147',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 315141.003383083,
#   'Sqft': 599.9774367873,
#   'Date_Listed': '2023-10-21',
#   'Agent_ID': 'A0019',
#   'Latitude': 44.7435644435,
#   'Longitude': -104.1279367211},
#  {'Listing_ID': 'L00148',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 1023729.995398589,
#   'Sqft': 3290.9962191948,
#   'Date_Listed': '2023-04-05',
#   'Agent_ID': 'A0004',
#   'Latitude': 28.0342509903,
#   'Longitude': -94.6932441319},
#  {'Listing_ID': 'L00149',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 339258.0009425989,
#   'Sqft': 1035.0011853086,
#   'Date_Listed': '2023-07-25',
#   'Agent_ID': 'A0032',
#   'Latitude': 43.4580054443,
#   'Longitude': -112.4820138143},
#  {'Listing_ID': 'L00150',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 418193.9964981157,
#   'Sqft': 1721.9966363458,
#   'Date_Listed': '2024-02-20',
#   'Agent_ID': 'A0037',
#   'Latitude': 39.9590911694,
#   'Longitude': -120.0584445227},
#  {'Listing_ID': 'L00151',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 620493.992027613,
#   'Sqft': 1469.9954118612,
#   'Date_Listed': '2023-10-13',
#   'Agent_ID': 'A0049',
#   'Latitude': 26.2490500316,
#   'Longitude': -94.1624749075},
#  {'Listing_ID': 'L00152',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 1726747.0076456612,
#   'Sqft': 4780.0165694005,
#   'Date_Listed': '2023-07-14',
#   'Agent_ID': 'A0029',
#   'Latitude': 37.9823868223,
#   'Longitude': -88.0296254752},
#  {'Listing_ID': 'L00153',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 1903900.0072051128,
#   'Sqft': 4011.9850074864,
#   'Date_Listed': '2023-06-06',
#   'Agent_ID': 'A0037',
#   'Latitude': 42.4371623768,
#   'Longitude': -68.3958859539},
#  {'Listing_ID': 'L00154',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 1378488.0062006712,
#   'Sqft': 1312.0115043629,
#   'Date_Listed': '2024-04-30',
#   'Agent_ID': 'A0049',
#   'Latitude': 37.3940568767,
#   'Longitude': -106.2787727495},
#  {'Listing_ID': 'L00155',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 655003.0061953461,
#   'Sqft': 1165.0107414023,
#   'Date_Listed': '2023-03-22',
#   'Agent_ID': 'A0016',
#   'Latitude': 44.0962308067,
#   'Longitude': -109.2903086842},
#  {'Listing_ID': 'L00156',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 428272.0008569846,
#   'Sqft': 521.0147101443,
#   'Date_Listed': '2023-07-29',
#   'Agent_ID': 'A0029',
#   'Latitude': 35.5206030221,
#   'Longitude': -120.450352358},
#  {'Listing_ID': 'L00157',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 710815.0002094533,
#   'Sqft': 767.0051104702,
#   'Date_Listed': '2023-04-29',
#   'Agent_ID': 'A0019',
#   'Latitude': 25.6067994962,
#   'Longitude': -69.1571126041},
#  {'Listing_ID': 'L00158',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 249273.9924751899,
#   'Sqft': 2411.9963411564,
#   'Date_Listed': '2024-04-18',
#   'Agent_ID': 'A0017',
#   'Latitude': 45.0510265255,
#   'Longitude': -84.6278880688},
#  {'Listing_ID': 'L00159',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 991581.0055225646,
#   'Sqft': 1440.0047384481,
#   'Date_Listed': '2023-10-06',
#   'Agent_ID': 'A0015',
#   'Latitude': 34.816928616,
#   'Longitude': -114.9205262791},
#  {'Listing_ID': 'L00160',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 1833570.9997813185,
#   'Sqft': 1664.9962860998,
#   'Date_Listed': '2023-02-06',
#   'Agent_ID': 'A0004',
#   'Latitude': 28.7640285097,
#   'Longitude': -110.4987853303},
#  {'Listing_ID': 'L00161',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 1347896.99686003,
#   'Sqft': 2864.0004130886,
#   'Date_Listed': '2023-08-13',
#   'Agent_ID': 'A0008',
#   'Latitude': 38.1687405325,
#   'Longitude': -83.5510356536},
#  {'Listing_ID': 'L00162',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 1567446.9895700254,
#   'Sqft': 3796.9933618484,
#   'Date_Listed': '2024-04-27',
#   'Agent_ID': 'A0018',
#   'Latitude': 40.850856526,
#   'Longitude': -108.7669551048},
#  {'Listing_ID': 'L00163',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1018046.0049537058,
#   'Sqft': 1158.0109396933,
#   'Date_Listed': '2023-11-03',
#   'Agent_ID': 'A0003',
#   'Latitude': 47.9218594958,
#   'Longitude': -82.1943299212},
#  {'Listing_ID': 'L00164',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 1366079.003186405,
#   'Sqft': 2550.9828025903,
#   'Date_Listed': '2023-01-14',
#   'Agent_ID': 'A0006',
#   'Latitude': 38.3182114626,
#   'Longitude': -89.5223502124},
#  {'Listing_ID': 'L00165',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1703818.003183117,
#   'Sqft': 2707.0008491568,
#   'Date_Listed': '2023-10-23',
#   'Agent_ID': 'A0003',
#   'Latitude': 35.0780467697,
#   'Longitude': -110.632638269},
#  {'Listing_ID': 'L00166',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1188345.9901538466,
#   'Sqft': 4122.0026066789,
#   'Date_Listed': '2024-04-14',
#   'Agent_ID': 'A0018',
#   'Latitude': 33.538714333,
#   'Longitude': -81.0448162912},
#  {'Listing_ID': 'L00167',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1431239.9974813054,
#   'Sqft': 4527.9948954456,
#   'Date_Listed': '2024-05-11',
#   'Agent_ID': 'A0006',
#   'Latitude': 25.3526642133,
#   'Longitude': -118.2534386924},
#  {'Listing_ID': 'L00168',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 956367.9859890623,
#   'Sqft': 3229.9982664241,
#   'Date_Listed': '2023-06-14',
#   'Agent_ID': 'A0043',
#   'Latitude': 26.0916669237,
#   'Longitude': -122.6318436416},
#  {'Listing_ID': 'L00169',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 791647.9820828615,
#   'Sqft': 3871.996130825,
#   'Date_Listed': '2023-12-22',
#   'Agent_ID': 'A0032',
#   'Latitude': 45.5342671527,
#   'Longitude': -84.1748886311},
#  {'Listing_ID': 'L00170',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 1806171.007374076,
#   'Sqft': 799.9996016406,
#   'Date_Listed': '2023-08-21',
#   'Agent_ID': 'A0006',
#   'Latitude': 36.3787521119,
#   'Longitude': -119.3309998298},
#  {'Listing_ID': 'L00171',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 777953.995332692,
#   'Sqft': 1449.0019971998,
#   'Date_Listed': '2024-05-11',
#   'Agent_ID': 'A0050',
#   'Latitude': 36.8030908847,
#   'Longitude': -97.5513370479},
#  {'Listing_ID': 'L00172',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1479212.994860693,
#   'Sqft': 4943.9872986791,
#   'Date_Listed': '2023-08-25',
#   'Agent_ID': 'A0027',
#   'Latitude': 29.1659193422,
#   'Longitude': -99.8316307087},
#  {'Listing_ID': 'L00173',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 1187245.9968799632,
#   'Sqft': 3462.9809711946,
#   'Date_Listed': '2023-11-15',
#   'Agent_ID': 'A0049',
#   'Latitude': 34.5583533877,
#   'Longitude': -89.268483623},
#  {'Listing_ID': 'L00174',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 1693814.9837498858,
#   'Sqft': 922.0210085796,
#   'Date_Listed': '2023-04-15',
#   'Agent_ID': 'A0018',
#   'Latitude': 40.2252192248,
#   'Longitude': -122.3570687774},
#  {'Listing_ID': 'L00175',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 704039.9905547743,
#   'Sqft': 4088.9887800051,
#   'Date_Listed': '2024-03-26',
#   'Agent_ID': 'A0045',
#   'Latitude': 33.993965493,
#   'Longitude': -88.7046899684},
#  {'Listing_ID': 'L00176',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 160542.9969940059,
#   'Sqft': 2460.0006302937,
#   'Date_Listed': '2023-12-30',
#   'Agent_ID': 'A0011',
#   'Latitude': 37.0755283206,
#   'Longitude': -75.3217493578},
#  {'Listing_ID': 'L00177',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1258154.9961006443,
#   'Sqft': 3841.9866559418,
#   'Date_Listed': '2023-02-17',
#   'Agent_ID': 'A0015',
#   'Latitude': 40.8038628701,
#   'Longitude': -115.5653353711},
#  {'Listing_ID': 'L00178',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 346343.992514347,
#   'Sqft': 1761.0008742146,
#   'Date_Listed': '2023-09-13',
#   'Agent_ID': 'A0046',
#   'Latitude': 26.6842806411,
#   'Longitude': -87.73653908},
#  {'Listing_ID': 'L00179',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 971345.9937457588,
#   'Sqft': 4451.9922483236,
#   'Date_Listed': '2023-08-30',
#   'Agent_ID': 'A0016',
#   'Latitude': 25.6343010024,
#   'Longitude': -91.0358769841},
#  {'Listing_ID': 'L00180',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 904437.9895144168,
#   'Sqft': 2060.998746059,
#   'Date_Listed': '2024-04-16',
#   'Agent_ID': 'A0039',
#   'Latitude': 47.5615335108,
#   'Longitude': -91.6310753868},
#  {'Listing_ID': 'L00181',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 1911995.0108554915,
#   'Sqft': 1071.0076628309,
#   'Date_Listed': '2023-05-22',
#   'Agent_ID': 'A0050',
#   'Latitude': 34.3163301626,
#   'Longitude': -87.6832429433},
#  {'Listing_ID': 'L00182',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 1751962.9871051617,
#   'Sqft': 4659.0019457093,
#   'Date_Listed': '2023-05-17',
#   'Agent_ID': 'A0001',
#   'Latitude': 35.9949324786,
#   'Longitude': -93.3473250158},
#  {'Listing_ID': 'L00183',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 1856314.008062075,
#   'Sqft': 4511.005908282,
#   'Date_Listed': '2024-03-19',
#   'Agent_ID': 'A0010',
#   'Latitude': 47.6101088785,
#   'Longitude': -102.5842846527},
#  {'Listing_ID': 'L00184',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 823777.0072965751,
#   'Sqft': 3222.9872363382,
#   'Date_Listed': '2023-10-10',
#   'Agent_ID': 'A0049',
#   'Latitude': 48.0630527727,
#   'Longitude': -72.4865814637},
#  {'Listing_ID': 'L00185',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1054926.005769147,
#   'Sqft': 3135.988996403,
#   'Date_Listed': '2024-03-21',
#   'Agent_ID': 'A0013',
#   'Latitude': 29.7048177552,
#   'Longitude': -120.9657422502},
#  {'Listing_ID': 'L00186',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 589815.0184050994,
#   'Sqft': 3864.9910633338,
#   'Date_Listed': '2023-01-23',
#   'Agent_ID': 'A0021',
#   'Latitude': 27.4314522347,
#   'Longitude': -123.9403300552},
#  {'Listing_ID': 'L00187',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 909664.9984257128,
#   'Sqft': 1746.0017037756,
#   'Date_Listed': '2023-09-11',
#   'Agent_ID': 'A0003',
#   'Latitude': 27.2504989809,
#   'Longitude': -85.3882321411},
#  {'Listing_ID': 'L00188',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 1923892.9960054152,
#   'Sqft': 1322.0128675427,
#   'Date_Listed': '2024-03-23',
#   'Agent_ID': 'A0029',
#   'Latitude': 26.7178699445,
#   'Longitude': -106.5126063212},
#  {'Listing_ID': 'L00189',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 132185.9848896388,
#   'Sqft': 1680.0227550797,
#   'Date_Listed': '2023-07-29',
#   'Agent_ID': 'A0042',
#   'Latitude': 45.2805509059,
#   'Longitude': -123.6516959065},
#  {'Listing_ID': 'L00190',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1084592.9946077748,
#   'Sqft': 2671.0134558025,
#   'Date_Listed': '2023-06-23',
#   'Agent_ID': 'A0040',
#   'Latitude': 44.5437074357,
#   'Longitude': -108.6579479652},
#  {'Listing_ID': 'L00191',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1886281.0148641623,
#   'Sqft': 3190.9897936555,
#   'Date_Listed': '2024-03-12',
#   'Agent_ID': 'A0044',
#   'Latitude': 27.8495222882,
#   'Longitude': -84.5879563919},
#  {'Listing_ID': 'L00192',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 764085.9897658034,
#   'Sqft': 4496.9923402709,
#   'Date_Listed': '2024-03-22',
#   'Agent_ID': 'A0035',
# ...
#   'Price': 964919.0067801416,
#   'Sqft': 3392.0091771094,
#   'Date_Listed': '2023-09-22',
#   'Agent_ID': 'A0035',
#   'Latitude': 37.1300907626,
#   'Longitude': -76.2565926475},
#  {'Listing_ID': 'L00938',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 620633.0141907684,
#   'Sqft': 2853.0160768262,
#   'Date_Listed': '2023-02-17',
#   'Agent_ID': 'A0026',
#   'Latitude': 42.5972050189,
#   'Longitude': -93.5547713128},
#  {'Listing_ID': 'L00939',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1262977.9843379103,
#   'Sqft': 1962.0078490154,
#   'Date_Listed': '2023-09-01',
#   'Agent_ID': 'A0021',
#   'Latitude': 39.1635094965,
#   'Longitude': -95.5194096202},
#  {'Listing_ID': 'L00940',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1975516.9881202264,
#   'Sqft': 2703.9815495549,
#   'Date_Listed': '2023-04-04',
#   'Agent_ID': 'A0048',
#   'Latitude': 32.1321523632,
#   'Longitude': -92.2292997839},
#  {'Listing_ID': 'L00941',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1645836.0057357575,
#   'Sqft': 2135.0120715841,
#   'Date_Listed': '2023-05-01',
#   'Agent_ID': 'A0048',
#   'Latitude': 41.5444233831,
#   'Longitude': -74.3341847489},
#  {'Listing_ID': 'L00942',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 533646.0046490618,
#   'Sqft': 2377.0101478575,
#   'Date_Listed': '2023-04-14',
#   'Agent_ID': 'A0016',
#   'Latitude': 40.2619177007,
#   'Longitude': -80.858369752},
#  {'Listing_ID': 'L00943',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 427145.9974053575,
#   'Sqft': 1373.0021475001,
#   'Date_Listed': '2023-03-03',
#   'Agent_ID': 'A0006',
#   'Latitude': 28.8558317756,
#   'Longitude': -98.2290396533},
#  {'Listing_ID': 'L00944',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1702736.0018970382,
#   'Sqft': 4935.0273468111,
#   'Date_Listed': '2024-05-05',
#   'Agent_ID': 'A0003',
#   'Latitude': 25.2110493422,
#   'Longitude': -110.7023279515},
#  {'Listing_ID': 'L00945',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 1401634.013886626,
#   'Sqft': 3082.9836876234,
#   'Date_Listed': '2023-09-10',
#   'Agent_ID': 'A0037',
#   'Latitude': 42.4383294556,
#   'Longitude': -67.4802902845},
#  {'Listing_ID': 'L00946',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 483509.9969847113,
#   'Sqft': 4686.9933777804,
#   'Date_Listed': '2023-05-24',
#   'Agent_ID': 'A0026',
#   'Latitude': 27.376105721,
#   'Longitude': -101.7137309317},
#  {'Listing_ID': 'L00947',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 213555.9835785558,
#   'Sqft': 4806.0000189872,
#   'Date_Listed': '2024-02-14',
#   'Agent_ID': 'A0028',
#   'Latitude': 44.1781774124,
#   'Longitude': -113.1747888264},
#  {'Listing_ID': 'L00948',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1153765.9980649615,
#   'Sqft': 3344.0058634983,
#   'Date_Listed': '2023-07-21',
#   'Agent_ID': 'A0044',
#   'Latitude': 38.3306642572,
#   'Longitude': -82.4785068411},
#  {'Listing_ID': 'L00949',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 352429.9893361207,
#   'Sqft': 4744.9923481224,
#   'Date_Listed': '2023-08-24',
#   'Agent_ID': 'A0021',
#   'Latitude': 39.7952889743,
#   'Longitude': -114.1009923405},
#  {'Listing_ID': 'L00950',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1513695.9971862186,
#   'Sqft': 2225.9888777361,
#   'Date_Listed': '2023-07-14',
#   'Agent_ID': 'A0038',
#   'Latitude': 33.51765466,
#   'Longitude': -79.5406574507},
#  {'Listing_ID': 'L00951',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 858334.9997742043,
#   'Sqft': 2626.9905238915,
#   'Date_Listed': '2023-04-06',
#   'Agent_ID': 'A0036',
#   'Latitude': 38.3032319682,
#   'Longitude': -124.6979331029},
#  {'Listing_ID': 'L00952',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 664990.0044078121,
#   'Sqft': 4360.9978285334,
#   'Date_Listed': '2024-05-05',
#   'Agent_ID': 'A0040',
#   'Latitude': 43.2569387226,
#   'Longitude': -122.9397830843},
#  {'Listing_ID': 'L00953',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 485694.0133910609,
#   'Sqft': 4585.0114289187,
#   'Date_Listed': '2023-08-06',
#   'Agent_ID': 'A0014',
#   'Latitude': 42.8936905976,
#   'Longitude': -113.2540790691},
#  {'Listing_ID': 'L00954',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 865623.9983014852,
#   'Sqft': 3780.9854717773,
#   'Date_Listed': '2023-05-24',
#   'Agent_ID': 'A0029',
#   'Latitude': 47.9864468144,
#   'Longitude': -103.6570990546},
#  {'Listing_ID': 'L00955',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1307733.997753278,
#   'Sqft': 2372.0021594962,
#   'Date_Listed': '2024-02-21',
#   'Agent_ID': 'A0007',
#   'Latitude': 32.8293403466,
#   'Longitude': -116.361950379},
#  {'Listing_ID': 'L00956',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1264631.978945778,
#   'Sqft': 4040.0120715125,
#   'Date_Listed': '2024-03-14',
#   'Agent_ID': 'A0025',
#   'Latitude': 32.3423134635,
#   'Longitude': -74.14886639},
#  {'Listing_ID': 'L00957',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1777800.0050071063,
#   'Sqft': 1724.9870504007,
#   'Date_Listed': '2023-08-31',
#   'Agent_ID': 'A0001',
#   'Latitude': 48.8960699987,
#   'Longitude': -103.6429627537},
#  {'Listing_ID': 'L00958',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1147731.9944066731,
#   'Sqft': 1601.018864826,
#   'Date_Listed': '2024-04-02',
#   'Agent_ID': 'A0041',
#   'Latitude': 35.7757858844,
#   'Longitude': -83.1259225582},
#  {'Listing_ID': 'L00959',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1746961.9922643765,
#   'Sqft': 4486.009742466,
#   'Date_Listed': '2023-06-03',
#   'Agent_ID': 'A0017',
#   'Latitude': 46.2489579332,
#   'Longitude': -90.5793263747},
#  {'Listing_ID': 'L00960',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 935508.9998543868,
#   'Sqft': 1310.0114722962,
#   'Date_Listed': '2023-12-20',
#   'Agent_ID': 'A0011',
#   'Latitude': 34.401946062,
#   'Longitude': -101.0625565517},
#  {'Listing_ID': 'L00961',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 1806699.99913556,
#   'Sqft': 2583.002947765,
#   'Date_Listed': '2023-09-01',
#   'Agent_ID': 'A0041',
#   'Latitude': 41.689859335,
#   'Longitude': -124.8158322709},
#  {'Listing_ID': 'L00962',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 1661525.0109190564,
#   'Sqft': 3240.9988245537,
#   'Date_Listed': '2023-05-14',
#   'Agent_ID': 'A0024',
#   'Latitude': 39.8635816288,
#   'Longitude': -104.3804356834},
#  {'Listing_ID': 'L00963',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 821713.9859258013,
#   'Sqft': 661.9841554829,
#   'Date_Listed': '2023-07-30',
#   'Agent_ID': 'A0008',
#   'Latitude': 44.057993422,
#   'Longitude': -119.6028797493},
#  {'Listing_ID': 'L00964',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1309750.0051606174,
#   'Sqft': 4910.0166016003,
#   'Date_Listed': '2023-03-31',
#   'Agent_ID': 'A0050',
#   'Latitude': 39.1177412991,
#   'Longitude': -97.0959521477},
#  {'Listing_ID': 'L00965',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 781763.005413031,
#   'Sqft': 4681.0041338398,
#   'Date_Listed': '2023-09-07',
#   'Agent_ID': 'A0050',
#   'Latitude': 40.4098279217,
#   'Longitude': -121.2313259717},
#  {'Listing_ID': 'L00966',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 899162.9932455958,
#   'Sqft': 2847.0116348508,
#   'Date_Listed': '2023-08-26',
#   'Agent_ID': 'A0041',
#   'Latitude': 38.9312472922,
#   'Longitude': -92.4313827764},
#  {'Listing_ID': 'L00967',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1443394.0027831136,
#   'Sqft': 3262.9974825532,
#   'Date_Listed': '2023-08-04',
#   'Agent_ID': 'A0041',
#   'Latitude': 38.4347662204,
#   'Longitude': -90.0110652905},
#  {'Listing_ID': 'L00968',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1880272.989946864,
#   'Sqft': 1083.998473513,
#   'Date_Listed': '2023-02-10',
#   'Agent_ID': 'A0011',
#   'Latitude': 41.2378470236,
#   'Longitude': -78.3099956172},
#  {'Listing_ID': 'L00969',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 757419.011173733,
#   'Sqft': 3095.0108932753,
#   'Date_Listed': '2023-12-01',
#   'Agent_ID': 'A0019',
#   'Latitude': 31.4926143193,
#   'Longitude': -77.1440242555},
#  {'Listing_ID': 'L00970',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 668847.9941677155,
#   'Sqft': 4143.9703796491,
#   'Date_Listed': '2024-02-04',
#   'Agent_ID': 'A0024',
#   'Latitude': 36.942350514,
#   'Longitude': -120.5197961426},
#  {'Listing_ID': 'L00971',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 968196.9922811488,
#   'Sqft': 1870.0032413284,
#   'Date_Listed': '2023-04-05',
#   'Agent_ID': 'A0002',
#   'Latitude': 26.4060364785,
#   'Longitude': -105.6133743855},
#  {'Listing_ID': 'L00972',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1488361.0077013418,
#   'Sqft': 2560.9811224679,
#   'Date_Listed': '2024-04-26',
#   'Agent_ID': 'A0048',
#   'Latitude': 43.8396507123,
#   'Longitude': -83.9599272928},
#  {'Listing_ID': 'L00973',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 450036.0140659073,
#   'Sqft': 3752.0261565588,
#   'Date_Listed': '2023-02-22',
#   'Agent_ID': 'A0007',
#   'Latitude': 43.9168638639,
#   'Longitude': -94.9968396188},
#  {'Listing_ID': 'L00974',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 1250148.008073223,
#   'Sqft': 940.0090940936,
#   'Date_Listed': '2023-01-14',
#   'Agent_ID': 'A0050',
#   'Latitude': 35.5591965368,
#   'Longitude': -116.4561997353},
#  {'Listing_ID': 'L00975',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 317952.9987282446,
#   'Sqft': 2649.9830312266,
#   'Date_Listed': '2023-11-13',
#   'Agent_ID': 'A0010',
#   'Latitude': 32.8683664498,
#   'Longitude': -99.8346550665},
#  {'Listing_ID': 'L00976',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 748797.0057511086,
#   'Sqft': 2378.0048822281,
#   'Date_Listed': '2023-05-07',
#   'Agent_ID': 'A0048',
#   'Latitude': 27.1400224617,
#   'Longitude': -112.216323944},
#  {'Listing_ID': 'L00977',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 1413825.0125863503,
#   'Sqft': 1535.0005133768,
#   'Date_Listed': '2023-03-09',
#   'Agent_ID': 'A0034',
#   'Latitude': 39.3774717313,
#   'Longitude': -82.3280462827},
#  {'Listing_ID': 'L00978',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 173725.0109242742,
#   'Sqft': 3423.0094823005,
#   'Date_Listed': '2024-03-16',
#   'Agent_ID': 'A0021',
#   'Latitude': 48.9655703368,
#   'Longitude': -70.8829029965},
#  {'Listing_ID': 'L00979',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 1926406.0030180956,
#   'Sqft': 4928.0070680532,
#   'Date_Listed': '2024-04-23',
#   'Agent_ID': 'A0018',
#   'Latitude': 40.4208374141,
#   'Longitude': -100.5730975753},
#  {'Listing_ID': 'L00980',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 383355.9949518397,
#   'Sqft': 4916.9840181707,
#   'Date_Listed': '2023-04-01',
#   'Agent_ID': 'A0038',
#   'Latitude': 40.2437317291,
#   'Longitude': -79.4367462682},
#  {'Listing_ID': 'L00981',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1423401.9928277023,
#   'Sqft': 4063.0071250191,
#   'Date_Listed': '2023-09-26',
#   'Agent_ID': 'A0041',
#   'Latitude': 27.8350008609,
#   'Longitude': -101.2185289732},
#  {'Listing_ID': 'L00982',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 828063.9967323261,
#   'Sqft': 4444.9899891958,
#   'Date_Listed': '2023-10-04',
#   'Agent_ID': 'A0015',
#   'Latitude': 45.1337568273,
#   'Longitude': -102.7325267388},
#  {'Listing_ID': 'L00983',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 745645.9947900687,
#   'Sqft': 3495.9925332838,
#   'Date_Listed': '2023-07-31',
#   'Agent_ID': 'A0017',
#   'Latitude': 38.7177590309,
#   'Longitude': -90.8986984457},
#  {'Listing_ID': 'L00984',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 122137.0108102742,
#   'Sqft': 500.0055860929,
#   'Date_Listed': '2023-09-25',
#   'Agent_ID': 'A0049',
#   'Latitude': 29.4363477067,
#   'Longitude': -104.0026911428},
#  {'Listing_ID': 'L00985',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 701383.9889024157,
#   'Sqft': 4343.0060644523,
#   'Date_Listed': '2023-10-01',
#   'Agent_ID': 'A0001',
#   'Latitude': 33.0237510748,
#   'Longitude': -123.4916638055},
#  {'Listing_ID': 'L00986',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 728327.9968834742,
#   'Sqft': 573.9811634925,
#   'Date_Listed': '2024-01-28',
#   'Agent_ID': 'A0028',
#   'Latitude': 25.5674306149,
#   'Longitude': -76.7579407278},
#  {'Listing_ID': 'L00987',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1770942.0052828873,
#   'Sqft': 558.9931124412,
#   'Date_Listed': '2023-10-08',
#   'Agent_ID': 'A0024',
#   'Latitude': 31.5601371951,
#   'Longitude': -94.9586149098},
#  {'Listing_ID': 'L00988',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1950026.99476192,
#   'Sqft': 4079.9964088476,
#   'Date_Listed': '2023-07-22',
#   'Agent_ID': 'A0016',
#   'Latitude': 32.1818501615,
#   'Longitude': -70.4225559254},
#  {'Listing_ID': 'L00989',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1837336.9863553816,
#   'Sqft': 3599.0215016817,
#   'Date_Listed': '2023-04-23',
#   'Agent_ID': 'A0017',
#   'Latitude': 31.2379801992,
#   'Longitude': -100.1003361525},
#  {'Listing_ID': 'L00990',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 1411396.9961362106,
#   'Sqft': 2461.9974057224,
#   'Date_Listed': '2023-09-22',
#   'Agent_ID': 'A0049',
#   'Latitude': 45.9376820863,
#   'Longitude': -76.1642816109},
#  {'Listing_ID': 'L00991',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 697010.0106800384,
#   'Sqft': 4857.0044600116,
#   'Date_Listed': '2024-02-19',
#   'Agent_ID': 'A0018',
#   'Latitude': 29.4775811145,
#   'Longitude': -78.4482736538},
#  {'Listing_ID': 'L00992',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 1889881.0164037675,
#   'Sqft': 1060.0042890779,
#   'Date_Listed': '2023-04-04',
#   'Agent_ID': 'A0009',
#   'Latitude': 35.9900877803,
#   'Longitude': -96.9901703087},
#  {'Listing_ID': 'L00993',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1435660.0026373651,
#   'Sqft': 4229.9822425921,
#   'Date_Listed': '2023-11-13',
#   'Agent_ID': 'A0029',
#   'Latitude': 28.2173963511,
#   'Longitude': -120.3311961632},
#  {'Listing_ID': 'L00994',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 493823.0001776781,
#   'Sqft': 3126.0088278405,
#   'Date_Listed': '2023-01-10',
#   'Agent_ID': 'A0010',
#   'Latitude': 42.4642321811,
#   'Longitude': -96.2085503498},
#  {'Listing_ID': 'L00995',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 489939.0088256518,
#   'Sqft': 1336.9908316814,
#   'Date_Listed': '2023-05-25',
#   'Agent_ID': 'A0018',
#   'Latitude': 35.4973099608,
#   'Longitude': -82.6894732655},
#  {'Listing_ID': 'L00996',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1624854.0002587065,
#   'Sqft': 567.0096022477,
#   'Date_Listed': '2023-04-30',
#   'Agent_ID': 'A0006',
#   'Latitude': 43.3606229414,
#   'Longitude': -115.7858996916},
#  {'Listing_ID': 'L00997',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1135111.0026554707,
#   'Sqft': 2278.9898291761,
#   'Date_Listed': '2023-06-25',
#   'Agent_ID': 'A0027',
#   'Latitude': 39.64818569,
#   'Longitude': -117.1449386306},
#  {'Listing_ID': 'L00998',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 878875.9970625386,
#   'Sqft': 4298.0121147898,
#   'Date_Listed': '2023-12-23',
#   'Agent_ID': 'A0003',
#   'Latitude': 43.0483481799,
#   'Longitude': -86.8972497875},
#  {'Listing_ID': 'L00999',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1869044.0016598515,
#   'Sqft': 1695.9742255388,
#   'Date_Listed': '2023-01-29',
#   'Agent_ID': 'A0018',
#   'Latitude': 47.953587212,
#   'Longitude': -120.9983509497},
#  {'Listing_ID': 'L01000',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1239155.9899416547,
#   'Sqft': 4350.9979926603,
#   'Date_Listed': '2023-04-03',
#   'Agent_ID': 'A0013',
#   'Latitude': 26.353020661,
#   'Longitude': -108.6323269324},
#  ...]

# %% [markdown]
# STEP 1: Read JSON Data (Python)

# %%
import pandas as pd

# Read JSON files
listings_df = pd.read_json("listings_final_expanded.json")
property_df = pd.read_json("property_attributes_final_expanded.json")
agents_df = pd.read_json("agents_cleaned.json")
sales_df = pd.read_json("sales_cleaned.json")
buyers_df = pd.read_json("buyers_cleaned.json")

# %%
listings_df.head()

# %%
property_df.head(10)

# %%
import json
import pandas as pd

with open("listings_final_expanded.json", "r") as file:
    data = json.load(file)    #data is now a list of dictionaries

# %%
data
# Out:
# [{'Listing_ID': 'L00001',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1655144.006669635,
#   'Sqft': 2753.009121237,
#   'Date_Listed': '2023-05-06',
#   'Agent_ID': 'A0015',
#   'Latitude': 33.9652080059,
#   'Longitude': -69.8615892795},
#  {'Listing_ID': 'L00002',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1519141.0026169808,
#   'Sqft': 4966.9881928135,
#   'Date_Listed': '2023-02-14',
#   'Agent_ID': 'A0038',
#   'Latitude': 42.5478920594,
#   'Longitude': -90.2778602519},
#  {'Listing_ID': 'L00003',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 162488.9975420714,
#   'Sqft': 1267.0039591344,
#   'Date_Listed': '2023-04-22',
#   'Agent_ID': 'A0015',
#   'Latitude': 28.7323266553,
#   'Longitude': -115.9529818783},
#  {'Listing_ID': 'L00004',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 1277015.9840670894,
#   'Sqft': 2128.0144287921,
#   'Date_Listed': '2024-01-02',
#   'Agent_ID': 'A0042',
#   'Latitude': 26.4039382837,
#   'Longitude': -74.7714904573},
#  {'Listing_ID': 'L00005',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 562297.0068077513,
#   'Sqft': 4178.9974210875,
#   'Date_Listed': '2023-10-29',
#   'Agent_ID': 'A0018',
#   'Latitude': 39.4252516293,
#   'Longitude': -83.9178782667},
#  {'Listing_ID': 'L00006',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 1564104.0078713011,
#   'Sqft': 3961.992615551,
#   'Date_Listed': '2023-06-24',
#   'Agent_ID': 'A0018',
#   'Latitude': 25.4877926032,
#   'Longitude': -68.7571139192},
#  {'Listing_ID': 'L00007',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1701163.003815294,
#   'Sqft': 3257.0150616858,
#   'Date_Listed': '2023-02-22',
#   'Agent_ID': 'A0006',
#   'Latitude': 44.9691124588,
#   'Longitude': -112.6784942679},
#  {'Listing_ID': 'L00008',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 852834.0147462517,
#   'Sqft': 3316.9937214813,
#   'Date_Listed': '2023-11-06',
#   'Agent_ID': 'A0017',
#   'Latitude': 29.3549128014,
#   'Longitude': -114.3646813823},
#  {'Listing_ID': 'L00009',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 1224550.9990439962,
#   'Sqft': 1522.0077799342,
#   'Date_Listed': '2024-05-13',
#   'Agent_ID': 'A0025',
#   'Latitude': 32.3025694404,
#   'Longitude': -94.5569819185},
#  {'Listing_ID': 'L00010',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 1839386.9924549507,
#   'Sqft': 3462.0226393851,
#   'Date_Listed': '2023-10-23',
#   'Agent_ID': 'A0013',
#   'Latitude': 35.3703968658,
#   'Longitude': -108.1193181126},
#  {'Listing_ID': 'L00011',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1486768.99430001,
#   'Sqft': 2366.0004685872,
#   'Date_Listed': '2024-01-31',
#   'Agent_ID': 'A0019',
#   'Latitude': 39.6667837428,
#   'Longitude': -116.9028968424},
#  {'Listing_ID': 'L00012',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 1917147.0045034816,
#   'Sqft': 1326.9966016133,
#   'Date_Listed': '2023-07-14',
#   'Agent_ID': 'A0018',
#   'Latitude': 32.0067048962,
#   'Longitude': -103.728939014},
#  {'Listing_ID': 'L00013',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 441109.9971346703,
#   'Sqft': 3532.0009552261,
#   'Date_Listed': '2023-07-01',
#   'Agent_ID': 'A0014',
#   'Latitude': 35.9403141234,
#   'Longitude': -79.4629622952},
#  {'Listing_ID': 'L00014',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1377440.009039592,
#   'Sqft': 1900.9981292033,
#   'Date_Listed': '2023-10-01',
#   'Agent_ID': 'A0047',
#   'Latitude': 29.7726767961,
#   'Longitude': -95.1627789955},
#  {'Listing_ID': 'L00015',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1069428.9949294312,
#   'Sqft': 3607.9958386703,
#   'Date_Listed': '2023-05-19',
#   'Agent_ID': 'A0041',
#   'Latitude': 39.2149977097,
#   'Longitude': -122.2951451057},
#  {'Listing_ID': 'L00016',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 1535739.9878467089,
#   'Sqft': 3155.9855295615,
#   'Date_Listed': '2024-03-07',
#   'Agent_ID': 'A0050',
#   'Latitude': 39.5606135828,
#   'Longitude': -115.1161514064},
#  {'Listing_ID': 'L00017',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 1823443.991926888,
#   'Sqft': 761.9910429221,
#   'Date_Listed': '2024-02-17',
#   'Agent_ID': 'A0021',
#   'Latitude': 26.5653340022,
#   'Longitude': -69.9599783535},
#  {'Listing_ID': 'L00018',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 238806.9991160855,
#   'Sqft': 2228.0055864515,
#   'Date_Listed': '2024-04-12',
#   'Agent_ID': 'A0037',
#   'Latitude': 48.1698905658,
#   'Longitude': -78.1024236235},
#  {'Listing_ID': 'L00019',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1474553.9971662802,
#   'Sqft': 4588.9969614987,
#   'Date_Listed': '2023-07-22',
#   'Agent_ID': 'A0042',
#   'Latitude': 32.3174646036,
#   'Longitude': -119.3352010399},
#  {'Listing_ID': 'L00020',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 655493.0037820246,
#   'Sqft': 1642.993953628,
#   'Date_Listed': '2023-05-07',
#   'Agent_ID': 'A0048',
#   'Latitude': 41.4292958213,
#   'Longitude': -99.4574502664},
#  {'Listing_ID': 'L00021',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1666600.9895170184,
#   'Sqft': 4008.9978969856,
#   'Date_Listed': '2024-04-04',
#   'Agent_ID': 'A0038',
#   'Latitude': 27.9290898341,
#   'Longitude': -96.2830279906},
#  {'Listing_ID': 'L00022',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 559947.9922024726,
#   'Sqft': 1632.9825852231,
#   'Date_Listed': '2023-09-18',
#   'Agent_ID': 'A0032',
#   'Latitude': 25.8170831427,
#   'Longitude': -72.269854559},
#  {'Listing_ID': 'L00023',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1905862.998264031,
#   'Sqft': 1398.000161607,
#   'Date_Listed': '2023-03-20',
#   'Agent_ID': 'A0041',
#   'Latitude': 31.2208542412,
#   'Longitude': -86.5858979497},
#  {'Listing_ID': 'L00024',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1350760.0032556157,
#   'Sqft': 1019.9872054702,
#   'Date_Listed': '2023-07-17',
#   'Agent_ID': 'A0025',
#   'Latitude': 32.4753814616,
#   'Longitude': -94.8329238418},
#  {'Listing_ID': 'L00025',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1209632.9979716954,
#   'Sqft': 2558.9872529546,
#   'Date_Listed': '2024-05-12',
#   'Agent_ID': 'A0036',
#   'Latitude': 38.119584411,
#   'Longitude': -114.2548262935},
#  {'Listing_ID': 'L00026',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1529650.007746305,
#   'Sqft': 4897.9929195399,
#   'Date_Listed': '2024-01-20',
#   'Agent_ID': 'A0018',
#   'Latitude': 48.2727660384,
#   'Longitude': -80.0229214198},
#  {'Listing_ID': 'L00027',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 715514.0105212211,
#   'Sqft': 4060.995356237,
#   'Date_Listed': '2023-03-22',
#   'Agent_ID': 'A0030',
#   'Latitude': 47.5607962653,
#   'Longitude': -73.0966404624},
#  {'Listing_ID': 'L00028',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 1149805.022774446,
#   'Sqft': 1963.0086161937,
#   'Date_Listed': '2023-09-17',
#   'Agent_ID': 'A0007',
#   'Latitude': 39.3433736022,
#   'Longitude': -71.5232101841},
#  {'Listing_ID': 'L00029',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 420526.996362138,
#   'Sqft': 3562.9998182924,
#   'Date_Listed': '2024-01-26',
#   'Agent_ID': 'A0011',
#   'Latitude': 27.1258472438,
#   'Longitude': -113.6176070274},
#  {'Listing_ID': 'L00030',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 1356076.9997694592,
#   'Sqft': 3155.0195611716,
#   'Date_Listed': '2023-09-08',
#   'Agent_ID': 'A0002',
#   'Latitude': 26.0633829383,
#   'Longitude': -106.1167797261},
#  {'Listing_ID': 'L00031',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 1942813.0070935567,
#   'Sqft': 3018.992756025,
#   'Date_Listed': '2023-05-03',
#   'Agent_ID': 'A0004',
#   'Latitude': 34.3268415649,
#   'Longitude': -109.2481520153},
#  {'Listing_ID': 'L00032',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 279627.9828940844,
#   'Sqft': 4481.0033803764,
#   'Date_Listed': '2024-02-22',
#   'Agent_ID': 'A0005',
#   'Latitude': 44.8886779321,
#   'Longitude': -104.3088841328},
#  {'Listing_ID': 'L00033',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 369255.9867133461,
#   'Sqft': 4392.9944753235,
#   'Date_Listed': '2024-04-29',
#   'Agent_ID': 'A0036',
#   'Latitude': 31.7483050495,
#   'Longitude': -93.5173568229},
#  {'Listing_ID': 'L00034',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 1206612.0044058403,
#   'Sqft': 3965.9999954926,
#   'Date_Listed': '2024-05-08',
#   'Agent_ID': 'A0014',
#   'Latitude': 28.3954666469,
#   'Longitude': -78.4792978709},
#  {'Listing_ID': 'L00035',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 1595162.0022436606,
#   'Sqft': 3053.00445987,
#   'Date_Listed': '2023-07-24',
#   'Agent_ID': 'A0043',
#   'Latitude': 26.7793816313,
#   'Longitude': -67.7637654748},
#  {'Listing_ID': 'L00036',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 1986626.9982937004,
#   'Sqft': 4739.0106064016,
#   'Date_Listed': '2023-08-20',
#   'Agent_ID': 'A0008',
#   'Latitude': 43.5497248799,
#   'Longitude': -113.4803450916},
#  {'Listing_ID': 'L00037',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 234271.9905708409,
#   'Sqft': 3268.9973305329,
#   'Date_Listed': '2023-01-11',
#   'Agent_ID': 'A0038',
#   'Latitude': 25.1271935888,
#   'Longitude': -77.695743235},
#  {'Listing_ID': 'L00038',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 1334047.9847119623,
#   'Sqft': 2303.9924302756,
#   'Date_Listed': '2023-01-04',
#   'Agent_ID': 'A0005',
#   'Latitude': 41.9517778588,
#   'Longitude': -82.7296416306},
#  {'Listing_ID': 'L00039',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 241347.9937965968,
#   'Sqft': 757.0172819014,
#   'Date_Listed': '2024-03-16',
#   'Agent_ID': 'A0022',
#   'Latitude': 43.5149827054,
#   'Longitude': -120.7095220006},
#  {'Listing_ID': 'L00040',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 684009.001745823,
#   'Sqft': 4475.9849570381,
#   'Date_Listed': '2023-04-20',
#   'Agent_ID': 'A0035',
#   'Latitude': 33.6008881471,
#   'Longitude': -118.2906497446},
#  {'Listing_ID': 'L00041',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 609601.9933523665,
#   'Sqft': 4373.9867944448,
#   'Date_Listed': '2024-02-18',
#   'Agent_ID': 'A0027',
#   'Latitude': 45.7091560157,
#   'Longitude': -88.8456795944},
#  {'Listing_ID': 'L00042',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 303278.0054376267,
#   'Sqft': 4030.9858568846,
#   'Date_Listed': '2023-07-01',
#   'Agent_ID': 'A0028',
#   'Latitude': 32.9466374501,
#   'Longitude': -121.3245138112},
#  {'Listing_ID': 'L00043',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 1911596.0243525945,
#   'Sqft': 943.006286233,
#   'Date_Listed': '2023-12-11',
#   'Agent_ID': 'A0042',
#   'Latitude': 32.4683955586,
#   'Longitude': -106.1345042263},
#  {'Listing_ID': 'L00044',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 944358.0060646946,
#   'Sqft': 3278.9872164437,
#   'Date_Listed': '2024-02-14',
#   'Agent_ID': 'A0007',
#   'Latitude': 42.5015929696,
#   'Longitude': -88.0343341326},
#  {'Listing_ID': 'L00045',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 498895.9931935394,
#   'Sqft': 4892.9774985391,
#   'Date_Listed': '2023-08-18',
#   'Agent_ID': 'A0009',
#   'Latitude': 46.2983679408,
#   'Longitude': -97.6086290268},
#  {'Listing_ID': 'L00046',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 684150.9850024586,
#   'Sqft': 4289.00371231,
#   'Date_Listed': '2023-05-08',
#   'Agent_ID': 'A0005',
#   'Latitude': 27.8670510432,
#   'Longitude': -83.628569518},
#  {'Listing_ID': 'L00047',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 206090.992576832,
#   'Sqft': 4928.0180862834,
#   'Date_Listed': '2024-03-04',
#   'Agent_ID': 'A0001',
#   'Latitude': 43.2642502129,
#   'Longitude': -92.4532509955},
#  {'Listing_ID': 'L00048',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 448778.9907588365,
#   'Sqft': 3829.0255823772,
#   'Date_Listed': '2023-09-06',
#   'Agent_ID': 'A0031',
#   'Latitude': 43.4900156661,
#   'Longitude': -96.3784651134},
#  {'Listing_ID': 'L00049',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1992558.993666205,
#   'Sqft': 980.00891026,
#   'Date_Listed': '2023-03-26',
#   'Agent_ID': 'A0025',
#   'Latitude': 37.5204776701,
#   'Longitude': -100.2117923844},
#  {'Listing_ID': 'L00050',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 656170.9985995548,
#   'Sqft': 4226.9820195161,
#   'Date_Listed': '2023-05-27',
#   'Agent_ID': 'A0028',
#   'Latitude': 25.6161133735,
#   'Longitude': -118.7403679638},
#  {'Listing_ID': 'L00051',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 424631.9953986098,
#   'Sqft': 2054.993811594,
#   'Date_Listed': '2023-06-01',
#   'Agent_ID': 'A0014',
#   'Latitude': 25.761618658,
#   'Longitude': -88.0936904528},
#  {'Listing_ID': 'L00052',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1668617.9917311152,
#   'Sqft': 3069.0072975525,
#   'Date_Listed': '2023-01-30',
#   'Agent_ID': 'A0004',
#   'Latitude': 32.5388363135,
#   'Longitude': -95.5066937821},
#  {'Listing_ID': 'L00053',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1154553.014901774,
#   'Sqft': 4850.0099341646,
#   'Date_Listed': '2023-03-22',
#   'Agent_ID': 'A0004',
#   'Latitude': 46.7904185617,
#   'Longitude': -110.5505869598},
#  {'Listing_ID': 'L00054',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 1885394.0027651929,
#   'Sqft': 2021.9877856247,
#   'Date_Listed': '2023-02-05',
#   'Agent_ID': 'A0039',
#   'Latitude': 34.8462556861,
#   'Longitude': -81.1700064354},
#  {'Listing_ID': 'L00055',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 946777.9996189112,
#   'Sqft': 1482.0179235242,
#   'Date_Listed': '2024-04-27',
#   'Agent_ID': 'A0037',
#   'Latitude': 30.4651560146,
#   'Longitude': -120.5369520762},
#  {'Listing_ID': 'L00056',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1398936.992892045,
#   'Sqft': 1170.9938551099,
#   'Date_Listed': '2023-08-03',
#   'Agent_ID': 'A0043',
#   'Latitude': 31.9565278567,
#   'Longitude': -115.6480486895},
#  {'Listing_ID': 'L00057',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 646864.9940109532,
#   'Sqft': 2173.0043767088,
#   'Date_Listed': '2023-12-09',
#   'Agent_ID': 'A0046',
#   'Latitude': 47.3112410926,
#   'Longitude': -78.1135549335},
#  {'Listing_ID': 'L00058',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 657034.0069895955,
#   'Sqft': 3742.0086963294,
#   'Date_Listed': '2023-03-09',
#   'Agent_ID': 'A0043',
#   'Latitude': 40.2086204548,
#   'Longitude': -74.4404303747},
#  {'Listing_ID': 'L00059',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 763071.0083974146,
#   'Sqft': 1094.0041316585,
#   'Date_Listed': '2023-01-05',
#   'Agent_ID': 'A0030',
#   'Latitude': 44.2827353761,
#   'Longitude': -114.1803056648},
#  {'Listing_ID': 'L00060',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 253638.0102558497,
#   'Sqft': 4904.0151293379,
#   'Date_Listed': '2023-04-20',
#   'Agent_ID': 'A0033',
#   'Latitude': 46.410717685,
#   'Longitude': -93.7183101908},
#  {'Listing_ID': 'L00061',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 831924.0092601049,
#   'Sqft': 1063.0061280225,
#   'Date_Listed': '2024-03-26',
#   'Agent_ID': 'A0016',
#   'Latitude': 44.3717180983,
#   'Longitude': -73.0168938696},
#  {'Listing_ID': 'L00062',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 430818.9959883752,
#   'Sqft': 4089.0195665673,
#   'Date_Listed': '2024-03-02',
#   'Agent_ID': 'A0035',
#   'Latitude': 32.6135712144,
#   'Longitude': -118.6064141325},
#  {'Listing_ID': 'L00063',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1500609.9979459555,
#   'Sqft': 2952.009513741,
#   'Date_Listed': '2024-04-22',
#   'Agent_ID': 'A0043',
#   'Latitude': 30.4851391176,
#   'Longitude': -100.2187723825},
#  {'Listing_ID': 'L00064',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 654625.0108844107,
#   'Sqft': 1445.000395038,
#   'Date_Listed': '2024-03-31',
#   'Agent_ID': 'A0007',
#   'Latitude': 44.6358264786,
#   'Longitude': -75.0729908729},
#  {'Listing_ID': 'L00065',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 671155.0073553645,
#   'Sqft': 2807.9897481108,
#   'Date_Listed': '2023-11-06',
#   'Agent_ID': 'A0014',
#   'Latitude': 25.1796892095,
#   'Longitude': -95.3779771634},
#  {'Listing_ID': 'L00066',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1541785.005881715,
#   'Sqft': 2661.9948108116,
#   'Date_Listed': '2023-09-16',
#   'Agent_ID': 'A0032',
#   'Latitude': 35.0154780669,
#   'Longitude': -112.1028739339},
#  {'Listing_ID': 'L00067',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 293562.991705888,
#   'Sqft': 3968.9890394132,
#   'Date_Listed': '2024-02-29',
#   'Agent_ID': 'A0018',
#   'Latitude': 27.8864520562,
#   'Longitude': -105.4113724066},
#  {'Listing_ID': 'L00068',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 799517.9931058761,
#   'Sqft': 1571.0019832297,
#   'Date_Listed': '2023-11-23',
#   'Agent_ID': 'A0017',
#   'Latitude': 47.6403206866,
#   'Longitude': -106.2632255622},
#  {'Listing_ID': 'L00069',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1256957.0031506247,
#   'Sqft': 4003.0114329256,
#   'Date_Listed': '2023-10-15',
#   'Agent_ID': 'A0001',
#   'Latitude': 37.4431846551,
#   'Longitude': -84.2371076936},
#  {'Listing_ID': 'L00070',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1952008.0085800816,
#   'Sqft': 1721.0087544017,
#   'Date_Listed': '2023-10-07',
#   'Agent_ID': 'A0003',
#   'Latitude': 33.7097956441,
#   'Longitude': -68.6340529765},
#  {'Listing_ID': 'L00071',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1001328.0130720296,
#   'Sqft': 1544.016407825,
#   'Date_Listed': '2023-01-22',
#   'Agent_ID': 'A0020',
#   'Latitude': 48.0783802554,
#   'Longitude': -110.3936928378},
#  {'Listing_ID': 'L00072',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1985180.9935530408,
#   'Sqft': 3431.0139869652,
#   'Date_Listed': '2023-04-18',
#   'Agent_ID': 'A0044',
#   'Latitude': 36.9180341978,
#   'Longitude': -107.5494182588},
#  {'Listing_ID': 'L00073',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 841716.9942317429,
#   'Sqft': 3829.0164019267,
#   'Date_Listed': '2024-05-13',
#   'Agent_ID': 'A0040',
#   'Latitude': 31.8411503329,
#   'Longitude': -122.8598128376},
#  {'Listing_ID': 'L00074',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1913209.0115324676,
#   'Sqft': 1831.0142917551,
#   'Date_Listed': '2024-05-14',
#   'Agent_ID': 'A0012',
#   'Latitude': 39.6170653256,
#   'Longitude': -95.8650866912},
#  {'Listing_ID': 'L00075',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 476145.995407261,
#   'Sqft': 3220.989488528,
#   'Date_Listed': '2024-02-05',
#   'Agent_ID': 'A0027',
#   'Latitude': 26.2321069187,
#   'Longitude': -108.838532292},
#  {'Listing_ID': 'L00076',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 433862.0290331536,
#   'Sqft': 1384.9975128761,
#   'Date_Listed': '2023-07-15',
#   'Agent_ID': 'A0003',
#   'Latitude': 46.7956695919,
#   'Longitude': -111.0779120601},
#  {'Listing_ID': 'L00077',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 518534.0134712281,
#   'Sqft': 4269.994796758,
#   'Date_Listed': '2023-06-29',
#   'Agent_ID': 'A0020',
#   'Latitude': 28.4913285609,
#   'Longitude': -96.6133456793},
#  {'Listing_ID': 'L00078',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 149626.9962423429,
#   'Sqft': 2082.0069999196,
#   'Date_Listed': '2023-07-24',
#   'Agent_ID': 'A0022',
#   'Latitude': 48.6648289016,
#   'Longitude': -110.9442572349},
#  {'Listing_ID': 'L00079',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1721783.002609785,
#   'Sqft': 2786.0017747648,
#   'Date_Listed': '2023-06-29',
#   'Agent_ID': 'A0042',
#   'Latitude': 41.1255847944,
#   'Longitude': -80.8146432293},
#  {'Listing_ID': 'L00080',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1525051.9908902347,
#   'Sqft': 4892.0016418842,
#   'Date_Listed': '2023-06-19',
#   'Agent_ID': 'A0002',
#   'Latitude': 30.7021644315,
#   'Longitude': -82.7792752253},
#  {'Listing_ID': 'L00081',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 474483.0059193216,
#   'Sqft': 2674.0091474699,
#   'Date_Listed': '2023-01-20',
#   'Agent_ID': 'A0007',
#   'Latitude': 33.831788759,
#   'Longitude': -88.3319176975},
#  {'Listing_ID': 'L00082',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 824958.0019557737,
#   'Sqft': 3068.9764770344,
#   'Date_Listed': '2023-08-12',
#   'Agent_ID': 'A0039',
#   'Latitude': 40.1998435587,
#   'Longitude': -93.9231491689},
#  {'Listing_ID': 'L00083',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 907812.9961061009,
#   'Sqft': 2056.9877339818,
#   'Date_Listed': '2023-05-11',
#   'Agent_ID': 'A0003',
#   'Latitude': 27.1660279182,
#   'Longitude': -76.5359624075},
#  {'Listing_ID': 'L00084',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1190351.005028891,
#   'Sqft': 4909.9949707974,
#   'Date_Listed': '2023-12-18',
#   'Agent_ID': 'A0047',
#   'Latitude': 32.6985991509,
#   'Longitude': -114.1887685035},
#  {'Listing_ID': 'L00085',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 1004496.0048382406,
#   'Sqft': 1072.9890662084,
#   'Date_Listed': '2024-04-30',
#   'Agent_ID': 'A0043',
#   'Latitude': 25.9851710636,
#   'Longitude': -90.7365685957},
#  {'Listing_ID': 'L00086',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 1491223.99404185,
#   'Sqft': 1520.0108733925,
#   'Date_Listed': '2024-01-04',
#   'Agent_ID': 'A0020',
#   'Latitude': 41.2509898934,
#   'Longitude': -124.0377071953},
#  {'Listing_ID': 'L00087',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1498575.001661819,
#   'Sqft': 3845.0155857059,
#   'Date_Listed': '2023-06-17',
#   'Agent_ID': 'A0026',
#   'Latitude': 37.2809613151,
#   'Longitude': -111.8731909314},
#  {'Listing_ID': 'L00088',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 502316.9957604048,
#   'Sqft': 3944.0044941681,
#   'Date_Listed': '2023-12-07',
#   'Agent_ID': 'A0025',
#   'Latitude': 40.4797516464,
#   'Longitude': -114.8868085307},
#  {'Listing_ID': 'L00089',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 951601.0134466242,
#   'Sqft': 4987.9912375584,
#   'Date_Listed': '2024-03-02',
#   'Agent_ID': 'A0001',
#   'Latitude': 41.5891334092,
#   'Longitude': -102.5621469695},
#  {'Listing_ID': 'L00090',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 540784.9904388748,
#   'Sqft': 4020.997939276,
#   'Date_Listed': '2024-02-07',
#   'Agent_ID': 'A0038',
#   'Latitude': 47.4900813399,
#   'Longitude': -117.0238451143},
#  {'Listing_ID': 'L00091',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1075149.9999516662,
#   'Sqft': 4118.9890218209,
#   'Date_Listed': '2023-08-15',
#   'Agent_ID': 'A0044',
#   'Latitude': 33.1790478186,
#   'Longitude': -118.4070442306},
#  {'Listing_ID': 'L00092',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1764583.0057763518,
#   'Sqft': 1890.0005543662,
#   'Date_Listed': '2023-12-04',
#   'Agent_ID': 'A0006',
#   'Latitude': 47.1793468077,
#   'Longitude': -74.1127530736},
#  {'Listing_ID': 'L00093',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 295847.0159191616,
#   'Sqft': 2424.015155872,
#   'Date_Listed': '2023-12-11',
#   'Agent_ID': 'A0020',
#   'Latitude': 31.1945220753,
#   'Longitude': -86.7028119854},
#  {'Listing_ID': 'L00094',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 409023.0071445631,
#   'Sqft': 699.9997482566,
#   'Date_Listed': '2023-01-24',
#   'Agent_ID': 'A0016',
#   'Latitude': 44.6172960145,
#   'Longitude': -92.8004448798},
#  {'Listing_ID': 'L00095',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1055076.0157005065,
#   'Sqft': 3895.0126157492,
#   'Date_Listed': '2024-03-29',
#   'Agent_ID': 'A0041',
#   'Latitude': 37.692175107,
#   'Longitude': -110.9823337336},
#  {'Listing_ID': 'L00096',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 1606479.992708546,
#   'Sqft': 3644.9978276229,
#   'Date_Listed': '2023-09-11',
#   'Agent_ID': 'A0026',
#   'Latitude': 27.2396739905,
#   'Longitude': -72.9662032066},
#  {'Listing_ID': 'L00097',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1475853.00722883,
#   'Sqft': 545.0033141921,
#   'Date_Listed': '2024-04-02',
#   'Agent_ID': 'A0049',
#   'Latitude': 46.5879493862,
#   'Longitude': -88.2823740171},
#  {'Listing_ID': 'L00098',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 558942.9926215892,
#   'Sqft': 1939.9985998331,
#   'Date_Listed': '2024-02-16',
#   'Agent_ID': 'A0045',
#   'Latitude': 33.1282410502,
#   'Longitude': -104.7492040567},
#  {'Listing_ID': 'L00099',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 205314.9934504401,
#   'Sqft': 2541.0056200682,
#   'Date_Listed': '2024-04-14',
#   'Agent_ID': 'A0008',
#   'Latitude': 42.4166211328,
#   'Longitude': -72.9761705308},
#  {'Listing_ID': 'L00100',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 1780691.987670497,
#   'Sqft': 4305.999765798,
#   'Date_Listed': '2023-12-08',
#   'Agent_ID': 'A0034',
#   'Latitude': 46.2801888539,
#   'Longitude': -79.7565876275},
#  {'Listing_ID': 'L00101',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1683874.001859864,
#   'Sqft': 4124.9938719396,
#   'Date_Listed': '2023-11-10',
#   'Agent_ID': 'A0047',
#   'Latitude': 40.4097109332,
#   'Longitude': -120.114584994},
#  {'Listing_ID': 'L00102',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1841829.011562143,
#   'Sqft': 4988.0010717367,
#   'Date_Listed': '2023-08-17',
#   'Agent_ID': 'A0011',
#   'Latitude': 28.889570004,
#   'Longitude': -72.8802290781},
#  {'Listing_ID': 'L00103',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 643564.0040515264,
#   'Sqft': 2525.0155911217,
#   'Date_Listed': '2024-03-06',
#   'Agent_ID': 'A0041',
#   'Latitude': 39.5631084999,
#   'Longitude': -124.4550860874},
#  {'Listing_ID': 'L00104',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 1414385.999983373,
#   'Sqft': 2459.0002140629,
#   'Date_Listed': '2023-05-21',
#   'Agent_ID': 'A0029',
#   'Latitude': 27.4311389295,
#   'Longitude': -86.5136836783},
#  {'Listing_ID': 'L00105',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 591767.9878689974,
#   'Sqft': 2724.9880048664,
#   'Date_Listed': '2023-06-21',
#   'Agent_ID': 'A0021',
#   'Latitude': 25.1147124504,
#   'Longitude': -115.6697260774},
#  {'Listing_ID': 'L00106',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 390190.9955295722,
#   'Sqft': 1735.0215210846,
#   'Date_Listed': '2023-04-29',
#   'Agent_ID': 'A0025',
#   'Latitude': 38.1585249461,
#   'Longitude': -84.8711276886},
#  {'Listing_ID': 'L00107',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 234697.0071264488,
#   'Sqft': 3898.0016920104,
#   'Date_Listed': '2023-07-28',
#   'Agent_ID': 'A0022',
#   'Latitude': 40.6555077884,
#   'Longitude': -111.9987312173},
#  {'Listing_ID': 'L00108',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 971940.990455548,
#   'Sqft': 1009.9916332196,
#   'Date_Listed': '2023-04-16',
#   'Agent_ID': 'A0027',
#   'Latitude': 42.0970367332,
#   'Longitude': -111.2329992824},
#  {'Listing_ID': 'L00109',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1896696.9978714725,
#   'Sqft': 3616.0011322252,
#   'Date_Listed': '2023-09-02',
#   'Agent_ID': 'A0001',
#   'Latitude': 32.8044107749,
#   'Longitude': -81.7192514889},
#  {'Listing_ID': 'L00110',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 1680151.0067175904,
#   'Sqft': 3693.9859848346,
#   'Date_Listed': '2024-03-12',
#   'Agent_ID': 'A0027',
#   'Latitude': 40.5892742074,
#   'Longitude': -75.7345831368},
#  {'Listing_ID': 'L00111',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 1123890.9990712989,
#   'Sqft': 2296.9946207191,
#   'Date_Listed': '2023-05-20',
#   'Agent_ID': 'A0028',
#   'Latitude': 40.7813935952,
#   'Longitude': -92.0274247021},
#  {'Listing_ID': 'L00112',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 915492.0097004994,
#   'Sqft': 3252.9921276148,
#   'Date_Listed': '2023-12-09',
#   'Agent_ID': 'A0044',
#   'Latitude': 27.2434337153,
#   'Longitude': -103.6720973956},
#  {'Listing_ID': 'L00113',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 1862668.003069206,
#   'Sqft': 4328.0123523842,
#   'Date_Listed': '2024-04-15',
#   'Agent_ID': 'A0009',
#   'Latitude': 31.3490074133,
#   'Longitude': -110.8563869227},
#  {'Listing_ID': 'L00114',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 926319.9969215828,
#   'Sqft': 721.9820406736,
#   'Date_Listed': '2023-02-12',
#   'Agent_ID': 'A0042',
#   'Latitude': 48.350449704,
#   'Longitude': -102.1848510008},
#  {'Listing_ID': 'L00115',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 1917918.993257518,
#   'Sqft': 4281.9944647223,
#   'Date_Listed': '2023-04-04',
#   'Agent_ID': 'A0004',
#   'Latitude': 46.4164134858,
#   'Longitude': -88.3804900848},
#  {'Listing_ID': 'L00116',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 786508.0063288987,
#   'Sqft': 2233.0004633734,
#   'Date_Listed': '2023-08-21',
#   'Agent_ID': 'A0021',
#   'Latitude': 44.0559403811,
#   'Longitude': -95.8440769943},
#  {'Listing_ID': 'L00117',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 683546.0066851192,
#   'Sqft': 3952.9886578067,
#   'Date_Listed': '2023-05-10',
#   'Agent_ID': 'A0006',
#   'Latitude': 38.8486012985,
#   'Longitude': -96.4380424877},
#  {'Listing_ID': 'L00118',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1670816.99636856,
#   'Sqft': 4917.9886705435,
#   'Date_Listed': '2023-01-27',
#   'Agent_ID': 'A0023',
#   'Latitude': 29.6980966801,
#   'Longitude': -83.1017018149},
#  {'Listing_ID': 'L00119',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1738363.992925086,
#   'Sqft': 828.9930430389,
#   'Date_Listed': '2024-01-22',
#   'Agent_ID': 'A0002',
#   'Latitude': 31.7338374306,
#   'Longitude': -123.601931486},
#  {'Listing_ID': 'L00120',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1859990.0050224245,
#   'Sqft': 666.0093419838,
#   'Date_Listed': '2023-11-15',
#   'Agent_ID': 'A0010',
#   'Latitude': 40.4833797167,
#   'Longitude': -114.7208011246},
#  {'Listing_ID': 'L00121',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1093128.9841211091,
#   'Sqft': 1437.0063530893,
#   'Date_Listed': '2023-10-16',
#   'Agent_ID': 'A0014',
#   'Latitude': 47.5674451497,
#   'Longitude': -69.6887733145},
#  {'Listing_ID': 'L00122',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 1708300.9978369076,
#   'Sqft': 3521.0025638572,
#   'Date_Listed': '2023-03-27',
#   'Agent_ID': 'A0039',
#   'Latitude': 46.934276441,
#   'Longitude': -103.5350632926},
#  {'Listing_ID': 'L00123',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 1731146.9882662804,
#   'Sqft': 1840.9941069555,
#   'Date_Listed': '2024-05-08',
#   'Agent_ID': 'A0020',
#   'Latitude': 25.3820501303,
#   'Longitude': -71.1773627666},
#  {'Listing_ID': 'L00124',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 754221.0163723365,
#   'Sqft': 3573.9881049624,
#   'Date_Listed': '2023-07-23',
#   'Agent_ID': 'A0046',
#   'Latitude': 35.2879924641,
#   'Longitude': -68.9396352315},
#  {'Listing_ID': 'L00125',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1341718.983048268,
#   'Sqft': 2488.9788216896,
#   'Date_Listed': '2023-02-22',
#   'Agent_ID': 'A0045',
#   'Latitude': 48.1208731693,
#   'Longitude': -75.5205641853},
#  {'Listing_ID': 'L00126',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1769808.999891914,
#   'Sqft': 836.0175349973,
#   'Date_Listed': '2023-06-27',
#   'Agent_ID': 'A0035',
#   'Latitude': 32.0504053089,
#   'Longitude': -102.6854651284},
#  {'Listing_ID': 'L00127',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 244611.9881667826,
#   'Sqft': 4643.9999194837,
#   'Date_Listed': '2023-11-28',
#   'Agent_ID': 'A0022',
#   'Latitude': 45.4213331691,
#   'Longitude': -106.6071400008},
#  {'Listing_ID': 'L00128',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 1824552.0047249724,
#   'Sqft': 4515.0145671116,
#   'Date_Listed': '2023-02-24',
#   'Agent_ID': 'A0028',
#   'Latitude': 29.073848364,
#   'Longitude': -92.7017402366},
#  {'Listing_ID': 'L00129',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 1583333.011155822,
#   'Sqft': 1753.0088785937,
#   'Date_Listed': '2023-08-11',
#   'Agent_ID': 'A0012',
#   'Latitude': 47.4847897066,
#   'Longitude': -84.6297147664},
#  {'Listing_ID': 'L00130',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1391660.9869196364,
#   'Sqft': 4908.0084521431,
#   'Date_Listed': '2024-02-01',
#   'Agent_ID': 'A0031',
#   'Latitude': 38.6809516482,
#   'Longitude': -119.371389667},
#  {'Listing_ID': 'L00131',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 1831690.017183493,
#   'Sqft': 2697.9967271988,
#   'Date_Listed': '2023-06-15',
#   'Agent_ID': 'A0016',
#   'Latitude': 39.769632392,
#   'Longitude': -67.5810078667},
#  {'Listing_ID': 'L00132',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 1948914.004414438,
#   'Sqft': 4191.9838615536,
#   'Date_Listed': '2023-05-05',
#   'Agent_ID': 'A0049',
#   'Latitude': 28.3557621799,
#   'Longitude': -94.9343042336},
#  {'Listing_ID': 'L00133',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 805474.005516904,
#   'Sqft': 735.0025001099,
#   'Date_Listed': '2023-09-11',
#   'Agent_ID': 'A0021',
#   'Latitude': 46.058348461,
#   'Longitude': -82.0390349493},
#  {'Listing_ID': 'L00134',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 544846.9960472332,
#   'Sqft': 3406.0048388256,
#   'Date_Listed': '2024-02-13',
#   'Agent_ID': 'A0017',
#   'Latitude': 41.7229083068,
#   'Longitude': -84.2513172591},
#  {'Listing_ID': 'L00135',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 1946163.994673243,
#   'Sqft': 2762.9757344839,
#   'Date_Listed': '2023-10-12',
#   'Agent_ID': 'A0001',
#   'Latitude': 33.635378476,
#   'Longitude': -107.9621436571},
#  {'Listing_ID': 'L00136',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 279543.0083691963,
#   'Sqft': 2476.9951260352,
#   'Date_Listed': '2024-01-04',
#   'Agent_ID': 'A0027',
#   'Latitude': 44.4295560706,
#   'Longitude': -78.0175733102},
#  {'Listing_ID': 'L00137',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 1548311.985173564,
#   'Sqft': 4400.0153800314,
#   'Date_Listed': '2023-11-27',
#   'Agent_ID': 'A0046',
#   'Latitude': 45.8139443156,
#   'Longitude': -72.041007889},
#  {'Listing_ID': 'L00138',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 1762900.0153484598,
#   'Sqft': 641.0056100565,
#   'Date_Listed': '2023-02-17',
#   'Agent_ID': 'A0019',
#   'Latitude': 37.2682001645,
#   'Longitude': -95.924341401},
#  {'Listing_ID': 'L00139',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1550782.006308987,
#   'Sqft': 2492.9950698093,
#   'Date_Listed': '2023-06-06',
#   'Agent_ID': 'A0043',
#   'Latitude': 44.1578034097,
#   'Longitude': -87.3123756644},
#  {'Listing_ID': 'L00140',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1092499.008112562,
#   'Sqft': 4849.0037975034,
#   'Date_Listed': '2023-06-26',
#   'Agent_ID': 'A0028',
#   'Latitude': 41.8410094948,
#   'Longitude': -78.8265096041},
#  {'Listing_ID': 'L00141',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 837799.9853241607,
#   'Sqft': 4217.0059480353,
#   'Date_Listed': '2023-05-19',
#   'Agent_ID': 'A0020',
#   'Latitude': 46.3720691882,
#   'Longitude': -105.3918276109},
#  {'Listing_ID': 'L00142',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 353032.988114459,
#   'Sqft': 2076.9961876743,
#   'Date_Listed': '2023-06-11',
#   'Agent_ID': 'A0008',
#   'Latitude': 34.0023169434,
#   'Longitude': -119.5484600323},
#  {'Listing_ID': 'L00143',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 501689.9922512635,
#   'Sqft': 2272.0074382279,
#   'Date_Listed': '2024-01-14',
#   'Agent_ID': 'A0031',
#   'Latitude': 38.9153848531,
#   'Longitude': -122.928607601},
#  {'Listing_ID': 'L00144',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 310817.9905364587,
#   'Sqft': 2089.9920858076,
#   'Date_Listed': '2023-06-01',
#   'Agent_ID': 'A0015',
#   'Latitude': 36.1621660889,
#   'Longitude': -93.5188750062},
#  {'Listing_ID': 'L00145',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 733900.989744627,
#   'Sqft': 614.9941296977,
#   'Date_Listed': '2023-12-29',
#   'Agent_ID': 'A0035',
#   'Latitude': 31.8770845403,
#   'Longitude': -90.7244378799},
#  {'Listing_ID': 'L00146',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 195452.9957649919,
#   'Sqft': 946.0088972079,
#   'Date_Listed': '2023-10-11',
#   'Agent_ID': 'A0019',
#   'Latitude': 25.7277662517,
#   'Longitude': -122.8300646307},
#  {'Listing_ID': 'L00147',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 315141.003383083,
#   'Sqft': 599.9774367873,
#   'Date_Listed': '2023-10-21',
#   'Agent_ID': 'A0019',
#   'Latitude': 44.7435644435,
#   'Longitude': -104.1279367211},
#  {'Listing_ID': 'L00148',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 1023729.995398589,
#   'Sqft': 3290.9962191948,
#   'Date_Listed': '2023-04-05',
#   'Agent_ID': 'A0004',
#   'Latitude': 28.0342509903,
#   'Longitude': -94.6932441319},
#  {'Listing_ID': 'L00149',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 339258.0009425989,
#   'Sqft': 1035.0011853086,
#   'Date_Listed': '2023-07-25',
#   'Agent_ID': 'A0032',
#   'Latitude': 43.4580054443,
#   'Longitude': -112.4820138143},
#  {'Listing_ID': 'L00150',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 418193.9964981157,
#   'Sqft': 1721.9966363458,
#   'Date_Listed': '2024-02-20',
#   'Agent_ID': 'A0037',
#   'Latitude': 39.9590911694,
#   'Longitude': -120.0584445227},
#  {'Listing_ID': 'L00151',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 620493.992027613,
#   'Sqft': 1469.9954118612,
#   'Date_Listed': '2023-10-13',
#   'Agent_ID': 'A0049',
#   'Latitude': 26.2490500316,
#   'Longitude': -94.1624749075},
#  {'Listing_ID': 'L00152',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 1726747.0076456612,
#   'Sqft': 4780.0165694005,
#   'Date_Listed': '2023-07-14',
#   'Agent_ID': 'A0029',
#   'Latitude': 37.9823868223,
#   'Longitude': -88.0296254752},
#  {'Listing_ID': 'L00153',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 1903900.0072051128,
#   'Sqft': 4011.9850074864,
#   'Date_Listed': '2023-06-06',
#   'Agent_ID': 'A0037',
#   'Latitude': 42.4371623768,
#   'Longitude': -68.3958859539},
#  {'Listing_ID': 'L00154',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 1378488.0062006712,
#   'Sqft': 1312.0115043629,
#   'Date_Listed': '2024-04-30',
#   'Agent_ID': 'A0049',
#   'Latitude': 37.3940568767,
#   'Longitude': -106.2787727495},
#  {'Listing_ID': 'L00155',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 655003.0061953461,
#   'Sqft': 1165.0107414023,
#   'Date_Listed': '2023-03-22',
#   'Agent_ID': 'A0016',
#   'Latitude': 44.0962308067,
#   'Longitude': -109.2903086842},
#  {'Listing_ID': 'L00156',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 428272.0008569846,
#   'Sqft': 521.0147101443,
#   'Date_Listed': '2023-07-29',
#   'Agent_ID': 'A0029',
#   'Latitude': 35.5206030221,
#   'Longitude': -120.450352358},
#  {'Listing_ID': 'L00157',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 710815.0002094533,
#   'Sqft': 767.0051104702,
#   'Date_Listed': '2023-04-29',
#   'Agent_ID': 'A0019',
#   'Latitude': 25.6067994962,
#   'Longitude': -69.1571126041},
#  {'Listing_ID': 'L00158',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 249273.9924751899,
#   'Sqft': 2411.9963411564,
#   'Date_Listed': '2024-04-18',
#   'Agent_ID': 'A0017',
#   'Latitude': 45.0510265255,
#   'Longitude': -84.6278880688},
#  {'Listing_ID': 'L00159',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 991581.0055225646,
#   'Sqft': 1440.0047384481,
#   'Date_Listed': '2023-10-06',
#   'Agent_ID': 'A0015',
#   'Latitude': 34.816928616,
#   'Longitude': -114.9205262791},
#  {'Listing_ID': 'L00160',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 1833570.9997813185,
#   'Sqft': 1664.9962860998,
#   'Date_Listed': '2023-02-06',
#   'Agent_ID': 'A0004',
#   'Latitude': 28.7640285097,
#   'Longitude': -110.4987853303},
#  {'Listing_ID': 'L00161',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 1347896.99686003,
#   'Sqft': 2864.0004130886,
#   'Date_Listed': '2023-08-13',
#   'Agent_ID': 'A0008',
#   'Latitude': 38.1687405325,
#   'Longitude': -83.5510356536},
#  {'Listing_ID': 'L00162',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 1567446.9895700254,
#   'Sqft': 3796.9933618484,
#   'Date_Listed': '2024-04-27',
#   'Agent_ID': 'A0018',
#   'Latitude': 40.850856526,
#   'Longitude': -108.7669551048},
#  {'Listing_ID': 'L00163',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1018046.0049537058,
#   'Sqft': 1158.0109396933,
#   'Date_Listed': '2023-11-03',
#   'Agent_ID': 'A0003',
#   'Latitude': 47.9218594958,
#   'Longitude': -82.1943299212},
#  {'Listing_ID': 'L00164',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 1366079.003186405,
#   'Sqft': 2550.9828025903,
#   'Date_Listed': '2023-01-14',
#   'Agent_ID': 'A0006',
#   'Latitude': 38.3182114626,
#   'Longitude': -89.5223502124},
#  {'Listing_ID': 'L00165',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1703818.003183117,
#   'Sqft': 2707.0008491568,
#   'Date_Listed': '2023-10-23',
#   'Agent_ID': 'A0003',
#   'Latitude': 35.0780467697,
#   'Longitude': -110.632638269},
#  {'Listing_ID': 'L00166',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1188345.9901538466,
#   'Sqft': 4122.0026066789,
#   'Date_Listed': '2024-04-14',
#   'Agent_ID': 'A0018',
#   'Latitude': 33.538714333,
#   'Longitude': -81.0448162912},
#  {'Listing_ID': 'L00167',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1431239.9974813054,
#   'Sqft': 4527.9948954456,
#   'Date_Listed': '2024-05-11',
#   'Agent_ID': 'A0006',
#   'Latitude': 25.3526642133,
#   'Longitude': -118.2534386924},
#  {'Listing_ID': 'L00168',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 956367.9859890623,
#   'Sqft': 3229.9982664241,
#   'Date_Listed': '2023-06-14',
#   'Agent_ID': 'A0043',
#   'Latitude': 26.0916669237,
#   'Longitude': -122.6318436416},
#  {'Listing_ID': 'L00169',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 791647.9820828615,
#   'Sqft': 3871.996130825,
#   'Date_Listed': '2023-12-22',
#   'Agent_ID': 'A0032',
#   'Latitude': 45.5342671527,
#   'Longitude': -84.1748886311},
#  {'Listing_ID': 'L00170',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 1806171.007374076,
#   'Sqft': 799.9996016406,
#   'Date_Listed': '2023-08-21',
#   'Agent_ID': 'A0006',
#   'Latitude': 36.3787521119,
#   'Longitude': -119.3309998298},
#  {'Listing_ID': 'L00171',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 777953.995332692,
#   'Sqft': 1449.0019971998,
#   'Date_Listed': '2024-05-11',
#   'Agent_ID': 'A0050',
#   'Latitude': 36.8030908847,
#   'Longitude': -97.5513370479},
#  {'Listing_ID': 'L00172',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1479212.994860693,
#   'Sqft': 4943.9872986791,
#   'Date_Listed': '2023-08-25',
#   'Agent_ID': 'A0027',
#   'Latitude': 29.1659193422,
#   'Longitude': -99.8316307087},
#  {'Listing_ID': 'L00173',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 1187245.9968799632,
#   'Sqft': 3462.9809711946,
#   'Date_Listed': '2023-11-15',
#   'Agent_ID': 'A0049',
#   'Latitude': 34.5583533877,
#   'Longitude': -89.268483623},
#  {'Listing_ID': 'L00174',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 1693814.9837498858,
#   'Sqft': 922.0210085796,
#   'Date_Listed': '2023-04-15',
#   'Agent_ID': 'A0018',
#   'Latitude': 40.2252192248,
#   'Longitude': -122.3570687774},
#  {'Listing_ID': 'L00175',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 704039.9905547743,
#   'Sqft': 4088.9887800051,
#   'Date_Listed': '2024-03-26',
#   'Agent_ID': 'A0045',
#   'Latitude': 33.993965493,
#   'Longitude': -88.7046899684},
#  {'Listing_ID': 'L00176',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 160542.9969940059,
#   'Sqft': 2460.0006302937,
#   'Date_Listed': '2023-12-30',
#   'Agent_ID': 'A0011',
#   'Latitude': 37.0755283206,
#   'Longitude': -75.3217493578},
#  {'Listing_ID': 'L00177',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1258154.9961006443,
#   'Sqft': 3841.9866559418,
#   'Date_Listed': '2023-02-17',
#   'Agent_ID': 'A0015',
#   'Latitude': 40.8038628701,
#   'Longitude': -115.5653353711},
#  {'Listing_ID': 'L00178',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 346343.992514347,
#   'Sqft': 1761.0008742146,
#   'Date_Listed': '2023-09-13',
#   'Agent_ID': 'A0046',
#   'Latitude': 26.6842806411,
#   'Longitude': -87.73653908},
#  {'Listing_ID': 'L00179',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 971345.9937457588,
#   'Sqft': 4451.9922483236,
#   'Date_Listed': '2023-08-30',
#   'Agent_ID': 'A0016',
#   'Latitude': 25.6343010024,
#   'Longitude': -91.0358769841},
#  {'Listing_ID': 'L00180',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 904437.9895144168,
#   'Sqft': 2060.998746059,
#   'Date_Listed': '2024-04-16',
#   'Agent_ID': 'A0039',
#   'Latitude': 47.5615335108,
#   'Longitude': -91.6310753868},
#  {'Listing_ID': 'L00181',
#   'City': 'Phoenix',
#   'Property_Type': 'House',
#   'Price': 1911995.0108554915,
#   'Sqft': 1071.0076628309,
#   'Date_Listed': '2023-05-22',
#   'Agent_ID': 'A0050',
#   'Latitude': 34.3163301626,
#   'Longitude': -87.6832429433},
#  {'Listing_ID': 'L00182',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 1751962.9871051617,
#   'Sqft': 4659.0019457093,
#   'Date_Listed': '2023-05-17',
#   'Agent_ID': 'A0001',
#   'Latitude': 35.9949324786,
#   'Longitude': -93.3473250158},
#  {'Listing_ID': 'L00183',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 1856314.008062075,
#   'Sqft': 4511.005908282,
#   'Date_Listed': '2024-03-19',
#   'Agent_ID': 'A0010',
#   'Latitude': 47.6101088785,
#   'Longitude': -102.5842846527},
#  {'Listing_ID': 'L00184',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 823777.0072965751,
#   'Sqft': 3222.9872363382,
#   'Date_Listed': '2023-10-10',
#   'Agent_ID': 'A0049',
#   'Latitude': 48.0630527727,
#   'Longitude': -72.4865814637},
#  {'Listing_ID': 'L00185',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1054926.005769147,
#   'Sqft': 3135.988996403,
#   'Date_Listed': '2024-03-21',
#   'Agent_ID': 'A0013',
#   'Latitude': 29.7048177552,
#   'Longitude': -120.9657422502},
#  {'Listing_ID': 'L00186',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 589815.0184050994,
#   'Sqft': 3864.9910633338,
#   'Date_Listed': '2023-01-23',
#   'Agent_ID': 'A0021',
#   'Latitude': 27.4314522347,
#   'Longitude': -123.9403300552},
#  {'Listing_ID': 'L00187',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 909664.9984257128,
#   'Sqft': 1746.0017037756,
#   'Date_Listed': '2023-09-11',
#   'Agent_ID': 'A0003',
#   'Latitude': 27.2504989809,
#   'Longitude': -85.3882321411},
#  {'Listing_ID': 'L00188',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 1923892.9960054152,
#   'Sqft': 1322.0128675427,
#   'Date_Listed': '2024-03-23',
#   'Agent_ID': 'A0029',
#   'Latitude': 26.7178699445,
#   'Longitude': -106.5126063212},
#  {'Listing_ID': 'L00189',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 132185.9848896388,
#   'Sqft': 1680.0227550797,
#   'Date_Listed': '2023-07-29',
#   'Agent_ID': 'A0042',
#   'Latitude': 45.2805509059,
#   'Longitude': -123.6516959065},
#  {'Listing_ID': 'L00190',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1084592.9946077748,
#   'Sqft': 2671.0134558025,
#   'Date_Listed': '2023-06-23',
#   'Agent_ID': 'A0040',
#   'Latitude': 44.5437074357,
#   'Longitude': -108.6579479652},
#  {'Listing_ID': 'L00191',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1886281.0148641623,
#   'Sqft': 3190.9897936555,
#   'Date_Listed': '2024-03-12',
#   'Agent_ID': 'A0044',
#   'Latitude': 27.8495222882,
#   'Longitude': -84.5879563919},
#  {'Listing_ID': 'L00192',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 764085.9897658034,
#   'Sqft': 4496.9923402709,
#   'Date_Listed': '2024-03-22',
#   'Agent_ID': 'A0035',
# ...
#   'Price': 964919.0067801416,
#   'Sqft': 3392.0091771094,
#   'Date_Listed': '2023-09-22',
#   'Agent_ID': 'A0035',
#   'Latitude': 37.1300907626,
#   'Longitude': -76.2565926475},
#  {'Listing_ID': 'L00938',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 620633.0141907684,
#   'Sqft': 2853.0160768262,
#   'Date_Listed': '2023-02-17',
#   'Agent_ID': 'A0026',
#   'Latitude': 42.5972050189,
#   'Longitude': -93.5547713128},
#  {'Listing_ID': 'L00939',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1262977.9843379103,
#   'Sqft': 1962.0078490154,
#   'Date_Listed': '2023-09-01',
#   'Agent_ID': 'A0021',
#   'Latitude': 39.1635094965,
#   'Longitude': -95.5194096202},
#  {'Listing_ID': 'L00940',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1975516.9881202264,
#   'Sqft': 2703.9815495549,
#   'Date_Listed': '2023-04-04',
#   'Agent_ID': 'A0048',
#   'Latitude': 32.1321523632,
#   'Longitude': -92.2292997839},
#  {'Listing_ID': 'L00941',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1645836.0057357575,
#   'Sqft': 2135.0120715841,
#   'Date_Listed': '2023-05-01',
#   'Agent_ID': 'A0048',
#   'Latitude': 41.5444233831,
#   'Longitude': -74.3341847489},
#  {'Listing_ID': 'L00942',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 533646.0046490618,
#   'Sqft': 2377.0101478575,
#   'Date_Listed': '2023-04-14',
#   'Agent_ID': 'A0016',
#   'Latitude': 40.2619177007,
#   'Longitude': -80.858369752},
#  {'Listing_ID': 'L00943',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 427145.9974053575,
#   'Sqft': 1373.0021475001,
#   'Date_Listed': '2023-03-03',
#   'Agent_ID': 'A0006',
#   'Latitude': 28.8558317756,
#   'Longitude': -98.2290396533},
#  {'Listing_ID': 'L00944',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1702736.0018970382,
#   'Sqft': 4935.0273468111,
#   'Date_Listed': '2024-05-05',
#   'Agent_ID': 'A0003',
#   'Latitude': 25.2110493422,
#   'Longitude': -110.7023279515},
#  {'Listing_ID': 'L00945',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 1401634.013886626,
#   'Sqft': 3082.9836876234,
#   'Date_Listed': '2023-09-10',
#   'Agent_ID': 'A0037',
#   'Latitude': 42.4383294556,
#   'Longitude': -67.4802902845},
#  {'Listing_ID': 'L00946',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 483509.9969847113,
#   'Sqft': 4686.9933777804,
#   'Date_Listed': '2023-05-24',
#   'Agent_ID': 'A0026',
#   'Latitude': 27.376105721,
#   'Longitude': -101.7137309317},
#  {'Listing_ID': 'L00947',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 213555.9835785558,
#   'Sqft': 4806.0000189872,
#   'Date_Listed': '2024-02-14',
#   'Agent_ID': 'A0028',
#   'Latitude': 44.1781774124,
#   'Longitude': -113.1747888264},
#  {'Listing_ID': 'L00948',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1153765.9980649615,
#   'Sqft': 3344.0058634983,
#   'Date_Listed': '2023-07-21',
#   'Agent_ID': 'A0044',
#   'Latitude': 38.3306642572,
#   'Longitude': -82.4785068411},
#  {'Listing_ID': 'L00949',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 352429.9893361207,
#   'Sqft': 4744.9923481224,
#   'Date_Listed': '2023-08-24',
#   'Agent_ID': 'A0021',
#   'Latitude': 39.7952889743,
#   'Longitude': -114.1009923405},
#  {'Listing_ID': 'L00950',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 1513695.9971862186,
#   'Sqft': 2225.9888777361,
#   'Date_Listed': '2023-07-14',
#   'Agent_ID': 'A0038',
#   'Latitude': 33.51765466,
#   'Longitude': -79.5406574507},
#  {'Listing_ID': 'L00951',
#   'City': 'New York',
#   'Property_Type': 'Condo',
#   'Price': 858334.9997742043,
#   'Sqft': 2626.9905238915,
#   'Date_Listed': '2023-04-06',
#   'Agent_ID': 'A0036',
#   'Latitude': 38.3032319682,
#   'Longitude': -124.6979331029},
#  {'Listing_ID': 'L00952',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 664990.0044078121,
#   'Sqft': 4360.9978285334,
#   'Date_Listed': '2024-05-05',
#   'Agent_ID': 'A0040',
#   'Latitude': 43.2569387226,
#   'Longitude': -122.9397830843},
#  {'Listing_ID': 'L00953',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 485694.0133910609,
#   'Sqft': 4585.0114289187,
#   'Date_Listed': '2023-08-06',
#   'Agent_ID': 'A0014',
#   'Latitude': 42.8936905976,
#   'Longitude': -113.2540790691},
#  {'Listing_ID': 'L00954',
#   'City': 'Houston',
#   'Property_Type': 'Condo',
#   'Price': 865623.9983014852,
#   'Sqft': 3780.9854717773,
#   'Date_Listed': '2023-05-24',
#   'Agent_ID': 'A0029',
#   'Latitude': 47.9864468144,
#   'Longitude': -103.6570990546},
#  {'Listing_ID': 'L00955',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1307733.997753278,
#   'Sqft': 2372.0021594962,
#   'Date_Listed': '2024-02-21',
#   'Agent_ID': 'A0007',
#   'Latitude': 32.8293403466,
#   'Longitude': -116.361950379},
#  {'Listing_ID': 'L00956',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1264631.978945778,
#   'Sqft': 4040.0120715125,
#   'Date_Listed': '2024-03-14',
#   'Agent_ID': 'A0025',
#   'Latitude': 32.3423134635,
#   'Longitude': -74.14886639},
#  {'Listing_ID': 'L00957',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1777800.0050071063,
#   'Sqft': 1724.9870504007,
#   'Date_Listed': '2023-08-31',
#   'Agent_ID': 'A0001',
#   'Latitude': 48.8960699987,
#   'Longitude': -103.6429627537},
#  {'Listing_ID': 'L00958',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1147731.9944066731,
#   'Sqft': 1601.018864826,
#   'Date_Listed': '2024-04-02',
#   'Agent_ID': 'A0041',
#   'Latitude': 35.7757858844,
#   'Longitude': -83.1259225582},
#  {'Listing_ID': 'L00959',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 1746961.9922643765,
#   'Sqft': 4486.009742466,
#   'Date_Listed': '2023-06-03',
#   'Agent_ID': 'A0017',
#   'Latitude': 46.2489579332,
#   'Longitude': -90.5793263747},
#  {'Listing_ID': 'L00960',
#   'City': 'Phoenix',
#   'Property_Type': 'Apartment',
#   'Price': 935508.9998543868,
#   'Sqft': 1310.0114722962,
#   'Date_Listed': '2023-12-20',
#   'Agent_ID': 'A0011',
#   'Latitude': 34.401946062,
#   'Longitude': -101.0625565517},
#  {'Listing_ID': 'L00961',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 1806699.99913556,
#   'Sqft': 2583.002947765,
#   'Date_Listed': '2023-09-01',
#   'Agent_ID': 'A0041',
#   'Latitude': 41.689859335,
#   'Longitude': -124.8158322709},
#  {'Listing_ID': 'L00962',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 1661525.0109190564,
#   'Sqft': 3240.9988245537,
#   'Date_Listed': '2023-05-14',
#   'Agent_ID': 'A0024',
#   'Latitude': 39.8635816288,
#   'Longitude': -104.3804356834},
#  {'Listing_ID': 'L00963',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 821713.9859258013,
#   'Sqft': 661.9841554829,
#   'Date_Listed': '2023-07-30',
#   'Agent_ID': 'A0008',
#   'Latitude': 44.057993422,
#   'Longitude': -119.6028797493},
#  {'Listing_ID': 'L00964',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1309750.0051606174,
#   'Sqft': 4910.0166016003,
#   'Date_Listed': '2023-03-31',
#   'Agent_ID': 'A0050',
#   'Latitude': 39.1177412991,
#   'Longitude': -97.0959521477},
#  {'Listing_ID': 'L00965',
#   'City': 'Chicago',
#   'Property_Type': 'Condo',
#   'Price': 781763.005413031,
#   'Sqft': 4681.0041338398,
#   'Date_Listed': '2023-09-07',
#   'Agent_ID': 'A0050',
#   'Latitude': 40.4098279217,
#   'Longitude': -121.2313259717},
#  {'Listing_ID': 'L00966',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 899162.9932455958,
#   'Sqft': 2847.0116348508,
#   'Date_Listed': '2023-08-26',
#   'Agent_ID': 'A0041',
#   'Latitude': 38.9312472922,
#   'Longitude': -92.4313827764},
#  {'Listing_ID': 'L00967',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1443394.0027831136,
#   'Sqft': 3262.9974825532,
#   'Date_Listed': '2023-08-04',
#   'Agent_ID': 'A0041',
#   'Latitude': 38.4347662204,
#   'Longitude': -90.0110652905},
#  {'Listing_ID': 'L00968',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1880272.989946864,
#   'Sqft': 1083.998473513,
#   'Date_Listed': '2023-02-10',
#   'Agent_ID': 'A0011',
#   'Latitude': 41.2378470236,
#   'Longitude': -78.3099956172},
#  {'Listing_ID': 'L00969',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 757419.011173733,
#   'Sqft': 3095.0108932753,
#   'Date_Listed': '2023-12-01',
#   'Agent_ID': 'A0019',
#   'Latitude': 31.4926143193,
#   'Longitude': -77.1440242555},
#  {'Listing_ID': 'L00970',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 668847.9941677155,
#   'Sqft': 4143.9703796491,
#   'Date_Listed': '2024-02-04',
#   'Agent_ID': 'A0024',
#   'Latitude': 36.942350514,
#   'Longitude': -120.5197961426},
#  {'Listing_ID': 'L00971',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 968196.9922811488,
#   'Sqft': 1870.0032413284,
#   'Date_Listed': '2023-04-05',
#   'Agent_ID': 'A0002',
#   'Latitude': 26.4060364785,
#   'Longitude': -105.6133743855},
#  {'Listing_ID': 'L00972',
#   'City': 'Los Angeles',
#   'Property_Type': 'House',
#   'Price': 1488361.0077013418,
#   'Sqft': 2560.9811224679,
#   'Date_Listed': '2024-04-26',
#   'Agent_ID': 'A0048',
#   'Latitude': 43.8396507123,
#   'Longitude': -83.9599272928},
#  {'Listing_ID': 'L00973',
#   'City': 'New York',
#   'Property_Type': 'House',
#   'Price': 450036.0140659073,
#   'Sqft': 3752.0261565588,
#   'Date_Listed': '2023-02-22',
#   'Agent_ID': 'A0007',
#   'Latitude': 43.9168638639,
#   'Longitude': -94.9968396188},
#  {'Listing_ID': 'L00974',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 1250148.008073223,
#   'Sqft': 940.0090940936,
#   'Date_Listed': '2023-01-14',
#   'Agent_ID': 'A0050',
#   'Latitude': 35.5591965368,
#   'Longitude': -116.4561997353},
#  {'Listing_ID': 'L00975',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 317952.9987282446,
#   'Sqft': 2649.9830312266,
#   'Date_Listed': '2023-11-13',
#   'Agent_ID': 'A0010',
#   'Latitude': 32.8683664498,
#   'Longitude': -99.8346550665},
#  {'Listing_ID': 'L00976',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 748797.0057511086,
#   'Sqft': 2378.0048822281,
#   'Date_Listed': '2023-05-07',
#   'Agent_ID': 'A0048',
#   'Latitude': 27.1400224617,
#   'Longitude': -112.216323944},
#  {'Listing_ID': 'L00977',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 1413825.0125863503,
#   'Sqft': 1535.0005133768,
#   'Date_Listed': '2023-03-09',
#   'Agent_ID': 'A0034',
#   'Latitude': 39.3774717313,
#   'Longitude': -82.3280462827},
#  {'Listing_ID': 'L00978',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 173725.0109242742,
#   'Sqft': 3423.0094823005,
#   'Date_Listed': '2024-03-16',
#   'Agent_ID': 'A0021',
#   'Latitude': 48.9655703368,
#   'Longitude': -70.8829029965},
#  {'Listing_ID': 'L00979',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 1926406.0030180956,
#   'Sqft': 4928.0070680532,
#   'Date_Listed': '2024-04-23',
#   'Agent_ID': 'A0018',
#   'Latitude': 40.4208374141,
#   'Longitude': -100.5730975753},
#  {'Listing_ID': 'L00980',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 383355.9949518397,
#   'Sqft': 4916.9840181707,
#   'Date_Listed': '2023-04-01',
#   'Agent_ID': 'A0038',
#   'Latitude': 40.2437317291,
#   'Longitude': -79.4367462682},
#  {'Listing_ID': 'L00981',
#   'City': 'Phoenix',
#   'Property_Type': 'Townhouse',
#   'Price': 1423401.9928277023,
#   'Sqft': 4063.0071250191,
#   'Date_Listed': '2023-09-26',
#   'Agent_ID': 'A0041',
#   'Latitude': 27.8350008609,
#   'Longitude': -101.2185289732},
#  {'Listing_ID': 'L00982',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 828063.9967323261,
#   'Sqft': 4444.9899891958,
#   'Date_Listed': '2023-10-04',
#   'Agent_ID': 'A0015',
#   'Latitude': 45.1337568273,
#   'Longitude': -102.7325267388},
#  {'Listing_ID': 'L00983',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 745645.9947900687,
#   'Sqft': 3495.9925332838,
#   'Date_Listed': '2023-07-31',
#   'Agent_ID': 'A0017',
#   'Latitude': 38.7177590309,
#   'Longitude': -90.8986984457},
#  {'Listing_ID': 'L00984',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 122137.0108102742,
#   'Sqft': 500.0055860929,
#   'Date_Listed': '2023-09-25',
#   'Agent_ID': 'A0049',
#   'Latitude': 29.4363477067,
#   'Longitude': -104.0026911428},
#  {'Listing_ID': 'L00985',
#   'City': 'Los Angeles',
#   'Property_Type': 'Condo',
#   'Price': 701383.9889024157,
#   'Sqft': 4343.0060644523,
#   'Date_Listed': '2023-10-01',
#   'Agent_ID': 'A0001',
#   'Latitude': 33.0237510748,
#   'Longitude': -123.4916638055},
#  {'Listing_ID': 'L00986',
#   'City': 'Houston',
#   'Property_Type': 'Townhouse',
#   'Price': 728327.9968834742,
#   'Sqft': 573.9811634925,
#   'Date_Listed': '2024-01-28',
#   'Agent_ID': 'A0028',
#   'Latitude': 25.5674306149,
#   'Longitude': -76.7579407278},
#  {'Listing_ID': 'L00987',
#   'City': 'Chicago',
#   'Property_Type': 'House',
#   'Price': 1770942.0052828873,
#   'Sqft': 558.9931124412,
#   'Date_Listed': '2023-10-08',
#   'Agent_ID': 'A0024',
#   'Latitude': 31.5601371951,
#   'Longitude': -94.9586149098},
#  {'Listing_ID': 'L00988',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1950026.99476192,
#   'Sqft': 4079.9964088476,
#   'Date_Listed': '2023-07-22',
#   'Agent_ID': 'A0016',
#   'Latitude': 32.1818501615,
#   'Longitude': -70.4225559254},
#  {'Listing_ID': 'L00989',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1837336.9863553816,
#   'Sqft': 3599.0215016817,
#   'Date_Listed': '2023-04-23',
#   'Agent_ID': 'A0017',
#   'Latitude': 31.2379801992,
#   'Longitude': -100.1003361525},
#  {'Listing_ID': 'L00990',
#   'City': 'New York',
#   'Property_Type': 'Townhouse',
#   'Price': 1411396.9961362106,
#   'Sqft': 2461.9974057224,
#   'Date_Listed': '2023-09-22',
#   'Agent_ID': 'A0049',
#   'Latitude': 45.9376820863,
#   'Longitude': -76.1642816109},
#  {'Listing_ID': 'L00991',
#   'City': 'Phoenix',
#   'Property_Type': 'Condo',
#   'Price': 697010.0106800384,
#   'Sqft': 4857.0044600116,
#   'Date_Listed': '2024-02-19',
#   'Agent_ID': 'A0018',
#   'Latitude': 29.4775811145,
#   'Longitude': -78.4482736538},
#  {'Listing_ID': 'L00992',
#   'City': 'Houston',
#   'Property_Type': 'House',
#   'Price': 1889881.0164037675,
#   'Sqft': 1060.0042890779,
#   'Date_Listed': '2023-04-04',
#   'Agent_ID': 'A0009',
#   'Latitude': 35.9900877803,
#   'Longitude': -96.9901703087},
#  {'Listing_ID': 'L00993',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1435660.0026373651,
#   'Sqft': 4229.9822425921,
#   'Date_Listed': '2023-11-13',
#   'Agent_ID': 'A0029',
#   'Latitude': 28.2173963511,
#   'Longitude': -120.3311961632},
#  {'Listing_ID': 'L00994',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 493823.0001776781,
#   'Sqft': 3126.0088278405,
#   'Date_Listed': '2023-01-10',
#   'Agent_ID': 'A0010',
#   'Latitude': 42.4642321811,
#   'Longitude': -96.2085503498},
#  {'Listing_ID': 'L00995',
#   'City': 'New York',
#   'Property_Type': 'Apartment',
#   'Price': 489939.0088256518,
#   'Sqft': 1336.9908316814,
#   'Date_Listed': '2023-05-25',
#   'Agent_ID': 'A0018',
#   'Latitude': 35.4973099608,
#   'Longitude': -82.6894732655},
#  {'Listing_ID': 'L00996',
#   'City': 'Los Angeles',
#   'Property_Type': 'Townhouse',
#   'Price': 1624854.0002587065,
#   'Sqft': 567.0096022477,
#   'Date_Listed': '2023-04-30',
#   'Agent_ID': 'A0006',
#   'Latitude': 43.3606229414,
#   'Longitude': -115.7858996916},
#  {'Listing_ID': 'L00997',
#   'City': 'Los Angeles',
#   'Property_Type': 'Apartment',
#   'Price': 1135111.0026554707,
#   'Sqft': 2278.9898291761,
#   'Date_Listed': '2023-06-25',
#   'Agent_ID': 'A0027',
#   'Latitude': 39.64818569,
#   'Longitude': -117.1449386306},
#  {'Listing_ID': 'L00998',
#   'City': 'Chicago',
#   'Property_Type': 'Townhouse',
#   'Price': 878875.9970625386,
#   'Sqft': 4298.0121147898,
#   'Date_Listed': '2023-12-23',
#   'Agent_ID': 'A0003',
#   'Latitude': 43.0483481799,
#   'Longitude': -86.8972497875},
#  {'Listing_ID': 'L00999',
#   'City': 'Chicago',
#   'Property_Type': 'Apartment',
#   'Price': 1869044.0016598515,
#   'Sqft': 1695.9742255388,
#   'Date_Listed': '2023-01-29',
#   'Agent_ID': 'A0018',
#   'Latitude': 47.953587212,
#   'Longitude': -120.9983509497},
#  {'Listing_ID': 'L01000',
#   'City': 'Houston',
#   'Property_Type': 'Apartment',
#   'Price': 1239155.9899416547,
#   'Sqft': 4350.9979926603,
#   'Date_Listed': '2023-04-03',
#   'Agent_ID': 'A0013',
#   'Latitude': 26.353020661,
#   'Longitude': -108.6323269324},
#  ...]

# %%
import pandas as pd
df = pd.read_csv("sales_cleaned.csv")
df.to_json("sales_cleaned.json", index=False)
print("json file created successfully.")
# Out:
# json file created successfully.

# %%
import pandas as pd

# Read JSON files
listings_df = pd.read_json("listings_final_expanded.json")
property_df = pd.read_json("property_attributes_final_expanded.json")
agents_df = pd.read_json("agents_cleaned.json")
sales_df = pd.read_json("sales_cleaned.json")
buyers_df = pd.read_json("buyers_cleaned.json")

# %%
listings_df.head()
# Out:
#   Listing_ID         City Property_Type         Price         Sqft  \
# 0     L00001     New York     Apartment  1.655144e+06  2753.009121
# 1     L00002  Los Angeles     Apartment  1.519141e+06  4966.988193
# 2     L00003      Houston     Apartment  1.624890e+05  1267.003959
# 3     L00004      Phoenix     Apartment  1.277016e+06  2128.014429
# 4     L00005      Phoenix     Townhouse  5.622970e+05  4178.997421
#
#   Date_Listed Agent_ID   Latitude   Longitude
# 0  2023-05-06    A0015  33.965208  -69.861589
# 1  2023-02-14    A0038  42.547892  -90.277860
# 2  2023-04-22    A0015  28.732327 -115.952982
# 3  2024-01-02    A0042  26.403938  -74.771490
# 4  2023-10-29    A0018  39.425252  -83.917878

# %%
property_df.head()
# Out:
#    attribute_id listing_id  bedrooms  bathrooms  floor_number  total_floors  \
# 0             1     L00001         5          3             9             9
# 1             2     L00002         2          2            19            29
# 2             3     L00003         2          3             8            26
# 3             4     L00004         3          3            25            10
# 4             5     L00005         2          2            15            16
#
#    year_built  is_rented  tenant_count furnishing_status  metro_distance_km  \
# 0        2001       True             4         Furnished               7.26
# 1        2020      False             0       Unfurnished               4.84
# 2        2007       True             4    Semi-Furnished               4.92
# 3        2003      False             3         Furnished               1.20
# 4        2008       True             1    Semi-Furnished               7.90
#
#    parking_available  power_backup
# 0              False          True
# 1               True         False
# 2              False         False
# 3              False          True
# 4              False         False

# %%
agents_df.head()
# Out:
#   Listing_ID    Sale_Price   Date_Sold  Days_on_Market
# 0     L01179  9.255800e+05  2023-07-07       65.005560
# 1     L00866  1.054160e+05  2023-06-14       38.004620
# 2     L00102  1.825184e+06  2023-09-09       22.992622
# 3     L00440  1.932085e+06  2023-10-29       72.012274
# 4     L00059  7.765860e+05  2023-05-01      116.000152

# %%
sales_df.head()
# Out:
#   Listing_ID    Sale_Price   Date_Sold  Days_on_Market
# 0     L01179  9.255800e+05  2023-07-07       65.005560
# 1     L00866  1.054160e+05  2023-06-14       38.004620
# 2     L00102  1.825184e+06  2023-09-09       22.992622
# 3     L00440  1.932085e+06  2023-10-29       72.012274
# 4     L00059  7.765860e+05  2023-05-01      116.000152

# %%
buyers_df.head()
# Out:
#    buyer_id sale_id buyer_type   payment_mode  loan_taken loan_provider  \
# 0         1  L01179   End User           Cash       False          None
# 1         2  L00866   Investor         Cheque       False          None
# 2         3  L00102   Investor         Cheque        True          Axis
# 3         4  L00440   Investor  Bank Transfer       False          None
# 4         5  L00059   Investor            UPI        True          HDFC
#
#    loan_amount
# 0            0
# 1            0
# 2      2317757
# 3            0
# 4      4191221

# %% [markdown]
# STEP 2: Connect to SQLite3

# %%
import sqlite3

# %%
# Create / connect database
conn = sqlite3.connect("brickview_realstate.db")
cursor = conn.cursor()

# %%
create_listings_table = """
CREATE TABLE IF NOT EXISTS listings(
    listings_id INTEGER PRIMARY KEY,
    address TEXT,
    city TEXT,
    state TEXT,
    zip TEXT,
    property_type TEXT,
    price REAL,
    area_sqft REAL,
    agent_id INTEGER,
    listed_date DATE
);
"""
cursor.execute(create_listings_table)
conn.commit()

# %%
cursor.execute("PRAGMA table_info(listings);")
columns = cursor.fetchall()

for col in columns:
    print(col)
# Out:
# (0, 'listings_id', 'INTEGER', 0, None, 1)
# (1, 'address', 'TEXT', 0, None, 0)
# (2, 'city', 'TEXT', 0, None, 0)
# (3, 'state', 'TEXT', 0, None, 0)
# (4, 'zip', 'TEXT', 0, None, 0)
# (5, 'property_type', 'TEXT', 0, None, 0)
# (6, 'price', 'REAL', 0, None, 0)
# (7, 'area_sqft', 'REAL', 0, None, 0)
# (8, 'agent_id', 'INTEGER', 0, None, 0)
# (9, 'listed_date', 'DATE', 0, None, 0)

# %%
create_property_attributes_table = """
CREATE TABLE IF NOT EXISTS property_attributes(
    attribute_id INTEGER PRIMARY KEY,
    listing_id INTEGER,
    bedrooms INTEGER,
    bathrooms INTEGER,
    floor_number INTEGER,
    total_floors INTEGER,
    year_built INTEGER,
    is_rented BOOLEAN,
    tenant_count INTEGER,
    furnishing_status TEXT,
    metro_distance_km REAL,
    parking_available BOOLEAN,
    power_backup BOOLEAN,
    FOREIGN KEY (listing_id) REFERENCES listings(listing_id)
);
"""

cursor.execute(create_property_attributes_table)
conn.commit()

# %%
import sqlite3

# %%
conn = sqlite3.connect("brickview_realstate.db")
cursor = conn.cursor()

# %%
create_agents_cleaned_table = """
CREATE TABLE IF NOT EXISTS agents(
    agents_id INTEGER PRIMARY KEY,
    name TEXT,
    city TEXT,
    contact TEXT
);
"""
cursor.execute(create_agents_cleaned_table)
conn.commit()

# %%
create_sales_cleaned_table = """
CREATE TABLE IF NOT EXISTS sales(
    sales_id INTEGER PRIMARY KEY,
    listing_id INTEGER,
    sale_date DATE,
    sale_price REAL,
    days_on_market INTEGER,
    FOREIGN KEY (listing_id) REFERENCES listings(listing_id)
);
"""
cursor.execute(create_sales_cleaned_table)
conn.commit()

# %%
create_buyers_cleaned_table = """
CREATE TABLE IF NOT EXISTS buyers(
    buyers_id INTEGER PRIMARY KEY,
    sale_id INTEGER,
    buyer_type TEXT,
    payment_mode TEXT,
    loan_taken BOOLEAN,
    loan_provider TEXT,
    loan_amount REAL,
    FOREIGN KEY (sale_id) REFERENCES sales(sale_id)
);
"""
cursor.execute(create_buyers_cleaned_table)
conn.commit()

# %%
# %who
# Out:
# conn	 create_agents_cleaned_table	 create_buyers_cleaned_table	 create_sales_cleaned_table	 cursor	 sqlite3

# %%
import sqlite3
conn = sqlite3.connect("brickview_realstate.db")
cursor = conn.cursor()

# %%
import pandas as pd

listings_df = pd.read_csv("listings_final_expanded.csv")
property_df = pd.read_csv("property_attributes_final_expanded.csv")
agents_df = pd.read_csv("agents_cleaned.csv")
sales_df = pd.read_csv("sales_cleaned.csv")
buyers_df = pd.read_csv("buyers_cleaned.csv")

listings_df.to_sql("listings", conn, if_exists="replace", index=False)
property_df.to_sql("property_attributes", conn, if_exists="replace", index=False)
agents_df.to_sql("agents", conn, if_exists="replace", index=False)
sales_df.to_sql("sales", conn, if_exists="replace", index=False)
buyers_df.to_sql("buyers", conn, if_exists="replace", index=False)
# Out:
# 20000

# %%
listings_df.to_sql("listings", conn, if_exists="replace", index=False)
# Out:
# 21200

# %%
property_df.to_sql("property_attributes", conn, if_exists="replace", index=False)
# Out:
# 21200

# %%
agents_df.to_sql("agents", conn, if_exists="replace", index=False)
# Out:
# 50

# %%
sales_df.to_sql("sales", conn, if_exists="replace", index=False)
# Out:
# 720

# %%
buyers_df.to_sql("buyers", conn, if_exists="replace", index=False)
# Out:
# 20000

# %% [markdown]
# PROPERTY & PRICING ANALYSIS

# %% [markdown]
# Q1 . What is the average listing price by city?

# %%
query = """
SELECT city, AVG(price) AS avg_price
FROM listings
GROUP BY city;
"""

df_avg_price_city = pd.read_sql(query, conn)
print(df_avg_price_city)
# Out:
#           City     avg_price
# 0      Chicago  2.430678e+06
# 1      Houston  2.436811e+06
# 2  Los Angeles  2.442418e+06
# 3     New York  2.493320e+06
# 4      Phoenix  2.459962e+06

# %%
query = """
SELECT CITY, COUNT(*) as total_listings
FROM listings
GROUP BY CITY;
"""

df_city_listings = pd.read_sql(query, conn)
print(df_city_listings)
# Out:
#           City  total_listings
# 0      Chicago            4293
# 1      Houston            4091
# 2  Los Angeles            4318
# 3     New York            4269
# 4      Phoenix            4229

# %% [markdown]
# Q2 . What is the average price per square foot by property type?

# %%
query = """
SELECT Property_Type AS property_type,
    AVG(Price * 1.0 / Sqft) AS avg_price_per_sqft
FROM listings
WHERE Sqft IS NOT NULL
  AND Sqft > 0
GROUP BY Property_Type
ORDER BY avg_price_per_sqft DESC;
"""

df_avg_price_per_sqft = pd.read_sql(query, conn)
print(df_avg_price_per_sqft)
# Out:
#   property_type  avg_price_per_sqft
# 0         House          796.040653
# 1     Apartment          792.203348
# 2     Townhouse          789.745399
# 3         Condo          754.675722

# %% [markdown]
# Q3 . How does furnishing status impact property prices?

# %%
query = """
SELECT pa.furnishing_status, COUNT(*) AS total_properties,
ROUND(AVG(l.Price), 2) AS avg_price,
ROUND(MIN(l.Price), 2) AS min_price,
ROUND(MAX(l.Price), 2) AS max_price
FROM property_attributes pa
JOIN listings l
  ON pa.listing_id = l.Listing_ID
WHERE pa.furnishing_status IS NOT NULL
GROUP BY pa.furnishing_status
ORDER BY avg_price DESC;
"""

df_total_properties = pd.read_sql(query, conn)
print(df_total_properties)
# Out:
#   furnishing_status  total_properties   avg_price  min_price   max_price
# 0         Furnished              6977  2463539.06  100082.01  4997593.10
# 1    Semi-Furnished              7013  2461192.65  100027.13  4999863.52
# 2       Unfurnished              7210  2433975.10  100458.61  4998967.92

# %%
conn = sqlite3.connect("brickview_realstate.db")
cursor = conn.cursor()

# %% [markdown]
# Q4 . Do properties closer to metro stations command higher prices?

# %%
query = """
SELECT
    CASE
        WHEN metro_distance_km IS NOT NULL AND metro_distance_km * 1000 <= 500 THEN '0-500 meters'
        WHEN metro_distance_km IS NOT NULL AND metro_distance_km * 1000 <= 1000 THEN '501-1000 meters'
        WHEN metro_distance_km IS NOT NULL AND metro_distance_km * 1000 <= 2000 THEN '1001-2000 meters'
        ELSE '2000M+'
    END AS distance_band,
    COUNT(*) AS property_count,
    ROUND(AVG(l.price), 2) AS avg_price,
    ROUND(MIN(l.price), 2) AS min_price,
    ROUND(MAX(l.price), 2) AS max_price
FROM property_attributes pa
JOIN listings l
    ON pa.listing_id = l.listings_id
GROUP BY distance_band
ORDER BY avg_price DESC;
"""

query = query.replace("l.listings_id", "l.Listing_ID")
df_avg_price = pd.read_sql(query, conn)
print(df_avg_price)
# Out:
#       distance_band  property_count   avg_price  min_price   max_price
# 0            2000M+           18292  2464613.02  100027.13  4999863.52
# 1      0-500 meters             611  2424531.90  116086.31  4987389.26
# 2  1001-2000 meters            1507  2369435.61  101180.33  4987047.72
# 3   501-1000 meters             790  2357704.84  101767.99  4997111.88

# %% [markdown]
# Q5 . Are rented properties priced differently from non-rented ones?

# %%
query = """
SELECT 
    CASE 
        WHEN is_rented = 1 THEN 'Rented'
        ELSE 'Not Rented'
    END AS rental_status,
    COUNT(*) AS property_count,
    AVG(price) AS avg_price,
    MIN(price) AS min_price,
    MAX(price) AS max_price
FROM property_attributes pa
JOIN listings l ON pa.listing_id = l.Listing_ID
GROUP BY rental_status;
"""
query = query.replace("l.listings_id", "l.Listing_ID")
df_rental_status = pd.read_sql(query, conn)
print(df_rental_status)
# Out:
#   rental_status  property_count     avg_price  min_price   max_price
# 0    Not Rented           10622  2.448250e+06  100027.13  4999463.77
# 1        Rented           10578  2.457185e+06  100082.01  4999863.52

# %% [markdown]
# Q6 . How do bedrooms and bathrooms affect pricing?

# %%
query = """
SELECT
    pa.bedrooms,
    pa.bathrooms,
    COUNT(*) AS property_count,
    AVG(l.price) AS avg_price,
    MIN(l.price) AS min_price,
    MAX(l.price) AS max_price
FROM property_attributes pa
JOIN listings l
    ON pa.listing_id = l.Listing_ID
GROUP BY pa.bedrooms, bathrooms
ORDER BY pa.bedrooms, bathrooms;
"""
query = query.replace("l.listings_id", "l.Listing_ID")
df_bedrooms_bathrooms = pd.read_sql(query, conn)
print(df_bedrooms_bathrooms)
# Out:
#     bedrooms  bathrooms  property_count     avg_price      min_price  \
# 0          1          1            1040  2.434001e+06  102914.310000
# 1          1          2            1047  2.509475e+06  106349.810000
# 2          1          3            1028  2.459033e+06  100613.180000
# 3          1          4            1094  2.455533e+06  103179.460000
# 4          2          1            1068  2.455735e+06  103066.003828
# 5          2          2            1127  2.378688e+06  109084.390000
# 6          2          3            1060  2.482619e+06  110132.995219
# 7          2          4            1021  2.555766e+06  108618.983283
# 8          3          1            1032  2.426008e+06  103991.620000
# 9          3          2            1064  2.409123e+06  103003.180000
# 10         3          3            1030  2.455024e+06  110584.510000
# 11         3          4            1068  2.478881e+06  100330.740000
# 12         4          1            1080  2.434956e+06  104320.460000
# 13         4          2            1037  2.450750e+06  107067.020000
# 14         4          3            1034  2.393515e+06  100082.010000
# 15         4          4            1118  2.471536e+06  114191.981728
# 16         5          1            1095  2.384940e+06  100458.610000
# 17         5          2            1066  2.478068e+06  101201.920000
# 18         5          3            1066  2.424067e+06  100027.130000
# 19         5          4            1025  2.527192e+06  100478.090000
#
#      max_price
# 0   4991616.90
# 1   4999463.77
# 2   4992521.05
# 3   4998032.07
# 4   4989814.26
# 5   4995504.67
# 6   4987908.19
# 7   4998967.92
# 8   4986875.58
# 9   4998508.49
# 10  4999863.52
# 11  4996278.84
# 12  4992631.99
# 13  4997593.10
# 14  4997111.88
# 15  4996416.56
# 16  4994023.99
# 17  4998516.33
# 18  4998687.21
# 19  4995869.83

# %% [markdown]
# Q7 . Do properties with parking and power backup sell at higher prices?

# %%
query = """
SELECT
    CASE
        WHEN parking_Available = 'True' AND power_backup = 'True' THEN 'parking_Availabe & power backup'
        WHEN parking_Available = 'True' AND power_backup = 'False' THEN 'parking_Available only'
        WHEN parking_Available = 'False' AND power_backup = 'True' THEN 'power_backup only'
        ELSE 'Neither'
    END AS amenities,
    COUNT(*) AS property_count,
    AVG(price) AS avg_price,
    MIN(price) AS min_price,
    MAX(price) AS max_price
FROM property_attributes pa
JOIN listings l ON pa.listing_id = l.Listing_ID
GROUP BY
    CASE
        WHEN parking_Available = 'True' AND power_backup = 'True' THEN 'parking_Available & power backup'
        WHEN parking_Available = 'True' AND power_backup = 'False' THEN 'parking_Available only'
        WHEN parking_Available = 'False' AND power_backup = 'True' THEN 'power_backup only'
        ELSE 'Neither'
    END
ORDER BY avg_price DESC;
"""

df_avg_price = pd.read_sql(query, conn)
print(df_avg_price)
# Out:
#   amenities  property_count     avg_price  min_price   max_price
# 0   Neither           21200  2.452708e+06  100027.13  4999863.52

# %% [markdown]
# Q8 . How does year built influence listing price?

# %%
import sqlite3

conn = sqlite3.connect("brickview_realstate.db")

query = """
SELECT
    CASE
        WHEN year_built >= 2020 THEN '2020-present'
        WHEN year_built >= 2010 THEN '2010-2019'
        WHEN year_built >= 2000 THEN '2000-2009'
        WHEN year_built >= 1990 THEN '1990-1999'
        ELSE 'Before 1990'
    END AS construction_period,
    COUNT(*) AS property_count,
    AVG(l.price) AS avg_listing_price,
    MIN(l.price) AS min_price,
    MAX(l.price) AS max_price
FROM property_attributes pa
JOIN listings l ON pa.listing_id = l.Listing_ID
GROUP BY
    CASE
        WHEN year_built >= 2020 THEN '2020-present'
        WHEN year_built >= 2010 THEN '2010-2019'
        WHEN year_built >= 2000 THEN '2000-2009'
        WHEN year_built >= 1990 THEN '1990-1999'
        ELSE 'Before 1990'
    END
ORDER BY avg_listing_price DESC;
"""

query = query.replace("l.listings_id", "l.Listing_ID")
df_avg_listing_price = pd.read_sql(query, conn)
print(df_avg_listing_price)
# Out:
#   construction_period  property_count  avg_listing_price  min_price  \
# 0           1990-1999            6081       2.507602e+06  100458.61
# 1        2020-present            2598       2.475700e+06  100330.74
# 2           2000-2009            6154       2.434915e+06  100082.01
# 3           2010-2019            6367       2.408097e+06  100027.13
#
#     max_price
# 0  4999463.77
# 1  4998516.33
# 2  4998687.21
# 3  4999863.52

# %% [markdown]
# Q9 . Which cities have the highest average property prices?

# %%
query = """
SELECT
    city,
    COUNT(*) AS property_count,
    AVG(price) AS avg_price,
    MIN(price) AS min_price,
    MAX(price) AS max_price
FROM listings
GROUP BY city
ORDER BY avg_price DESC;
"""

df_avg_price = pd.read_sql(query, conn)
print(df_avg_price)
# Out:
#           City  property_count     avg_price  min_price   max_price
# 0     New York            4269  2.493320e+06  100027.13  4998508.49
# 1      Phoenix            4229  2.459962e+06  100458.61  4999863.52
# 2  Los Angeles            4318  2.442418e+06  100613.18  4999463.77
# 3      Houston            4091  2.436811e+06  100882.19  4998687.21
# 4      Chicago            4293  2.430678e+06  100082.01  4997593.10

# %% [markdown]
# Q10 . How are properties distributed across price buckets?

# %%
query = """
SELECT
    CASE
        WHEN Price < 100000 THEN 'Below 100k'
        WHEN Price BETWEEN 100000 AND 299999 THEN '100K - 299K'
        WHEN Price BETWEEN 300000 AND 499999 THEN '300K - 499K'
        WHEN Price BETWEEN 500000 AND 999999 THEN '500K - 999K'
        ELSE '1M and Above'
    END AS price_bucket,
    COUNT(*) AS Property_count,
    AVG(price) AS avg_price,
    MIN(price) AS min_price
FROM listings
GROUP BY price_bucket
ORDER BY min_price;
"""

df_min_price = pd.read_sql(query, conn)
print(df_min_price)
# Out:
#    price_bucket  Property_count     avg_price   min_price
# 0   100K - 299K             922  2.022725e+05   100027.13
# 1   300K - 499K             945  4.009215e+05   300379.04
# 2   500K - 999K            2402  7.480466e+05   500242.12
# 3  1M and Above           16931  2.931619e+06  1000322.88

# %% [markdown]
# SALES & MARKET PERFORMANCE

# %% [markdown]
# Q11 . What is the average days on market by city?

# %%
import pandas as pd
import sqlite3

query = """
SELECT
    l.city AS City,
    AVG(s.days_on_market) AS avg_days_on_market
FROM listings l
JOIN sales s
    ON l.Listing_ID = s.listing_id
GROUP BY l.city
ORDER BY avg_days_on_market DESC;
"""

conn = sqlite3.connect("brickview_realstate.db")
df_avg_days_on_market = pd.read_sql(query, conn)
print(df_avg_days_on_market)
# Out:
#           City  avg_days_on_market
# 0  Los Angeles           65.126408
# 1      Chicago           64.250577
# 2     New York           60.847639
# 3      Phoenix           59.654343
# 4      Houston           58.511086

# %% [markdown]
# Q12 . Which property types sell the fastest?

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("brickview_realstate.db")

query = """
SELECT 
    l.Listing_ID AS property_id,
    l.City,
    ROUND(l.Date_Listed) AS days_on_market
FROM listings l
JOIN sales s
    ON l.Listing_ID = s.listing_id
ORDER BY days_on_market ASC;
"""

df_DATEDIFF = pd.read_sql(query, conn)
print(df_DATEDIFF)
# Out:
#     property_id         City  days_on_market
# 0        L00001     New York          2023.0
# 1        L00003      Houston          2023.0
# 2        L00006     New York          2023.0
# 3        L00007  Los Angeles          2023.0
# 4        L00008      Houston          2023.0
# ..          ...          ...             ...
# 715      L01167     New York          2024.0
# 716      L01170      Chicago          2024.0
# 717      L01178      Houston          2024.0
# 718      L01186     New York          2024.0
# 719      L01196      Chicago          2024.0
#
# [720 rows x 3 columns]

# %% [markdown]
# Q13 . What percentage of properties are sold above listing price?

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("brickview_realstate.db")

query = """
SELECT
    ROUND(
        100.0 * SUM(CASE WHEN s.Sale_Price > l.price THEN 1 ELSE 0 END)
        / COUNT(*),
        2
    ) AS percentage_sold_above_listing
FROM sales s
JOIN listings l
    ON s.listing_id = l.Listing_ID
WHERE s.Sale_Price IS NOT NULL
  AND l.price IS NOT NULL;
"""

df_Price = pd.read_sql(query, conn)
print(df_Price)
# Out:
#    percentage_sold_above_listing
# 0                          49.31

# %% [markdown]
# Q14 . What is the sale-to-list price ratio by city?

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("brickview_realstate.db")

query = """
SELECT
  l.city AS City,
  ROUND(AVG((s.sale_price * 100.0) / l.price), 2) AS sale_to_list_ratio_pct
FROM sales s
JOIN listings l
  ON s.listing_id = l.Listing_ID
WHERE s.sale_price IS NOT NULL
  AND l.price IS NOT NULL
  AND l.price > 0
GROUP BY l.city
ORDER BY sale_to_list_ratio_pct DESC;
"""
df_sale_to_list_ratio_pct = pd.read_sql(query, conn)
print(df_sale_to_list_ratio_pct)
# Out:
#           City  sale_to_list_ratio_pct
# 0      Chicago                  100.15
# 1      Houston                  100.00
# 2  Los Angeles                   99.98
# 3     New York                   99.96
# 4      Phoenix                   99.89

# %% [markdown]
# Q15 . Which listings took more than 90 days to sell?

# %%
cols = [row[1] for row in conn.execute("PRAGMA table_info(listings)").fetchall()]

can_compute_days = ("Date_Sold" in cols) and ("Date_Listed" in cols)
has_days_col = "Days_on_Market" in cols

select_parts = []
# Property_Type
select_parts.append("Property_Type" if "Property_Type" in cols else "NULL AS Property_Type")
# Listing_ID -> listing_id
select_parts.append("Listing_ID AS listing_id" if "Listing_ID" in cols else "NULL AS listing_id")
# City
select_parts.append("City" if "City" in cols else "NULL AS City")
# Date_Listed
select_parts.append("Date_Listed" if "Date_Listed" in cols else "NULL AS Date_Listed")
# Date_Sold
select_parts.append("Date_Sold" if "Date_Sold" in cols else "NULL AS Date_Sold")
# Days_on_Market: use existing column, or compute from dates, or NULL
if has_days_col:
    select_parts.append("Days_on_Market")
elif can_compute_days:
    select_parts.append("ROUND(julianday(Date_Sold) - julianday(Date_Listed)) AS Days_on_Market")
else:
    select_parts.append("NULL AS Days_on_Market")

select_clause = ",\n    ".join(select_parts)

# Build WHERE / ORDER clauses depending on availability
if has_days_col:
    where_clause = "WHERE Days_on_Market > 90"
    order_clause = "ORDER BY Days_on_Market DESC"
elif can_compute_days:
    where_clause = "WHERE (julianday(Date_Sold) - julianday(Date_Listed)) > 90"
    order_clause = "ORDER BY Days_on_Market DESC"
else:
    where_clause = ""  # cannot filter by days on market
    order_clause = ""

query = f"""
SELECT
    {select_clause}
FROM listings
{where_clause}
{order_clause};
"""

df_Days_on_Market = pd.read_sql(query, conn)
print(df_Days_on_Market)
# Out:
#       Property_Type listing_id         City Date_Listed Date_Sold  \
# 0         Apartment     L00001     New York  2023-05-06      None
# 1         Apartment     L00002  Los Angeles  2023-02-14      None
# 2         Apartment     L00003      Houston  2023-04-22      None
# 3         Apartment     L00004      Phoenix  2024-01-02      None
# 4         Townhouse     L00005      Phoenix  2023-10-29      None
# ...             ...        ...          ...         ...       ...
# 21195         House     L21196      Phoenix  2023-12-31      None
# 21196         Condo     L21197      Phoenix  2023-07-23      None
# 21197     Apartment     L21198  Los Angeles  2024-06-30      None
# 21198     Townhouse     L21199  Los Angeles  2023-09-17      None
# 21199     Apartment     L21200     New York  2023-07-28      None
#
#       Days_on_Market
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
# ...              ...
# 21195           None
# 21196           None
# 21197           None
# 21198           None
# 21199           None
#
# [21200 rows x 6 columns]

# %% [markdown]
# Q16 . How does metro distance affect time on market?

# %%
cursor = conn.cursor()
sales_cols = [r[1] for r in cursor.execute("PRAGMA table_info(sales)").fetchall()]
listing_cols = [r[1] for r in cursor.execute("PRAGMA table_info(listings)").fetchall()]

# find sale date column in sales table
for c in ['sale_date','Sale_Date','Date_Sold','date_sold','saleDate','SaleDate']:
    if c in sales_cols:
        sale_date_col = c
        break
else:
    raise RuntimeError(f"Could not find sale date column in sales table. Found: {', '.join(sales_cols)}")

# find listing date column in listings table
for c in ['Date_Listed','date_listed','listed_date','DateListed','dateListed']:
    if c in listing_cols:
        listing_date_col = c
        break
else:
    raise RuntimeError(f"Could not find listing date column in listings table. Found: {', '.join(listing_cols)}")

# find listing id column name used in listings table
for c in ['Listing_ID','listing_id','ListingId','listingId']:
    if c in listing_cols:
        listing_id_col = c
        break
else:
    raise RuntimeError(f"Could not find listing id column in listings table. Found: {', '.join(listing_cols)}")

# Build and run query using the detected column names (quoted to preserve case)
query = f"""
SELECT
    CASE
        WHEN pa.metro_distance_km < 1 THEN '0-1 km'
        WHEN pa.metro_distance_km < 3 THEN '1-3 km'
        WHEN pa.metro_distance_km < 5 THEN '3-5 km'
        ELSE '5+ km'
    END AS metro_distance_km,
    ROUND(AVG(julianday(s.\"{sale_date_col}\") - julianday(l.\"{listing_date_col}\")), 2) AS avg_Days_on_Market,
    COUNT(*) AS total_listings
FROM listings l
JOIN property_attributes pa ON pa.listing_id = l.\"{listing_id_col}\"
JOIN sales s ON s.listing_id = l.\"{listing_id_col}\"
WHERE pa.metro_distance_km IS NOT NULL
  AND s.\"{sale_date_col}\" IS NOT NULL
  AND l.\"{listing_date_col}\" IS NOT NULL
GROUP BY
    CASE
        WHEN pa.metro_distance_km < 1 THEN '0-1 km'
        WHEN pa.metro_distance_km < 3 THEN '1-3 km'
        WHEN pa.metro_distance_km < 5 THEN '3-5 km'
        ELSE '5+ km'
    END
ORDER BY avg_Days_on_Market;
"""

df_Days_on_Market = pd.read_sql(query, conn)
print(df_Days_on_Market)
# Out:
#   metro_distance_km  avg_Days_on_Market  total_listings
# 0            3-5 km               59.72             186
# 1             5+ km               60.75             302
# 2            1-3 km               63.96             165
# 3            0-1 km               65.30              67

# %% [markdown]
# Q17 . What is the monthly sales trend?

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("brickview_realstate.db")

query = """
SELECT
    CAST(strftime('%Y', Date_Sold) AS INTEGER) AS sale_year,
    CAST(strftime('%m', Date_Sold) AS INTEGER) AS sale_month,
    COUNT(*) AS properties_sold,
    SUM(Sale_Price) AS total_sales_value,
    AVG(Sale_Price) AS average_sale_price
FROM sales
WHERE Date_Sold IS NOT NULL
GROUP BY
    sale_year,
    sale_month
ORDER BY
    sale_year,
    sale_month;
"""

df_sale_year_sale_month = pd.read_sql(query, conn)
print(df_sale_year_sale_month)
# Out:
#     sale_year  sale_month  properties_sold  total_sales_value  \
# 0        2023           1                7       5.298401e+06
# 1        2023           2               17       1.594507e+07
# 2        2023           3               20       1.999507e+07
# 3        2023           4               36       4.420825e+07
# 4        2023           5               45       5.138567e+07
# 5        2023           6               31       2.964344e+07
# 6        2023           7               48       5.600021e+07
# 7        2023           8               50       5.505066e+07
# 8        2023           9               46       4.986870e+07
# 9        2023          10               64       7.020253e+07
# 10       2023          11               46       4.997119e+07
# 11       2023          12               42       4.579371e+07
# 12       2024           1               44       4.800911e+07
# 13       2024           2               44       4.963750e+07
# 14       2024           3               39       4.139912e+07
# 15       2024           4               29       3.006874e+07
# 16       2024           5               45       4.518732e+07
# 17       2024           6               29       2.949840e+07
# 18       2024           7               24       2.561708e+07
# 19       2024           8               13       1.282358e+07
# 20       2024           9                1       2.293040e+05
#
#     average_sale_price
# 0         7.569144e+05
# 1         9.379453e+05
# 2         9.997533e+05
# 3         1.228007e+06
# 4         1.141904e+06
# 5         9.562401e+05
# 6         1.166671e+06
# 7         1.101013e+06
# 8         1.084102e+06
# 9         1.096915e+06
# 10        1.086330e+06
# 11        1.090327e+06
# 12        1.091116e+06
# 13        1.128125e+06
# 14        1.061516e+06
# 15        1.036853e+06
# 16        1.004163e+06
# 17        1.017186e+06
# 18        1.067378e+06
# 19        9.864294e+05
# 20        2.293040e+05

# %% [markdown]
# Q18 . Which properties are currently unsold?

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("brickview_realstate.db")

query = """
SELECT
    Property_Type,
    address,
    City,
    Date_Listed,
    listing_price
FROM listings
WHERE Date_Sold IS NULL
ORDER BY Date_Listed DESC;
"""

cols = [r[1] for r in conn.execute("PRAGMA table_info(listings)").fetchall()]

def find(cands):
    for c in cands:
        if c in cols:
            return c
    return None

pt_col = find(['Property_Type','property_type','PropertyType'])
addr_col = find(['address','Address','addr'])
city_col = find(['City','city'])
date_listed_col = find(['Date_Listed','listed_date','DateListed','listedDate','listeddate'])
price_col = find(['listing_price','price','Listing_Price','listingPrice'])
date_sold_col = find(['Date_Sold','date_sold','DateSold','datesold'])

select_parts = [
    (f"{pt_col} AS Property_Type" if pt_col else "NULL AS Property_Type"),
    (f"{addr_col} AS address" if addr_col else "NULL AS address"),
    (f"{city_col} AS City" if city_col else "NULL AS City"),
    (f"{date_listed_col} AS Date_Listed" if date_listed_col else "NULL AS Date_Listed"),
    (f"{price_col} AS listing_price" if price_col else "NULL AS listing_price"),
]

where_clause = f"WHERE {date_sold_col} IS NULL" if date_sold_col else ""
order_clause = f"ORDER BY {date_listed_col} DESC" if date_listed_col else ""

# build the joiner separately to avoid backslashes inside f-string expressions
joiner = ",\n    "
query_corrected = f"SELECT\n    {joiner.join(select_parts)}\nFROM listings\n{where_clause}\n{order_clause};"

df_Date_Listed = pd.read_sql(query_corrected, conn)
print(df_Date_Listed)
# Out:
#       Property_Type address         City Date_Listed listing_price
# 0         Townhouse    None      Chicago  2024-12-31          None
# 1             Condo    None      Chicago  2024-12-31          None
# 2         Apartment    None      Phoenix  2024-12-31          None
# 3         Townhouse    None      Phoenix  2024-12-31          None
# 4             Condo    None      Houston  2024-12-31          None
# ...             ...     ...          ...         ...           ...
# 21195     Townhouse    None      Houston  2023-01-01          None
# 21196         Condo    None     New York  2023-01-01          None
# 21197         House    None      Chicago  2023-01-01          None
# 21198         House    None  Los Angeles  2023-01-01          None
# 21199     Apartment    None      Phoenix  2023-01-01          None
#
# [21200 rows x 5 columns]

# %% [markdown]
# Q19 . Which agents have closed the most sales?

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("brickview_realstate.db")

query = """
SELECT
    agent_id,
    agent_name,
    COUNT(*) AS total_sales_closed
FROM agents
WHERE Date_Sold IS NOT NULL
GROUP BY
    agent_id,
    agent_name
ORDER BY deals_closed DESC;
"""
df_deals_closed = pd.read_sql(query_corrected, conn)
print(df_deals_closed)
# Out:
#       Property_Type address         City Date_Listed listing_price
# 0         Townhouse    None      Chicago  2024-12-31          None
# 1             Condo    None      Chicago  2024-12-31          None
# 2         Apartment    None      Phoenix  2024-12-31          None
# 3         Townhouse    None      Phoenix  2024-12-31          None
# 4             Condo    None      Houston  2024-12-31          None
# ...             ...     ...          ...         ...           ...
# 21195     Townhouse    None      Houston  2023-01-01          None
# 21196         Condo    None     New York  2023-01-01          None
# 21197         House    None      Chicago  2023-01-01          None
# 21198         House    None  Los Angeles  2023-01-01          None
# 21199     Apartment    None      Phoenix  2023-01-01          None
#
# [21200 rows x 5 columns]

# %% [markdown]
# Q20 . Who are the top agents by total sales revenue?

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("brickview_realstate.db")

query = """
SELECT
    agent_id,
    agent_name,
    SUM(sale_price) AS total_sales_revenue,
    COUNT(*) AS properties_sold,
    AVG(sale_price) AS average_sale_price
FROM listings
WHERE Date_Sold IS NOT NULL
GROUP BY
    agent_id,
    agent_name
ORDER BY total_sales_revenue DESC;
"""
# build a robust query using actual table column names
listings_cols = [r[1] for r in conn.execute("PRAGMA table_info(listings)").fetchall()]
sales_cols = [r[1] for r in conn.execute("PRAGMA table_info(sales)").fetchall()]
agents_cols = [r[1] for r in conn.execute("PRAGMA table_info(agents)").fetchall()]

def find(cols, candidates):
    for c in candidates:
        if c in cols:
            return c
    return None

listing_id_col = find(listings_cols, ['Listing_ID','listing_id','ListingId','listingId'])
listing_agent_col = find(listings_cols, ['Agent_ID','agent_id','AgentId','agentId'])
sales_listing_id_col = find(sales_cols, ['listing_id','Listing_ID','ListingId'])
sales_price_col = find(sales_cols, ['sale_price','Sale_Price','SalePrice','salePrice'])
sales_date_col = find(sales_cols, ['Date_Sold','date_sold','Sale_Date','sale_date'])
agents_id_col = find(agents_cols, ['agents_id','agent_id','id','Agents_ID','Agent_ID'])
agents_name_col = find(agents_cols, ['name','agent_name','Name','Agent_Name'])

if not listing_agent_col:
    raise RuntimeError(f"Could not find agent id column in listings. Found: {listings_cols}")

# prepare joins / selects depending on availability of agents table / name
if agents_name_col and agents_id_col:
    join_agents = f'LEFT JOIN agents a ON a."{agents_id_col}" = l."{listing_agent_col}"'
    select_agent_name = f'a."{agents_name_col}" AS agent_name'
    group_by_extra = f', a."{agents_name_col}"'
else:
    join_agents = ''
    select_agent_name = 'NULL AS agent_name'
    group_by_extra = ''

# ensure sales columns exist
if not sales_listing_id_col or not sales_price_col:
    raise RuntimeError(f"Could not find required columns in sales table. Found: {sales_cols}")

# filter by sale date if available
where_clause = f'WHERE s."{sales_date_col}" IS NOT NULL' if sales_date_col else ''

query = f'''
SELECT
    l."{listing_agent_col}" AS agent_id,
    {select_agent_name},
    SUM(s."{sales_price_col}") AS total_sales_revenue,
    COUNT(*) AS properties_sold,
    AVG(s."{sales_price_col}") AS average_sale_price
FROM listings l
JOIN sales s ON s."{sales_listing_id_col}" = l."{listing_id_col}"
{join_agents}
{where_clause}
GROUP BY
    l."{listing_agent_col}"{group_by_extra}
ORDER BY total_sales_revenue DESC;
'''

df_total_sales_revenue = pd.read_sql(query, conn)
print(df_total_sales_revenue)
# Out:
#    agent_id   agent_name  total_sales_revenue  properties_sold  \
# 0     A0011  Agent A0011         2.788227e+07               24
# 1     A0042  Agent A0042         2.719161e+07               25
# 2     A0043  Agent A0043         2.410242e+07               20
# 3     A0035  Agent A0035         2.272575e+07               21
# 4     A0014  Agent A0014         2.203401e+07               21
# 5     A0046  Agent A0046         2.133580e+07               20
# 6     A0048  Agent A0048         2.118631e+07               19
# 7     A0027  Agent A0027         2.109970e+07               18
# 8     A0009  Agent A0009         2.027927e+07               17
# 9     A0029  Agent A0029         1.958650e+07               18
# 10    A0039  Agent A0039         1.922301e+07               16
# 11    A0036  Agent A0036         1.920954e+07               16
# 12    A0050  Agent A0050         1.896855e+07               17
# 13    A0025  Agent A0025         1.881859e+07               17
# 14    A0017  Agent A0017         1.858385e+07               14
# 15    A0007  Agent A0007         1.841448e+07               19
# 16    A0001  Agent A0001         1.817392e+07               15
# 17    A0015  Agent A0015         1.775286e+07               16
# 18    A0019  Agent A0019         1.673061e+07               17
# 19    A0021  Agent A0021         1.654831e+07               17
# 20    A0006  Agent A0006         1.652323e+07               15
# 21    A0031  Agent A0031         1.572329e+07               13
# 22    A0003  Agent A0003         1.558495e+07               16
# 23    A0018  Agent A0018         1.553988e+07               13
# 24    A0012  Agent A0012         1.473053e+07               11
# 25    A0023  Agent A0023         1.463487e+07               12
# 26    A0010  Agent A0010         1.422816e+07               15
# 27    A0033  Agent A0033         1.420215e+07               16
# 28    A0041  Agent A0041         1.407748e+07               15
# 29    A0049  Agent A0049         1.395495e+07               10
# 30    A0047  Agent A0047         1.347818e+07               14
# 31    A0016  Agent A0016         1.345035e+07               15
# 32    A0024  Agent A0024         1.319602e+07               14
# 33    A0004  Agent A0004         1.275477e+07               11
# 34    A0030  Agent A0030         1.248445e+07               11
# 35    A0037  Agent A0037         1.231499e+07               12
# 36    A0040  Agent A0040         1.203929e+07               13
# 37    A0045  Agent A0045         1.181907e+07               13
# 38    A0002  Agent A0002         1.175497e+07                8
# 39    A0008  Agent A0008         1.107190e+07               11
# 40    A0038  Agent A0038         1.106064e+07               12
# 41    A0032  Agent A0032         1.065332e+07               10
# 42    A0044  Agent A0044         1.024755e+07                8
# 43    A0005  Agent A0005         1.011439e+07               10
# 44    A0028  Agent A0028         9.831891e+06               10
# 45    A0020  Agent A0020         9.605503e+06               10
# 46    A0013  Agent A0013         9.114420e+06                7
# 47    A0026  Agent A0026         8.479518e+06               12
# 48    A0034  Agent A0034         7.011394e+06                7
# 49    A0022  Agent A0022         6.303601e+06                9
#
#     average_sale_price
# 0         1.161761e+06
# 1         1.087664e+06
# 2         1.205121e+06
# 3         1.082179e+06
# 4         1.049238e+06
# 5         1.066790e+06
# 6         1.115069e+06
# 7         1.172205e+06
# 8         1.192899e+06
# 9         1.088139e+06
# 10        1.201438e+06
# 11        1.200596e+06
# 12        1.115797e+06
# 13        1.106976e+06
# 14        1.327418e+06
# 15        9.691832e+05
# 16        1.211595e+06
# 17        1.109554e+06
# 18        9.841536e+05
# 19        9.734299e+05
# 20        1.101549e+06
# 21        1.209484e+06
# 22        9.740596e+05
# 23        1.195375e+06
# 24        1.339140e+06
# 25        1.219573e+06
# 26        9.485443e+05
# 27        8.876343e+05
# 28        9.384988e+05
# 29        1.395495e+06
# 30        9.627273e+05
# 31        8.966901e+05
# 32        9.425727e+05
# 33        1.159524e+06
# 34        1.134950e+06
# 35        1.026249e+06
# 36        9.260991e+05
# 37        9.091594e+05
# 38        1.469371e+06
# 39        1.006536e+06
# 40        9.217198e+05
# 41        1.065332e+06
# 42        1.280944e+06
# 43        1.011439e+06
# 44        9.831891e+05
# 45        9.605503e+05
# 46        1.302060e+06
# 47        7.066265e+05
# 48        1.001628e+06
# 49        7.004001e+05

# %% [markdown]
# Q21 . Which agents close deals fastest?

# %%
query = """
SELECT
    a.Agent_ID AS agent_id,
    a.Name AS agent_name,
    ROUND(AVG(julianday(s.Date_Sold) - julianday(l.Date_Listed)), 2) AS avg_days_to_close,
    COUNT(s.Listing_ID) AS deals_closed
FROM agents a
JOIN listings l ON l.Agent_ID = a.Agent_ID
JOIN sales s ON s.Listing_ID = l.Listing_ID
WHERE s.Date_Sold IS NOT NULL
  AND l.Date_Listed IS NOT NULL
GROUP BY
    a.Agent_ID,
    a.Name
ORDER BY
    avg_days_to_close ASC;
"""

df_agents_closing_speed = pd.read_sql(query, conn)
print(df_agents_closing_speed)
# Out:
#    agent_id   agent_name  avg_days_to_close  deals_closed
# 0     A0044  Agent A0044              36.88             8
# 1     A0013  Agent A0013              42.43             7
# 2     A0037  Agent A0037              44.50            12
# 3     A0002  Agent A0002              45.50             8
# 4     A0008  Agent A0008              46.64            11
# 5     A0017  Agent A0017              48.57            14
# 6     A0026  Agent A0026              49.50            12
# 7     A0012  Agent A0012              50.64            11
# 8     A0010  Agent A0010              51.13            15
# 9     A0043  Agent A0043              52.35            20
# 10    A0009  Agent A0009              52.71            17
# 11    A0018  Agent A0018              54.69            13
# 12    A0022  Agent A0022              55.56             9
# 13    A0028  Agent A0028              55.60            10
# 14    A0040  Agent A0040              55.92            13
# 15    A0041  Agent A0041              56.13            15
# 16    A0036  Agent A0036              56.38            16
# 17    A0023  Agent A0023              56.50            12
# 18    A0046  Agent A0046              59.90            20
# 19    A0027  Agent A0027              61.33            18
# 20    A0047  Agent A0047              61.36            14
# 21    A0030  Agent A0030              61.55            11
# 22    A0049  Agent A0049              61.80            10
# 23    A0001  Agent A0001              61.93            15
# 24    A0019  Agent A0019              62.00            17
# 25    A0029  Agent A0029              62.00            18
# 26    A0024  Agent A0024              62.21            14
# 27    A0020  Agent A0020              62.30            10
# 28    A0032  Agent A0032              62.50            10
# 29    A0033  Agent A0033              62.75            16
# 30    A0050  Agent A0050              62.88            17
# 31    A0005  Agent A0005              63.90            10
# 32    A0007  Agent A0007              64.47            19
# 33    A0016  Agent A0016              64.53            15
# 34    A0011  Agent A0011              64.71            24
# 35    A0015  Agent A0015              65.94            16
# 36    A0042  Agent A0042              67.00            25
# 37    A0014  Agent A0014              67.24            21
# 38    A0035  Agent A0035              67.24            21
# 39    A0039  Agent A0039              67.50            16
# 40    A0021  Agent A0021              67.82            17
# 41    A0034  Agent A0034              68.29             7
# 42    A0048  Agent A0048              68.58            19
# 43    A0031  Agent A0031              68.62            13
# 44    A0045  Agent A0045              69.08            13
# 45    A0038  Agent A0038              70.33            12
# 46    A0025  Agent A0025              70.76            17
# 47    A0004  Agent A0004              80.09            11
# 48    A0003  Agent A0003              80.25            16
# 49    A0006  Agent A0006              81.33            15

# %% [markdown]
# Q22 . Does experience correlate with deals closed?

# %%
query = """
SELECT
    a."Agent_ID" AS agent_id,
    a."Name" AS agent_name,
    a."experience_years" AS years_experience,
    COUNT(s."Listing_ID") AS deals_closed
FROM agents a
LEFT JOIN listings l
    ON a."Agent_ID" = l."Agent_ID"
LEFT JOIN sales s
    ON l."Listing_ID" = s."Listing_ID"
WHERE s."Date_Sold" IS NOT NULL
GROUP BY
    a."Agent_ID",
    a."Name",
    a."experience_years"
ORDER BY
    a."experience_years" DESC;
"""

df_years_experience = pd.read_sql(query, conn)
print(df_years_experience)
# Out:
#    agent_id   agent_name  years_experience  deals_closed
# 0     A0019  Agent A0019                25            17
# 1     A0045  Agent A0045                25            13
# 2     A0011  Agent A0011                23            24
# 3     A0014  Agent A0014                23            21
# 4     A0036  Agent A0036                22            16
# 5     A0003  Agent A0003                21            16
# 6     A0021  Agent A0021                21            17
# 7     A0032  Agent A0032                21            10
# 8     A0039  Agent A0039                21            16
# 9     A0048  Agent A0048                21            19
# 10    A0002  Agent A0002                20             8
# 11    A0018  Agent A0018                20            13
# 12    A0020  Agent A0020                20            10
# 13    A0031  Agent A0031                20            13
# 14    A0043  Agent A0043                20            20
# 15    A0044  Agent A0044                20             8
# 16    A0017  Agent A0017                19            14
# 17    A0028  Agent A0028                19            10
# 18    A0008  Agent A0008                18            11
# 19    A0009  Agent A0009                18            17
# 20    A0023  Agent A0023                18            12
# 21    A0010  Agent A0010                17            15
# 22    A0026  Agent A0026                17            12
# 23    A0005  Agent A0005                16            10
# 24    A0012  Agent A0012                16            11
# 25    A0029  Agent A0029                16            18
# 26    A0047  Agent A0047                16            14
# 27    A0016  Agent A0016                15            15
# 28    A0037  Agent A0037                15            12
# 29    A0013  Agent A0013                14             7
# 30    A0025  Agent A0025                14            17
# 31    A0049  Agent A0049                14            10
# 32    A0022  Agent A0022                13             9
# 33    A0030  Agent A0030                13            11
# 34    A0042  Agent A0042                13            25
# 35    A0038  Agent A0038                12            12
# 36    A0050  Agent A0050                11            17
# 37    A0001  Agent A0001                10            15
# 38    A0046  Agent A0046                10            20
# 39    A0024  Agent A0024                 9            14
# 40    A0006  Agent A0006                 7            15
# 41    A0034  Agent A0034                 7             7
# 42    A0004  Agent A0004                 5            11
# 43    A0027  Agent A0027                 5            18
# 44    A0041  Agent A0041                 5            15
# 45    A0007  Agent A0007                 4            19
# 46    A0040  Agent A0040                 4            13
# 47    A0033  Agent A0033                 3            16
# 48    A0015  Agent A0015                 2            16
# 49    A0035  Agent A0035                 1            21

# %% [markdown]
# Q23 . Do agents with higher ratings close deals faster?

# %%
query = """
SELECT
    a."Agent_ID" AS agent_id,
    a."Name" AS agent_name,
    a.rating,
    ROUND(AVG(julianday(s."Date_Sold") - julianday(l."Date_Listed")), 2) AS avg_days_to_close,
    COUNT(s."Listing_ID") AS deals_closed
FROM agents a
JOIN listings l
    ON l."Agent_ID" = a."Agent_ID"
JOIN sales s
    ON s."Listing_ID" = l."Listing_ID"
WHERE s."Date_Sold" IS NOT NULL
  AND l."Date_Listed" IS NOT NULL
GROUP BY
    a."Agent_ID",
    a."Name",
    a.rating
ORDER BY
    avg_days_to_close ASC;
"""

df_days_to_close = pd.read_sql(query, conn)
print(df_days_to_close)
# Out:
#    agent_id   agent_name  rating  avg_days_to_close  deals_closed
# 0     A0044  Agent A0044     3.6              36.88             8
# 1     A0013  Agent A0013     4.8              42.43             7
# 2     A0037  Agent A0037     4.1              44.50            12
# 3     A0002  Agent A0002     3.8              45.50             8
# 4     A0008  Agent A0008     3.4              46.64            11
# 5     A0017  Agent A0017     4.3              48.57            14
# 6     A0026  Agent A0026     5.0              49.50            12
# 7     A0012  Agent A0012     3.5              50.64            11
# 8     A0010  Agent A0010     3.4              51.13            15
# 9     A0043  Agent A0043     3.2              52.35            20
# 10    A0009  Agent A0009     4.4              52.71            17
# 11    A0018  Agent A0018     4.1              54.69            13
# 12    A0022  Agent A0022     3.2              55.56             9
# 13    A0028  Agent A0028     4.0              55.60            10
# 14    A0040  Agent A0040     4.8              55.92            13
# 15    A0041  Agent A0041     3.6              56.13            15
# 16    A0036  Agent A0036     3.7              56.38            16
# 17    A0023  Agent A0023     4.1              56.50            12
# 18    A0046  Agent A0046     3.2              59.90            20
# 19    A0027  Agent A0027     4.6              61.33            18
# 20    A0047  Agent A0047     4.0              61.36            14
# 21    A0030  Agent A0030     3.3              61.55            11
# 22    A0049  Agent A0049     4.1              61.80            10
# 23    A0001  Agent A0001     4.3              61.93            15
# 24    A0019  Agent A0019     3.1              62.00            17
# 25    A0029  Agent A0029     4.8              62.00            18
# 26    A0024  Agent A0024     4.1              62.21            14
# 27    A0020  Agent A0020     5.0              62.30            10
# 28    A0032  Agent A0032     3.3              62.50            10
# 29    A0033  Agent A0033     3.1              62.75            16
# 30    A0050  Agent A0050     3.5              62.88            17
# 31    A0005  Agent A0005     4.3              63.90            10
# 32    A0007  Agent A0007     3.8              64.47            19
# 33    A0016  Agent A0016     4.8              64.53            15
# 34    A0011  Agent A0011     4.9              64.71            24
# 35    A0015  Agent A0015     4.1              65.94            16
# 36    A0042  Agent A0042     4.3              67.00            25
# 37    A0014  Agent A0014     3.7              67.24            21
# 38    A0035  Agent A0035     3.4              67.24            21
# 39    A0039  Agent A0039     3.5              67.50            16
# 40    A0021  Agent A0021     3.6              67.82            17
# 41    A0034  Agent A0034     3.1              68.29             7
# 42    A0048  Agent A0048     4.0              68.58            19
# 43    A0031  Agent A0031     3.6              68.62            13
# 44    A0045  Agent A0045     4.2              69.08            13
# 45    A0038  Agent A0038     4.3              70.33            12
# 46    A0025  Agent A0025     3.2              70.76            17
# 47    A0004  Agent A0004     4.5              80.09            11
# 48    A0003  Agent A0003     3.6              80.25            16
# 49    A0006  Agent A0006     4.9              81.33            15

# %% [markdown]
# Q24 . What is the average commission earned by each agent?

# %%
query = """
SELECT
    a."Agent_ID" AS agent_id,
    a."Name" AS agent_name,
    a."commission_rate" AS commission_rate,
    COUNT(s."Listing_ID") AS total_deals,
    ROUND(AVG(s."Sale_Price" * a."commission_rate" / 100), 2) AS avg_commission_earned,
    ROUND(SUM(s."Sale_Price" * a."commission_rate" / 100), 2) AS total_commission_earned
FROM agents a
LEFT JOIN listings l
    ON a."Agent_ID" = l."Agent_ID"
LEFT JOIN sales s
    ON l."Listing_ID" = s."Listing_ID"
WHERE s."Sale_Price" IS NOT NULL
GROUP BY
    a."Agent_ID",
    a."Name",
    a."commission_rate"
ORDER BY
    total_commission_earned DESC;
"""

df_comission_earned = pd.read_sql(query, conn)
print(df_comission_earned)
# Out:
#    agent_id   agent_name  commission_rate  total_deals  avg_commission_earned  \
# 0     A0035  Agent A0035             2.96           21               32032.49
# 1     A0042  Agent A0042             2.24           25               24363.68
# 2     A0009  Agent A0009             2.85           17               33997.61
# 3     A0011  Agent A0011             2.01           24               23351.40
# 4     A0050  Agent A0050             2.56           17               28564.40
# 5     A0029  Agent A0029             2.45           18               26659.40
# 6     A0019  Agent A0019             2.80           17               27556.30
# 7     A0021  Agent A0021             2.73           17               26574.64
# 8     A0003  Agent A0003             2.85           16               27760.70
# 9     A0014  Agent A0014             1.97           21               20670.00
# 10    A0043  Agent A0043             1.75           20               21089.62
# 11    A0018  Agent A0018             2.63           13               31438.36
# 12    A0027  Agent A0027             1.92           18               22506.34
# 13    A0017  Agent A0017             2.14           14               28406.74
# 14    A0031  Agent A0031             2.51           13               30358.05
# 15    A0024  Agent A0024             2.95           14               27805.90
# 16    A0025  Agent A0025             2.01           17               22250.22
# 17    A0033  Agent A0033             2.56           16               22723.44
# 18    A0001  Agent A0001             2.00           15               24231.89
# 19    A0012  Agent A0012             2.37           11               31737.61
# 20    A0030  Agent A0030             2.79           11               31665.09
# 21    A0046  Agent A0046             1.57           20               16748.61
# 22    A0036  Agent A0036             1.73           16               20770.32
# 23    A0007  Agent A0007             1.78           19               17251.46
# 24    A0010  Agent A0010             2.14           15               20298.85
# 25    A0045  Agent A0045             2.50           13               22728.98
# 26    A0048  Agent A0048             1.34           19               14941.92
# 27    A0023  Agent A0023             1.89           12               23049.93
# 28    A0032  Agent A0032             2.57           10               27379.03
# 29    A0015  Agent A0015             1.49           16               16532.35
# 30    A0039  Agent A0039             1.37           16               16459.71
# 31    A0006  Agent A0006             1.58           15               17404.47
# 32    A0002  Agent A0002             2.20            8               32326.16
# 33    A0020  Agent A0020             2.67           10               25646.69
# 34    A0049  Agent A0049             1.70           10               23723.41
# 35    A0028  Agent A0028             2.25           10               22121.75
# 36    A0047  Agent A0047             1.63           14               15692.45
# 37    A0037  Agent A0037             1.78           12               18267.24
# 38    A0004  Agent A0004             1.67           11               19364.05
# 39    A0016  Agent A0016             1.45           15               13002.01
# 40    A0008  Agent A0008             1.72           11               17312.42
# 41    A0040  Agent A0040             1.58           13               14632.37
# 42    A0041  Agent A0041             1.32           15               12388.18
# 43    A0034  Agent A0034             2.46            7               24640.04
# 44    A0013  Agent A0013             1.78            7               23176.67
# 45    A0044  Agent A0044             1.45            8               18573.68
# 46    A0026  Agent A0026             1.63           12               11518.01
# 47    A0038  Agent A0038             1.22           12               11244.98
# 48    A0022  Agent A0022             1.94            9               13587.76
# 49    A0005  Agent A0005             1.11           10               11226.97
#
#     total_commission_earned
# 0                 672682.26
# 1                 609091.97
# 2                 577959.34
# 3                 560433.67
# 4                 485594.83
# 5                 479869.20
# 6                 468457.14
# 7                 451768.81
# 8                 444171.19
# 9                 434069.96
# 10                421792.32
# 11                408698.74
# 12                405114.18
# 13                397694.41
# 14                394654.65
# 15                389282.53
# 16                378253.68
# 17                363575.01
# 18                363478.40
# 19                349113.68
# 20                348316.02
# 21                334972.14
# 22                332325.11
# 23                327777.74
# 24                304482.71
# 25                295476.80
# 26                283896.50
# 27                276599.12
# 28                273790.32
# 29                264517.56
# 30                263355.29
# 31                261067.05
# 32                258609.25
# 33                256466.93
# 34                237234.07
# 35                221217.55
# 36                219694.37
# 37                219206.82
# 38                213004.59
# 39                195030.10
# 40                190436.63
# 41                190220.75
# 42                185822.76
# 43                172480.29
# 44                162236.68
# 45                148589.45
# 46                138216.14
# 47                134939.78
# 48                122289.86
# 49                112269.68

# %% [markdown]
# Q25 . Which agents currently have the most active listings?

# %%
import pandas as pd

listing_cols = [row[1] for row in conn.execute("PRAGMA table_info(listings)").fetchall()]
agents_cols = [row[1] for row in conn.execute("PRAGMA table_info(agents)").fetchall()]

def find_col(cols, candidates):
    for c in candidates:
        if c in cols:
            return c
    return None

status_col = find_col(listing_cols, ['status', 'Status', 'listing_status', 'Listing_Status'])
date_sold_col = find_col(listing_cols, ['Date_Sold', 'date_sold', 'Sale_Date', 'sale_date'])
listing_id_col = find_col(listing_cols, ['listing_id', 'Listing_ID', 'ListingId', 'listingId', 'listings_id', 'Listings_ID'])
listing_agent_col = find_col(listing_cols, ['agent_id', 'Agent_ID', 'AgentId', 'agentId'])
agents_id_col = find_col(agents_cols, ['agent_id', 'agents_id', 'Agent_ID', 'Agents_ID'])
agents_name_col = find_col(agents_cols, ['name', 'Name', 'agent_name', 'Agent_Name'])

sales_cols = [row[1] for row in conn.execute("PRAGMA table_info(sales)").fetchall()]
sales_listing_id_col = find_col(sales_cols, ['listing_id', 'Listing_ID', 'ListingId', 'listingId', 'listings_id', 'Listings_ID'])

if not agents_id_col:
    raise RuntimeError(f"Could not find agent id column in agents table. Found: {agents_cols}")
if not listing_agent_col:
    raise RuntimeError(f"Could not find agent id column in listings table. Found: {listing_cols}")
if not agents_name_col:
    raise RuntimeError(f"Could not find agent name column in agents table. Found: {agents_cols}")
if not listing_id_col:
    raise RuntimeError(f"Could not find listing id column in listings table. Found: {listing_cols}")

if status_col:
    where_clause = f"WHERE l.\"{status_col}\" = 'Active'"
elif date_sold_col:
    where_clause = f"WHERE l.\"{date_sold_col}\" IS NULL"
elif sales_listing_id_col:
    where_clause = f"""
WHERE l.\"{listing_id_col}\" NOT IN (
    SELECT s.\"{sales_listing_id_col}\"
    FROM sales s
    WHERE s.\"{sales_listing_id_col}\" IS NOT NULL
)
"""
else:
    raise RuntimeError(
        "Could not find a status or Date_Sold column in listings "
        "or a sales listing_id column to identify active listings."
    )

query = f"""
SELECT
    a."{agents_id_col}" AS agent_id,
    a."{agents_name_col}" AS agent_name,
    COUNT(l."{listing_id_col}") AS active_listings
FROM agents a
JOIN listings l
    ON a."{agents_id_col}" = l."{listing_agent_col}"
{where_clause}
GROUP BY
    a."{agents_id_col}",
    a."{agents_name_col}"
ORDER BY
    active_listings DESC;
"""

df_active_listings = pd.read_sql(query, conn)
print(df_active_listings)
# Out:
#    agent_id   agent_name  active_listings
# 0     A0023  Agent A0023              446
# 1     A0011  Agent A0011              439
# 2     A0008  Agent A0008              438
# 3     A0042  Agent A0042              435
# 4     A0014  Agent A0014              432
# 5     A0044  Agent A0044              430
# 6     A0020  Agent A0020              426
# 7     A0012  Agent A0012              425
# 8     A0015  Agent A0015              425
# 9     A0048  Agent A0048              425
# 10    A0016  Agent A0016              424
# 11    A0018  Agent A0018              422
# 12    A0031  Agent A0031              422
# 13    A0036  Agent A0036              422
# 14    A0033  Agent A0033              418
# 15    A0022  Agent A0022              417
# 16    A0040  Agent A0040              416
# 17    A0010  Agent A0010              415
# 18    A0027  Agent A0027              415
# 19    A0002  Agent A0002              414
# 20    A0037  Agent A0037              413
# 21    A0005  Agent A0005              412
# 22    A0026  Agent A0026              412
# 23    A0007  Agent A0007              411
# 24    A0035  Agent A0035              410
# 25    A0045  Agent A0045              410
# 26    A0009  Agent A0009              409
# 27    A0021  Agent A0021              409
# 28    A0050  Agent A0050              409
# 29    A0043  Agent A0043              408
# 30    A0028  Agent A0028              407
# 31    A0004  Agent A0004              406
# 32    A0032  Agent A0032              404
# 33    A0047  Agent A0047              404
# 34    A0006  Agent A0006              403
# 35    A0038  Agent A0038              401
# 36    A0041  Agent A0041              399
# 37    A0046  Agent A0046              397
# 38    A0030  Agent A0030              396
# 39    A0013  Agent A0013              395
# 40    A0029  Agent A0029              395
# 41    A0001  Agent A0001              392
# 42    A0017  Agent A0017              388
# 43    A0034  Agent A0034              388
# 44    A0049  Agent A0049              387
# 45    A0019  Agent A0019              386
# 46    A0025  Agent A0025              384
# 47    A0024  Agent A0024              380
# 48    A0039  Agent A0039              380
# 49    A0003  Agent A0003              379

# %% [markdown]
#  BUYER & FINANCING BEHAVIOR

# %% [markdown]
# Q26 . What percentage of buyers are investors vs end users?

# %%
query = """
SELECT
    buyer_type,
    COUNT(buyer_id) AS total_buyers,
    ROUND(
        COUNT(buyer_id) * 100.0 / (SELECT COUNT(*) FROM buyers),
        2
    ) AS percentage_of_buyers
FROM buyers
GROUP BY buyer_type;
"""

df_buyer_type = pd.read_sql(query, conn)
print(df_buyer_type)
# Out:
#   buyer_type  total_buyers  percentage_of_buyers
# 0   End User         10020                  50.1
# 1   Investor          9980                  49.9

# %% [markdown]
# Q27 . Which cities have the highest loan uptake rate?

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("brickview_realstate.db")

# discover column names to build a robust query (no 'loans' table expected)
def cols(table):
    return [r[1] for r in conn.execute(f"PRAGMA table_info({table})").fetchall()]

buyers_cols = cols("buyers")
sales_cols = cols("sales")
listing_cols = cols("listings")

def find(candidates, arr):
    for c in candidates:
        if c in arr:
            return c
    return None

buyer_id_col = find(['buyer_id','buyers_id','buyersId','Buyer_ID','buyers_id'], buyers_cols)
buyer_sale_id_col = find(['sale_id','sales_id','Sale_ID','saleId'], buyers_cols)
loan_taken_col = find(['loan_taken','loanTaken','loan_taken_flag'], buyers_cols)
loan_amount_col = find(['loan_amount','Loan_Amount','loanAmount'], buyers_cols)
buyer_city_col = find(['city','City','buyer_city','Buyer_City'], buyers_cols)

sales_id_col = find(['sales_id','sale_id','Sale_ID','id'], sales_cols)
sales_listing_id_col = find(['listing_id','Listing_ID','ListingId','listingId'], sales_cols)

listing_id_col = find(['listing_id','Listing_ID','ListingId','listingId','listings_id'], listing_cols)
listing_city_col = find(['city','City','town'], listing_cols)

# determine source of city
if listing_city_col and ((buyer_sale_id_col and sales_listing_id_col and listing_id_col) or (buyer_sale_id_col and sales_listing_id_col)):
    # join buyers -> sales -> listings to get city
    join_clause = []
    join_clause.append(f'LEFT JOIN sales s ON b."{buyer_sale_id_col}" = s."{sales_id_col}"' if buyer_sale_id_col and sales_id_col else '')
    join_clause.append(f'LEFT JOIN listings l ON s."{sales_listing_id_col}" = l."{listing_id_col}"' if sales_listing_id_col and listing_id_col else '')
    join_clause = "\n".join([j for j in join_clause if j])
    city_expr = f'l."{listing_city_col}"'
elif buyer_city_col:
    join_clause = ""
    city_expr = f'b."{buyer_city_col}"'
else:
    raise RuntimeError("Could not determine a city column from buyers or listings tables.")

# determine loan indicator expression
loan_indicator = None
if loan_taken_col:
    loan_indicator = f'(b."{loan_taken_col}" = 1 OR b."{loan_taken_col}" IN (\'True\',\'true\',\'TRUE\'))'
elif loan_amount_col:
    loan_indicator = f'b."{loan_amount_col}" IS NOT NULL'
else:
    # try loan provider presence
    loan_provider_col = find(['loan_provider','loanProvider','Loan_Provider'], buyers_cols)
    if loan_provider_col:
        loan_indicator = f'b."{loan_provider_col}" IS NOT NULL'
    else:
        raise RuntimeError("Could not determine loan indicator column in buyers table (loan_taken/loan_amount/loan_provider).")

buyer_id_ref = buyer_id_col or 'ROWID'  # fallback to ROWID if explicit id not present
if buyer_id_col is None:
    buyer_id_ref = 'ROWID'

query = f"""
SELECT
    {city_expr} AS city,
    COUNT(DISTINCT CASE WHEN {loan_indicator} THEN b."{buyer_id_ref}" END) AS buyers_with_loans,
    COUNT(DISTINCT b."{buyer_id_ref}") AS total_buyers,
    ROUND(
        100.0 * COUNT(DISTINCT CASE WHEN {loan_indicator} THEN b."{buyer_id_ref}" END)
        / NULLIF(COUNT(DISTINCT b."{buyer_id_ref}"), 0),
        2
    ) AS loan_uptake_rate
FROM buyers b
{join_clause}
GROUP BY
    {city_expr}
ORDER BY
    loan_uptake_rate DESC;
"""

# rebuild a correct join clause (handles buyers.sale_id -> sales.Listing_ID cases)
join_parts = []
if buyer_sale_id_col:
    if sales_id_col:
        join_parts.append(f'LEFT JOIN sales s ON b."{buyer_sale_id_col}" = s."{sales_id_col}"')
    elif sales_listing_id_col:
        join_parts.append(f'LEFT JOIN sales s ON b."{buyer_sale_id_col}" = s."{sales_listing_id_col}"')
if sales_listing_id_col and listing_id_col:
    join_parts.append(f'LEFT JOIN listings l ON s."{sales_listing_id_col}" = l."{listing_id_col}"')

new_join_clause = "\n".join(join_parts) if join_parts else join_clause

# replace the possibly-broken join_clause in the already-built query
corrected_query = query.replace(join_clause, new_join_clause)

df_loan_uptake_rate = pd.read_sql(corrected_query, conn)
print(df_loan_uptake_rate)
# Out:
#           city  buyers_with_loans  total_buyers  loan_uptake_rate
# 0  Los Angeles               1811          3552             50.99
# 1      Chicago               2188          4327             50.57
# 2     New York               1913          3809             50.22
# 3      Houston               1809          3639             49.71
# 4      Phoenix               2313          4673             49.50

# %% [markdown]
# Q28 . What is the average loan amount by buyer type?

# %%
query = """
SELECT
    buyer_type,
    ROUND(
        AVG(CASE WHEN loan_amount IS NOT NULL THEN loan_amount END),
        2
    ) AS avg_loan_amount,
    SUM(CASE WHEN loan_amount IS NOT NULL THEN 1 ELSE 0 END) AS total_loans
FROM buyers
GROUP BY buyer_type
ORDER BY avg_loan_amount DESC;
"""

df_avg_loan_amount = pd.read_sql(query, conn)
print(df_avg_loan_amount)
# Out:
#   buyer_type  avg_loan_amount  total_loans
# 0   Investor       2629271.94         9980
# 1   End User       2599433.82        10020

# %% [markdown]
# Q29 . Which payment mode is most commonly used?

# %%
# Prefer payments table if it exists, otherwise fall back to buyers.payment_mode
tables = [r[0] for r in conn.execute("SELECT name FROM sqlite_master WHERE type='table'").fetchall()]

if 'payments' in tables:
    query = """
    SELECT
        payment_mode,
        COUNT(payment_id) AS usage_count
    FROM payments
    GROUP BY payment_mode
    ORDER BY usage_count DESC;
    """
else:
    query = """
    SELECT
        payment_mode,
        COUNT(buyer_id) AS usage_count
    FROM buyers
    GROUP BY payment_mode
    ORDER BY usage_count DESC;
    """

df_usage_count = pd.read_sql(query, conn)
print(df_usage_count)
# Out:
#     payment_mode  usage_count
# 0           Cash         5088
# 1            UPI         5012
# 2         Cheque         4951
# 3  Bank Transfer         4949

# %% [markdown]
# Q30 . Do loan-backed purchases take longer to close?

# %%
# Use existing connection `conn`. Compute avg days to close for loan-backed vs non-loan purchases
import pandas as pd

# discover columns
def cols(table):
    return [r[1] for r in conn.execute(f"PRAGMA table_info({table})").fetchall()]

buyers_cols = cols("buyers")
sales_cols = cols("sales")
listing_cols = cols("listings")

def find(cands, arr):
    for c in cands:
        if c in arr:
            return c
    return None

# relevant columns
buyer_sale_id_col = find(['sale_id','sales_id','Sale_ID','saleId'], buyers_cols)
loan_taken_col = find(['loan_taken','loanTaken','loan_taken_flag'], buyers_cols)
loan_amount_col = find(['loan_amount','Loan_Amount','loanAmount'], buyers_cols)

sales_id_col = find(['sales_id','sale_id','Sale_ID','id'], sales_cols)
sales_listing_id_col = find(['listing_id','Listing_ID','ListingId'], sales_cols)
sales_date_col = find(['Date_Sold','sale_date','Sale_Date','DateSold','SaleDate'], sales_cols)

listing_id_col = find(['Listing_ID','listing_id','ListingId','listings_id'], listing_cols)
listing_date_col = find(['Date_Listed','listed_date','listedDate','DateListed'], listing_cols)

# determine loan indicator expression
if loan_taken_col:
    loan_indicator = f"(b.\"{loan_taken_col}\" = 1 OR b.\"{loan_taken_col}\" IN ('True','true','TRUE'))"
elif loan_amount_col:
    loan_indicator = f"b.\"{loan_amount_col}\" IS NOT NULL"
else:
    raise RuntimeError("Could not find loan indicator (loan_taken / loan_amount) in buyers table.")

# build joins: buyers -> sales -> listings
joins = []
if buyer_sale_id_col and sales_id_col:
    joins.append(f'JOIN sales s ON b.\"{buyer_sale_id_col}\" = s.\"{sales_id_col}\"')
elif buyer_sale_id_col and sales_listing_id_col:
    joins.append(f'JOIN sales s ON b.\"{buyer_sale_id_col}\" = s.\"{sales_listing_id_col}\"')
elif sales_id_col and sales_listing_id_col:
    joins.append('JOIN sales s ON 1=1')  # will be filtered later if needed
else:
    raise RuntimeError("Could not determine join path between buyers and sales tables.")

if sales_listing_id_col and listing_id_col:
    joins.append(f'JOIN listings l ON s.\"{sales_listing_id_col}\" = l.\"{listing_id_col}\"')
elif listing_date_col and sales_date_col:
    # if listings not joinable, try to compute from sales dates only
    pass
else:
    raise RuntimeError("Could not join sales to listings to get listing/listed date.")

join_clause = "\n".join(joins)

# ensure we have sale and listing date columns for days calculation
if not sales_date_col:
    raise RuntimeError("Could not find sale date column in sales table.")
if not listing_date_col:
    raise RuntimeError("Could not find listing/listed date column in listings table.")

query = f"""
SELECT
    CASE WHEN {loan_indicator} THEN 'Loan-backed' ELSE 'No Loan' END AS financing_type,
    ROUND(AVG(julianday(s."{sales_date_col}") - julianday(l."{listing_date_col}")), 2) AS avg_days_to_close,
    COUNT(*) AS total_deals
FROM buyers b
{join_clause}
WHERE s."{sales_date_col}" IS NOT NULL
  AND l."{listing_date_col}" IS NOT NULL
GROUP BY financing_type
ORDER BY avg_days_to_close DESC;
"""

df_avg_days_to_close = pd.read_sql(query, conn)
print(df_avg_days_to_close)
# Out:
#   financing_type  avg_days_to_close  total_deals
# 0    Loan-backed              62.15        10034
# 1        No Loan              61.07         9966

# %% [markdown]
# Q27 . Which cities have the highest loan uptake rate?

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("brickview_realstate.db")
query = """
SELECT
    b.city,
    COUNT(DISTINCT CASE
        WHEN l.loan_status = 'Approved' THEN b.buyer_id
    END) AS buyers_with_loans,
    COUNT(DISTINCT b.buyer_id) AS total_buyers,
    ROUND(
        COUNT(DISTINCT CASE
            WHEN l.loan_status = 'Approved' THEN b.buyer_id
        END) * 100.0 /
        COUNT(DISTINCT b.buyer_id),
        2
    ) AS loan_uptake_rate
FROM buyers b
LEFT JOIN loans l
    ON b.buyer_id = l.buyer_id
GROUP BY b.city
ORDER BY loan_uptake_rate DESC;
"""

df_loan_uptake_by_city = pd.read_sql(corrected_query, conn)
print(df_loan_uptake_by_city)
# Out:
#           city  buyers_with_loans  total_buyers  loan_uptake_rate
# 0  Los Angeles               1811          3552             50.99
# 1      Chicago               2188          4327             50.57
# 2     New York               1913          3809             50.22
# 3      Houston               1809          3639             49.71
# 4      Phoenix               2313          4673             49.50
